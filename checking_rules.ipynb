# %%
from clear_anonymization.models.rulelearner import RuleChefLearner
from clear_anonymization.extractors.ruleextractor import RuleExtractor
from pathlib import Path
import regex as re
from rulechef import RuleChef, Task, TaskType, Rule
from rulechef.core import RuleFormat
import random
from rulechef.executor import RuleExecutor
from clear_anonymization.ner_datasets.ner_dataset import NERData, NERSample
from clear_anonymization.extractors import factory
from clear_anonymization.extractors.base import BaseExtractor

# %%
def sample_data(samples, allowed_classes, k=6, seed=12):
    random.seed(seed)
    relevant_samples = []
    negative_samples = []
    for sample in samples:
        relevant_spans = []
        negative_spans = []

        for label in sample.labels:
            if label["class"] in allowed_classes:
                relevant_spans.append(
                    {
                        "text": label["text"],
                        "start": label["start"],
                        "end": label["end"],
                        "type": label["class"],
                    }
                )
            else:
                negative_spans.append(
                    {
                        "text": label["text"],
                        "start": label["start"],
                        "end": label["end"],
                        "type": label["class"],
                    }
                )

        if relevant_spans:
            relevant_samples.append(
                {
                    "text": sample.text,
                    "entities": list(relevant_spans),
                }
            )
        if negative_spans:
            negative_samples.append(
                {
                    "text": sample.text,
                    "entities": list(negative_spans),
                }
            )

    k = min(k, len(relevant_samples))

    return random.sample(relevant_samples, k), random.sample(negative_samples, 3)

# %%
def print_rule_result(rule, text):
    print("RULE")
    print(rule.content)
    pattern = re.compile(rule.content)
    print(pattern)
    print("######")
    print("RESULT")
    for match in pattern.finditer(text):
        match_text = match.group()
        print(match.group())
        if match_text:
            print(match_text)
        else:
            print("NO result")

    print("-----------------------")

# %%
input_dir = Path("data/ler/ler_data.json")
data = NERData.from_json(json.loads(input_dir.read_text()))
train_samples = [s for s in data.samples if s.split == "train"]

test_samples = [s for s in data.samples if s.split == "validation"]

sampled, negative = sample_data(train_samples, "ORG")
sampled
# Out:
# [{'text': 'cc ) Eine die erhöhte Beweiskraft bewirkende Rechtsgrundlage für die Ausstellung der Zertifikate lässt sich ebenso wenig der am 31. Oktober 2005 zwischen dem Bundesministerium für Verbraucherschutz , Ernährung und Landwirtschaft und dem ukrainischen Veterinärdienst getroffenen Übereinkunft über eine " Veterinärbescheinigung für die Ausfuhr von frischem Schweinefleisch aus der Bundesrepublik Deutschland in die Ukraine " oder den beiden E-Mails des Bundesministeriums vom 4. November 2005 und vom 13. März 2011 entnehmen .',
#   'entities': [{'text': 'Bundesministerium für Verbraucherschutz , Ernährung und Landwirtschaft',
#     'start': 158,
#     'end': 228,
#     'type': 'ORG'}]},
#  {'text': 'Nach der Rechtsprechung des Europäischen Gerichtshofs für Menschenrechte sei ein Verstoß gegen Art. 2 EMRK durch die Verhängung der Todesstrafe erst dann gegeben , wenn die ernsthafte Gefahr einer Vollstreckung bestehe .',
#   'entities': [{'text': 'Europäischen Gerichtshofs für Menschenrechte',
#     'start': 28,
#     'end': 72,
#     'type': 'ORG'}]},
#  {'text': 'Es ist nicht Aufgabe des Beschwerdegerichts , aus der Beschwerdebegründung unter Heranziehung von Verwaltungs- und Prozessakten das herauszusuchen , was möglicherweise - bei wohlwollender Auslegung - zur Begründung der Beschwerde geeignet sein könnte ( BSG , aaO ) .',
#   'entities': [{'text': 'BSG', 'start': 253, 'end': 256, 'type': 'ORG'}]},
#  {'text': 'Mit diesem auf das Patenterteilungsverfahren bezogenen Grundsatz hat der Bundesgerichtshof jedoch lediglich klargestellt , dass nur so ein angemessener Patentschutz gewährt werden könne .',
#   'entities': [{'text': 'Bundesgerichtshof',
#     'start': 73,
#     'end': 90,
#     'type': 'ORG'}]},
#  {'text': 'Die Beschwerdeführerin beantragt sinngemäß , den Beschluss der Markenstelle für Klasse 35 des Deutschen Patent- und Markenamts vom 12. Juni 2015 insoweit aufzuheben , als die Löschung der angegriffenen Marke angeordnet worden ist .',
#   'entities': [{'text': 'Markenstelle für Klasse 35 des Deutschen Patent- und Markenamts',
#     'start': 63,
#     'end': 126,
#     'type': 'ORG'}]},
#  {'text': 'b ) Im Juli 2009 gründete der Angeklagte den Verein „ Neudeutschland “ mit ihm als „ unabwählbarem “ ersten Vorstand .',
#   'entities': [{'text': '„ Neudeutschland “',
#     'start': 52,
#     'end': 70,
#     'type': 'ORG'}]}]

# %%
negative
# Out:
# [{'text': 'Aufgrund der dargelegten Sachlage hätte die Prüfungsstelle die Unwirksamkeit der Zustellungen erkennen können , insbesondere nachdem sie durch die Mitteilung von Patentanwalt B1 … vom 2. Mai 2013 Kenntnis von dem Bescheid der Patentanwaltskammer vom 4. April 2013 und damit von der Tatsache erhalten hat , dass die Kanzlei des beigeordneten Patentanwalts K … jedenfalls zum Zeit- punkt der vermeintlichen Zustellung der Fristverlängerung mit Beschlussankündigung am 14. März 2013 schon seit einiger Zeit verwaist war .',
#   'entities': [{'text': 'B1 …', 'start': 175, 'end': 179, 'type': 'PER'},
#    {'text': 'K …', 'start': 355, 'end': 358, 'type': 'PER'}]},
#  {'text': 'D10 Khalil , M. S. : International Research and Development Trends and Problems of HVDC Cables with Polymeric Insulation .',
#   'entities': [{'text': 'Khalil , M. S.',
#     'start': 4,
#     'end': 18,
#     'type': 'PER'}]},
#  {'text': 'Eng damit zusammen hängt das ebenfalls aus Art 103 Abs 1 GG folgende Verbot von " Überraschungsentscheidungen " .',
#   'entities': [{'text': 'Art 103 Abs 1 GG',
#     'start': 43,
#     'end': 59,
#     'type': 'NRM'}]}]

# %%
rule_learner = RuleChefLearner(
    model="gpt-5-mini-2025-08-07",
    dataset="ler",
    allowed_classes="ORG",
    rule_file="gpt5-mini_ORG_negative",
)
# Out:
# {'PERS', 'LOC', 'LIT', 'RS', 'NRM', 'REG', 'ORG'}

# %%
rule_learner.fit(sampled, negative)
# Out:
# ✓ Added example (buffer: 1 new, 1 total)
# ✓ Added example (buffer: 2 new, 2 total)
# ✓ Added example (buffer: 3 new, 3 total)
# ✓ Added example (buffer: 4 new, 4 total)
# ✓ Added example (buffer: 5 new, 5 total)
# ✓ Added example (buffer: 6 new, 6 total)
# ✗ Added negative example (buffer: 7 new, 7 total)
# ✗ Added negative example (buffer: 8 new, 8 total)
# ✗ Added negative example (buffer: 9 new, 9 total)
#
# 📥 Converting 9 buffered examples to dataset...
#    (0 corrections, 0 LLM, 9 human)
# ✓ Converted to dataset: 0 corrections, 9 examples
#
# ============================================================
# Learning rules from 9 training items
#   Corrections: 0 (high value)
#   Examples: 9
#   Mode: Synthesis + Refinement (max 3 iterations)
# ============================================================
#
# NEW PROMPT Task: Named Entity Recognition
# Description: Extract ORG: Organisationsnamen (Parteien, Vereine, Institutionen, Unternehmen) from text
#
# Input schema: {'text': 'str'}
# Output schema:
# entities: List[Entity]
#
# Entity:
#   text: string  # The matched text span
#   start: integer  # Start character offset
#   end: integer  # End character offset
#   type: string  # Entity label
#
# TRAINING EXAMPLES (6 shown):
#
# Input: {"text": "cc ) Eine die erh\u00f6hte Beweiskraft bewirkende Rechtsgrundlage f\u00fcr die Ausstellung der Zertifikate l\u00e4sst sich ebenso wenig der am 31. Oktober 2005 zwischen dem Bundesministerium f\u00fcr Verbraucherschutz , Ern\u00e4hrung und Landwirtschaft und dem ukrainischen Veterin\u00e4rdienst getroffenen \u00dcbereinkunft \u00fcber eine \" Veterin\u00e4rbescheinigung f\u00fcr die Ausfuhr von frischem Schweinefleisch aus der Bundesrepublik Deutschland in die Ukraine \" oder den beiden E-Mails des Bundesministeriums vom 4. November 2005 und vom 13. M\u00e4rz 2011 entnehmen ."}
# Output: {"entities": [{"text": "Bundesministerium f\u00fcr Verbraucherschutz , Ern\u00e4hrung und Landwirtschaft", "start": 158, "end": 228, "type": "ORG"}]}
#
# Input: {"text": "Nach der Rechtsprechung des Europ\u00e4ischen Gerichtshofs f\u00fcr Menschenrechte sei ein Versto\u00df gegen Art. 2 EMRK durch die Verh\u00e4ngung der Todesstrafe erst dann gegeben , wenn die ernsthafte Gefahr einer Vollstreckung bestehe ."}
# Output: {"entities": [{"text": "Europ\u00e4ischen Gerichtshofs f\u00fcr Menschenrechte", "start": 28, "end": 72, "type": "ORG"}]}
#
# Input: {"text": "Es ist nicht Aufgabe des Beschwerdegerichts , aus der Beschwerdebegr\u00fcndung unter Heranziehung von Verwaltungs- und Prozessakten das herauszusuchen , was m\u00f6glicherweise - bei wohlwollender Auslegung - zur Begr\u00fcndung der Beschwerde geeignet sein k\u00f6nnte ( BSG , aaO ) ."}
# Output: {"entities": [{"text": "BSG", "start": 253, "end": 256, "type": "ORG"}]}
#
# Input: {"text": "Mit diesem auf das Patenterteilungsverfahren bezogenen Grundsatz hat der Bundesgerichtshof jedoch lediglich klargestellt , dass nur so ein angemessener Patentschutz gew\u00e4hrt werden k\u00f6nne ."}
# Output: {"entities": [{"text": "Bundesgerichtshof", "start": 73, "end": 90, "type": "ORG"}]}
#
# Input: {"text": "Die Beschwerdef\u00fchrerin beantragt sinngem\u00e4\u00df , den Beschluss der Markenstelle f\u00fcr Klasse 35 des Deutschen Patent- und Markenamts vom 12. Juni 2015 insoweit aufzuheben , als die L\u00f6schung der angegriffenen Marke angeordnet worden ist ."}
# Output: {"entities": [{"text": "Markenstelle f\u00fcr Klasse 35 des Deutschen Patent- und Markenamts", "start": 63, "end": 126, "type": "ORG"}]}
#
# Input: {"text": "b ) Im Juli 2009 gr\u00fcndete der Angeklagte den Verein \u201e Neudeutschland \u201c mit ihm als \u201e unabw\u00e4hlbarem \u201c ersten Vorstand ."}
# Output: {"entities": [{"text": "\u201e Neudeutschland \u201c", "start": 52, "end": 70, "type": "ORG"}]}
#
#  NEGATIVE TRAINING EXAMPLES (3 shown):
# CRITICAL:
# - NONE of the entities shown below are ORG
#
# These examples contain spans that MUST NOT be extracted.
# - You MUST NOT generate rules that extract these patterns.
# - You MUST NOT output these entity types under any circumstances
#
# Input: {"text": "Aufgrund der dargelegten Sachlage h\u00e4tte die Pr\u00fcfungsstelle die Unwirksamkeit der Zustellungen erkennen k\u00f6nnen , insbesondere nachdem sie durch die Mitteilung von Patentanwalt B1 \u2026 vom 2. Mai 2013 Kenntnis von dem Bescheid der Patentanwaltskammer vom 4. April 2013 und damit von der Tatsache erhalten hat , dass die Kanzlei des beigeordneten Patentanwalts K \u2026 jedenfalls zum Zeit- punkt der vermeintlichen Zustellung der Fristverl\u00e4ngerung mit Beschlussank\u00fcndigung am 14. M\u00e4rz 2013 schon seit einiger Zeit verwaist war ."}
# Output: {"entities": [{"text": "B1 \u2026", "start": 175, "end": 179, "type": "PER"}, {"text": "K \u2026", "start": 355, "end": 358, "type": "PER"}]}
#
# Input: {"text": "D10 Khalil , M. S. : International Research and Development Trends and Problems of HVDC Cables with Polymeric Insulation ."}
# Output: {"entities": [{"text": "Khalil , M. S.", "start": 4, "end": 18, "type": "PER"}]}
#
# Input: {"text": "Eng damit zusammen h\u00e4ngt das ebenfalls aus Art 103 Abs 1 GG folgende Verbot von \" \u00dcberraschungsentscheidungen \" ."}
# Output: {"entities": [{"text": "Art 103 Abs 1 GG", "start": 43, "end": 59, "type": "NRM"}]}
#
# YOUR TASK:
# Synthesize a complete ruleset (max 10 rules) that:
# 1. Handles all corrections correctly (CRITICAL - these show failure modes)
# 2. Works on all examples
# 3. Respects user feedback
# 4. Is general and minimal (avoid redundant rules)
#
# RULES CAN BE:- Regex patterns (for structured extraction)
#
# IMPORTANT: You must ONLY use the allowed formats listed above. Do NOT generate rules in other formats.
# IMPORTANT: Do NOT include Python/code rules. Only return the listed formats.
# IMPORTANT: Do NOT include spaCy rules. Only return the listed formats.
#
# SCHEMA-AWARE RULES:
# For this task, rules must include an output_template that maps matches to the output schema.
#
# Output schema:
# entities: List[Entity]
#
# Entity:
#   text: string  # The matched text span
#   start: integer  # Start character offset
#   end: integer  # End character offset
#   type: string  # Entity label
#
# Each rule needs:
# - pattern: The regex pattern to match
# - output_template: JSON template for each match, using variables:
#   - $0: Full match text
#   - $start: Start character offset
#   - $end: End character offset
#   - $1, $2, ...: Capture groups (regex only)
# - output_key: Which output array to populate (e.g., "entities")
#
# Return JSON:
# {
#   "analysis": "What patterns did you find? What went wrong in corrections?",
#   "strategy": "Overall approach",
#   "note": "Every rule must include both output_template and output_key",
#   "rules": [
#     {
#       "name": "Short rule name",
#       "description": "What this rule does",
#       "format": "regex",
#       "pattern": "regex pattern",
#       "output_template": {"text": "$0", "start": "$start", "end": "$end", "type": "LITERAL_OR_$VAR"},
#       "output_key": "entities",
#       "priority": 1-10 (higher = more important),
#       "reasoning": "Why this rule is needed"
#     }
#   ]
# }
#
# NER RULE EXAMPLES (regex):
#
# Example 1 - Organizations with corporate suffixes:
# {
#   "name": "corporate_suffixes",
#   "format": "regex",
#   "pattern": "\b([A-Z][a-z]+(?:\s+[A-Z][a-z]+)*)\s+(Inc\.|LLC|Corp\.|Corporation)\b",
#   "output_template": {"text": "$0", "start": "$start", "end": "$end", "type": "ORG"},
#   "output_key": "entities",
#   "priority": 9
# }
#
# Focus on learning from CORRECTIONS - they show exactly what went wrong!
#
# IMPORTANT: Return ONLY valid JSON. Ensure:
# - All strings use double quotes and are properly escaped
# - All braces and brackets are balanced
# - No trailing commas
# - Response is complete (not truncated)
#
# 📚 Synthesizing rules from dataset...
#       Validation error: unbalanced parenthesis at position 129
#    ⚠ Skipped invalid rule: capitalized_multiword_orgs
# ✓ Synthesized 4 rules (90.7s)
# ✓ Generated 4 rules
#
# 🔄 Refinement loop (max 3 iterations)
# [1/3] Evaluating rules...
# [1/3] Accuracy: 0.0% (0/9)
# [1/3] Refining based on 9 failures...
# [1/3] Refined 10 rules (99.7s)
# [2/3] Evaluating rules...
# [2/3] Accuracy: 11.1% (1/9)
# [2/3] Refining based on 8 failures...
#       Validation error: look-behind requires fixed-width pattern
#    ⚠ Skipped invalid rule: verein_with_quoted_name
#       Validation error: look-behind requires fixed-width pattern
#    ⚠ Skipped invalid rule: quoted_org_with_known_suffixes
# [2/3] Refined 7 rules (112.7s)
# [3/3] Evaluating rules...
# [3/3] Accuracy: 44.4% (4/9)
# [3/3] Refining based on 5 failures...
# [3/3] Refined 9 rules (68.8s)
#
# ============================================================
# Learning complete! (372.0s)
#   Rules: 7
#   Accuracy: 44.4% (4/9)
# ============================================================

# %%
rules_file = Path("./rulechef_data/gpt5-mini_ORG_negative.json")
rules_data = json.loads(rules_file.read_text())

rules = [Rule.from_dict(r) for r in rules_data.get("rules")]
for rule in rules:
    print(rule.description)
    print(rule.content)
    print("####################")
# Out:
# Exact match for 'Bundesministerium für Verbraucherschutz, Ernährung und Landwirtschaft' (handles ü/ae variants and optional comma).
# \bBundesministerium\s+f(?:ü|u)r\s+Verbraucherschutz\s*,?\s*(?:Ern(?:ä|ae)hrung)\s+und\s+Landwirtschaft\b
# ####################
# Exact match for 'Europäischen Gerichtshofs für Menschenrechte' (umlaut/ae variants).
# \bEurop(?:ae|ä)ischen\s+Gerichtshofs\s+f(?:ü|u)r\s+Menschenrechte\b
# ####################
# Match 'Markenstelle für Klasse <num> des Deutschen Patent- und Markenamts' stopping before dates (no trailing 'vom ...').
# \bMarkenstelle\s+f(?:ü|u)r\s+Klasse\s*\d+\s+des\s+Deutschen\s+Patent-\s*und\s+Markenamts\b(?=(?:[\.,;:]|\s+vom\b|\s*$))
# ####################
# Exact token match for 'Bundesgerichtshof'.
# \bBundesgerichtshof\b
# ####################
# Match 'Patentanwaltskammer' with up to 3 preceding capitalized words (e.g., regional name) but do not include trailing 'vom' or dates.
# \b(?:[A-ZÄÖÜ][\wÄÖÜäöüß\-']*(?:\s+[A-ZÄÖÜ][\wÄÖÜäöüß\-']*){0,3}\s+)?Patentanwaltskammer\b(?=(?:[\.,;:]|\s+vom\b|\s*$))
# ####################
# Match company names that include common corporate suffixes (GmbH, AG, KG, e.V., GmbH & Co. KG) with up to 6 preceding tokens (capitalized) to capture the company name plus suffix.
# \b(?:[A-ZÄÖÜ][\wÄÖÜäöüß\-']*(?:\s+[A-ZÄÖÜ][\wÄÖÜäöüß\-']*){0,6})\s+(?:GmbH|AG|KG|OHG|GmbH\s*&\s*Co\.?|GmbH\s*&\s*Co\s*KG|e\.V\.|e\.V)\b
# ####################
# Conservative generic rule: up to 3 preceding capitalized tokens plus a guarded organization keyword (stops before 'vom' or dates or punctuation). This is intentionally conservative to avoid long narrative captures.
# \b(?:[A-ZÄÖÜ][\wÄÖÜäöüß\-']*(?:\s+[A-ZÄÖÜ][\wÄÖÜäöüß\-']*){0,3}\s+)?(?:Bundesministerium|Bundesgerichtshof|Gerichtshof|Veterin(?:är|a)dienst|Markenstelle|Patent(?:-\s*und\s*Markenamt|\s*und\s*Markenamt)|Patentanwaltskammer|Kanzlei|Verein|Stiftung|Institut|Universit(?:ät|y)|Behörde)\b(?=(?:[\.,;:]|\s+vom\b|\s*$))
# ####################

# %%
rules = [Rule.from_dict(r) for r in rules_data.get("rules")]
# print(rules)

RuleChefExtractor = factory.make_extractor(
    "rulechef",
    dataset="ler",
    rules=rules,
)

print(
    RuleChefExtractor.predict(
        {
            "text": "Nadia studiert an der Technische Universität. Sie arbeitet beim AG GmbH."
        }
    )
)
# Out:
# {'entities': [{'text': 'AG GmbH', 'start': 64, 'end': 71, 'type': 'ORG'}, {'text': 'Technische Universität', 'start': 22, 'end': 44, 'type': 'ORG'}]}

# %%
print(
    RuleChefExtractor.predict(
        {"text": "Frau X kommt heute nach Wien und geht zum Sport Verein"}
    )
)
# Out:
# {'entities': [{'text': 'Sport Verein', 'start': 42, 'end': 54, 'type': 'ORG'}]}

# %%
print(RuleChefExtractor.predict({"text": "Nadia arbeitet beim AG gmbh."}))
pred = True
if pred:
    for test in test_samples:
        print(test.labels)
        result = RuleChefExtractor.predict({"text": test.text})
        print(f"Output: {result}")
        print("---------------------------------------")
        print("---------------------------------------")
        print("---------------------------------------")
# Out:
# {}
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 102, 'end': 126, 'text': '§ 14 Abs. 2 Satz 2 TzBfG', 'class': 'NRM'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 111, 'end': 128, 'text': 'Bundesgerichtshof', 'class': 'ORG'}]
# Output: {'entities': [{'text': 'Bundesgerichtshof', 'start': 111, 'end': 128, 'type': 'ORG'}]}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 101, 'end': 149, 'text': 'BGH GRUR 2012 , 1139 , Nr. 23 , 30 - Weinkaraffe', 'class': 'RS'}, {'start': 152, 'end': 211, 'text': 'Eichmann / v. Falckenstein / Kühne , a. a. O. , § 37 Rn. 11', 'class': 'LIT'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 168, 'end': 205, 'text': 'Wittreck , DRiZ 2007 , S. 356 < 359 >', 'class': 'LIT'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 118, 'end': 134, 'text': '§ 115 Abs. 2 FGO', 'class': 'NRM'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 21, 'end': 33, 'text': 'Jay B. Saoud', 'class': 'PER'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 16, 'end': 32, 'text': 'Bundesfinanzhofs', 'class': 'ORG'}, {'start': 35, 'end': 38, 'text': 'BFH', 'class': 'ORG'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 45, 'end': 46, 'text': 'A', 'class': 'PER'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 65, 'end': 89, 'text': 'Bundesverfassungsgericht', 'class': 'ORG'}, {'start': 396, 'end': 420, 'text': 'BVerfGE 76 , 253 < 255 >', 'class': 'RS'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 99, 'end': 123, 'text': 'Bundesverfassungsgericht', 'class': 'ORG'}, {'start': 139, 'end': 156, 'text': 'Art. 19 Abs. 4 GG', 'class': 'NRM'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 69, 'end': 100, 'text': 'Deutschen Patent- und Markenamt', 'class': 'ORG'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 58, 'end': 66, 'text': 'RRG 1992', 'class': 'NRM'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 134, 'end': 136, 'text': 'BA', 'class': 'ORG'}, {'start': 270, 'end': 276, 'text': 'SGB II', 'class': 'NRM'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 0, 'end': 6, 'text': 'Bender', 'class': 'PER'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 7, 'end': 29, 'text': 'Europäische Kommission', 'class': 'ORG'}, {'start': 62, 'end': 92, 'text': 'Nr. 89 der Vertikal-Leitlinien', 'class': 'NRM'}, {'start': 210, 'end': 225, 'text': '§ 18 Abs. 1 GWB', 'class': 'NRM'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 404, 'end': 410, 'text': 'NIVONA', 'class': 'ORG'}, {'start': 597, 'end': 616, 'text': '§ 26 Abs. 3 MarkenG', 'class': 'NRM'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 129, 'end': 192, 'text': 'Markenstelle für Klasse 35 des Deutschen Patent- und Markenamts', 'class': 'ORG'}]
# Output: {'entities': [{'text': 'Markenstelle für Klasse 35 des Deutschen Patent- und Markenamts', 'start': 129, 'end': 192, 'type': 'ORG'}]}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 209, 'end': 276, 'text': 'BFH-Beschlüsse vom 15. März 2002 VII B 120/01 , BFH / NV 2002 , 943', 'class': 'RS'}, {'start': 279, 'end': 340, 'text': 'vom 23. November 2010 V B 133/09 , BFH / NV 2011 , 612 , Rz 5', 'class': 'RS'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 142, 'end': 162, 'text': 'Art. 353 und 354 CPP', 'class': 'NRM'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 4, 'end': 10, 'text': 'X-EWIV', 'class': 'ORG'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 112, 'end': 116, 'text': 'DPMA', 'class': 'ORG'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 219, 'end': 282, 'text': 'Greger , in : Zöller , ZPO , 31. Auflage 2016 , § 398 Rn. 5 , 7', 'class': 'LIT'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 242, 'end': 266, 'text': '§ 14 Abs. 2 Satz 1 TzBfG', 'class': 'NRM'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 8, 'end': 25, 'text': '§ 1 Nr. 1 DesignG', 'class': 'NRM'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 204, 'end': 213, 'text': '§ 128 SGG', 'class': 'NRM'}, {'start': 338, 'end': 353, 'text': '§ 124 Abs 2 SGG', 'class': 'NRM'}, {'start': 369, 'end': 415, 'text': 'BSGE 44 , 292 , 293 = SozR 1500 § 124 Nr 2 S 2', 'class': 'RS'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 247, 'end': 269, 'text': 'Anhörungsrügengesetzes', 'class': 'NRM'}, {'start': 272, 'end': 334, 'text': 'BVerfG 26. März 2001 - 1 BvR 383/00 - zu B I 2 c dd der Gründe', 'class': 'RS'}, {'start': 337, 'end': 409, 'text': 'BAG 1. Oktober 2003 - 1 ABN 62/01 - zu II 3 c der Gründe , BAGE 108 , 55', 'class': 'RS'}, {'start': 442, 'end': 467, 'text': '§ 72b Abs. 1 Satz 2 ArbGG', 'class': 'NRM'}, {'start': 468, 'end': 512, 'text': 'BAG 24. Februar 2015 - 5 AZN 1007/14 - Rn. 3', 'class': 'RS'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 23, 'end': 45, 'text': '§ 2 Abs. 5a BetrAVG aF', 'class': 'NRM'}, {'start': 75, 'end': 96, 'text': '§ 2 Abs. 1 BetrAVG aF', 'class': 'NRM'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 2, 'end': 164, 'text': 'RICHTLINIE 2008 / 94 / EG DES EUROPÄISCHEN PARLAMENTS UND DES RATES vom 22. Oktober 2008 über den Schutz der Arbeitnehmer bei Zahlungsunfähigkeit des Arbeitgebers', 'class': 'NRM'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 189, 'end': 218, 'text': '§ 85 Abs. 1 Satz 1 EStG a. F.', 'class': 'NRM'}, {'start': 241, 'end': 294, 'text': 'Killat in Herrmann / Heuer / Raupach , § 85 EStG Rz 6', 'class': 'LIT'}, {'start': 297, 'end': 372, 'text': 'Myßen / Obermair , in : Kirchhof / Söhn / Mellinghoff , EStG , § 85 Rz D 18', 'class': 'LIT'}, {'start': 375, 'end': 422, 'text': 'Schmidt / Wacker , EStG , 36. Aufl. , § 85 Rz 2', 'class': 'LIT'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 250, 'end': 251, 'text': 'K', 'class': 'PER'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 24, 'end': 27, 'text': 'KTD', 'class': 'REG'}, {'start': 89, 'end': 106, 'text': 'EinführungsTV KTD', 'class': 'REG'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 33, 'end': 61, 'text': '§ 217 in das Strafgesetzbuch', 'class': 'NRM'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 4, 'end': 24, 'text': 'PreussenElektra GmbH', 'class': 'ORG'}, {'start': 51, 'end': 117, 'text': 'Verfassungsbeschwerdeverfahren 1 BvR 2821/11 ( BVerfGE 143 , 246 )', 'class': 'RS'}, {'start': 183, 'end': 195, 'text': 'Atomgesetzes', 'class': 'NRM'}]
# Output: {'entities': [{'text': 'Die PreussenElektra GmbH', 'start': 0, 'end': 24, 'type': 'ORG'}]}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 30, 'end': 34, 'text': 'S-BV', 'class': 'ORG'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 155, 'end': 266, 'text': 'BVerfG , Beschluss der 1. Kammer des Zweiten Senats vom 12. Dezember 2012 - 2 BvR 1294/10 - , a. a. O. , Rn. 15', 'class': 'RS'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 253, 'end': 264, 'text': '§ 23b BAT-O', 'class': 'REG'}, {'start': 295, 'end': 364, 'text': 'Teil II Abschnitt B Unterabschnitte II und IV der Anlage 1a zum BAT-O', 'class': 'REG'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 85, 'end': 93, 'text': 'R … GmbH', 'class': 'ORG'}, {'start': 97, 'end': 100, 'text': 'S …', 'class': 'LOC'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 3, 'end': 126, 'text': 'Tarifvertrag ERA-Anpassungsfonds der Metallindustrie Nordwürttemberg / Nordbaden , Südwürttemberg-Hohenzollern und Südbaden', 'class': 'REG'}, {'start': 151, 'end': 161, 'text': 'TV ERA-APF', 'class': 'REG'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 189, 'end': 288, 'text': 'BFH-Urteil vom 26. Januar 1970 IV R 144/66 , BFHE 97 , 466 , BStBl II 1970 , 264 , unter C. III. 1.', 'class': 'RS'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 75, 'end': 83, 'text': '... GmbH', 'class': 'ORG'}, {'start': 86, 'end': 92, 'text': 'S-GmbH', 'class': 'ORG'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 101, 'end': 125, 'text': 'Universitat de Barcelona', 'class': 'ORG'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 285, 'end': 345, 'text': 'BGH , Beschluss vom 10. November 2016 - 1 StR 417/16 , juris', 'class': 'RS'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 6, 'end': 58, 'text': '§§ 119 , 124 , 113 , 37 , 8 Abs. 2 Nr. 1 , 2 MarkenG', 'class': 'NRM'}, {'start': 77, 'end': 88, 'text': 'Art. 5 PMMA', 'class': 'NRM'}, {'start': 91, 'end': 101, 'text': 'Art 6B PVÜ', 'class': 'NRM'}, {'start': 153, 'end': 179, 'text': 'Bundesrepublik Deutschland', 'class': 'LOC'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 490, 'end': 531, 'text': 'BGH , GRUR 2011 , 158 Rn. 8 – Hefteinband', 'class': 'RS'}, {'start': 534, 'end': 569, 'text': 'GRUR 2005 , 257 , 258 – Bürogebäude', 'class': 'RS'}, {'start': 572, 'end': 622, 'text': 'GRUR 2004 , 683 , 684 – Farbige Arzneimittelkapsel', 'class': 'RS'}, {'start': 625, 'end': 660, 'text': 'GRUR 2001 , 239f. – Zahnpastastrang', 'class': 'RS'}, {'start': 663, 'end': 698, 'text': 'GRUR 2001 , 734 , 735 – Westie-Kopf', 'class': 'RS'}, {'start': 701, 'end': 814, 'text': 'BPatG , Beschluss vom 06. 08. 2015 25 W ( pat ) 14/14 – Abbildung eines bunten aus Stoffbahnen bestehenden Zeltes', 'class': 'RS'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 266, 'end': 310, 'text': 'BAG 17. Oktober 2013 - 8 AZR 974/12 - Rn. 27', 'class': 'RS'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 37, 'end': 58, 'text': '§ 240 Abs 1 S 2 SGB V', 'class': 'NRM'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 86, 'end': 109, 'text': '§ 24 Abs. 6 Satz 6 PatG', 'class': 'NRM'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 68, 'end': 79, 'text': 'Wahlordnung', 'class': 'NRM'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 52, 'end': 60, 'text': '§ 13 GVG', 'class': 'NRM'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 359, 'end': 400, 'text': 'BGH Urteil vom 23. 9. 1986 - VI ZR 261/85', 'class': 'RS'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 118, 'end': 121, 'text': 'USA', 'class': 'LOC'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 16, 'end': 32, 'text': '§ 135 Abs. 2 FGO', 'class': 'NRM'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 39, 'end': 105, 'text': 'Urteil des Hessischen Finanzgerichts vom 24. März 2015 4 K 1187/11', 'class': 'RS'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 44, 'end': 50, 'text': 'A-GmbH', 'class': 'ORG'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 26, 'end': 39, 'text': 'Paul Kirchhof', 'class': 'PER'}, {'start': 78, 'end': 103, 'text': '§ 18 Abs. 1 Nr. 1 BVerfGG', 'class': 'NRM'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 10, 'end': 98, 'text': 'Sechste Gesetz über Änderungen in der Unfallversicherung vom 9. 3. 1942 ( RGBl I S 107 )', 'class': 'NRM'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 311, 'end': 313, 'text': 'H.', 'class': 'PER'}, {'start': 319, 'end': 342, 'text': '§ 29a Abs. 1 Nr. 2 BtMG', 'class': 'NRM'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 108, 'end': 125, 'text': '§ 118 Abs 4 SGB 5', 'class': 'NRM'}, {'start': 131, 'end': 150, 'text': '§ 24 Abs 3 Ärzte ZV', 'class': 'NRM'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 4, 'end': 7, 'text': 'BFH', 'class': 'ORG'}, {'start': 124, 'end': 151, 'text': '§ 39 Abs. 2 Nr. 1 Satz 1 AO', 'class': 'NRM'}, {'start': 159, 'end': 220, 'text': 'BFH-Urteile in BFHE 166 , 49 , BStBl II 1992 , 182 , unter 1.', 'class': 'RS'}, {'start': 223, 'end': 307, 'text': 'vom 14. Mai 2002 VIII R 30/98 , BFHE 199 , 181 , BStBl II 2002 , 741 , unter I. 1. a', 'class': 'RS'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 10, 'end': 20, 'text': '§ 247 StPO', 'class': 'NRM'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 52, 'end': 63, 'text': 'Art. 3 EMRK', 'class': 'NRM'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 120, 'end': 153, 'text': '§ 23 Abs. 1 Satz 2 , § 92 BVerfGG', 'class': 'NRM'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 5, 'end': 24, 'text': '§ 137 Abs 1 SGB III', 'class': 'NRM'}, {'start': 35, 'end': 133, 'text': 'Gesetzes zur Verbesserung der Eingliederungschancen am Arbeitsmarkt vom 20. 12. 2011 - BGBl I 2854', 'class': 'NRM'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 40, 'end': 94, 'text': 'Urteil in BFHE 257 , 177 , BStBl II 2017 , 760 , Rz 49', 'class': 'RS'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 192, 'end': 217, 'text': 'Bundesverwaltungsgerichts', 'class': 'ORG'}, {'start': 386, 'end': 448, 'text': 'BVerwG 3. Dezember 2014 - 2 A 3.13 - Rn. 24 , BVerwGE 151 , 14', 'class': 'RS'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 150, 'end': 256, 'text': 'Keller und Schmidt in Meyer-Ladewig / Keller / Leitherer / Schmidt , aaO , § 54 RdNr 4b und § 95 RdNr 3 ff', 'class': 'LIT'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 77, 'end': 101, 'text': '§ 8 Abs. 2 Nr. 1 MarkenG', 'class': 'NRM'}, {'start': 218, 'end': 242, 'text': '§ 8 Abs. 2 Nr. 4 MarkenG', 'class': 'NRM'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 24, 'end': 33, 'text': '§ 40 LFGB', 'class': 'NRM'}, {'start': 40, 'end': 131, 'text': 'Artikel 2 des Änderungsgesetzes zum Verbraucherinformationsgesetz ( BGBl 2012 I S. 479 f. )', 'class': 'NRM'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 116, 'end': 140, 'text': 'BVerfGE 34 , 269 < 287 >', 'class': 'RS'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 9, 'end': 12, 'text': 'GBA', 'class': 'ORG'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 37, 'end': 53, 'text': '§ 135 Abs. 2 FGO', 'class': 'NRM'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 28, 'end': 68, 'text': 'Art. 2 Abs. 1 i. V. m. Art. 20 Abs. 3 GG', 'class': 'NRM'}, {'start': 115, 'end': 154, 'text': 'Art. 2 Abs. 1 i. V. m. Art. 1 Abs. 1 GG', 'class': 'NRM'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 48, 'end': 63, 'text': 'Republik Guinea', 'class': 'LOC'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 128, 'end': 166, 'text': 'Benkard , a. a. O. , § 24 PatG , Rn. 9', 'class': 'LIT'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 0, 'end': 4, 'text': 'Koch', 'class': 'PER'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 10, 'end': 40, 'text': '§ 14 Abs. 1 Satz 2 Nr. 7 TzBfG', 'class': 'NRM'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 87, 'end': 107, 'text': '§ 160 Abs 2 Nr 3 SGG', 'class': 'NRM'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 4, 'end': 67, 'text': 'Markenstelle für Klasse 42 des Deutschen Patent- und Markenamts', 'class': 'ORG'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 383, 'end': 409, 'text': '§ 32 Abs. 6 Satz 2 BVerfGG', 'class': 'NRM'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 17, 'end': 19, 'text': 'HV', 'class': 'REG'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 273, 'end': 354, 'text': 'BSG Beschluss vom 26. 6. 2007 - B 2 U 55/07 B - SozR 4 - 1750 § 227 Nr 1 , RdNr 7', 'class': 'RS'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 150, 'end': 191, 'text': 'EuGH GRUR 2004 , 428 Rn. 30 , 31 – Henkel', 'class': 'RS'}, {'start': 194, 'end': 239, 'text': 'BGH GRUR 2006 , 850 Rn. 17 – FUSSBALL WM 2006', 'class': 'RS'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 22, 'end': 38, 'text': 'Art. 5 Abs. 3 GG', 'class': 'NRM'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 102, 'end': 117, 'text': 'Bundesfinanzhof', 'class': 'ORG'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 280, 'end': 300, 'text': '§ 97a Abs. 1 BVerfGG', 'class': 'NRM'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 27, 'end': 51, 'text': '§ 97 Abs. 5 Satz 1 ArbGG', 'class': 'NRM'}, {'start': 117, 'end': 198, 'text': 'Zentralverbands Deutscher Schornsteinfeger e. V. - Gewerkschaftlicher Fachverband', 'class': 'ORG'}, {'start': 219, 'end': 329, 'text': 'Tarifvertrags über die Förderung der beruflichen Ausbildung im Schornsteinfegerhandwerk vom 24. September 2012', 'class': 'REG'}, {'start': 219, 'end': 306, 'text': 'Tarifvertrags über die Förderung der beruflichen Ausbildung im Schornsteinfegerhandwerk', 'class': 'REG'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 39, 'end': 56, 'text': '§ 93 Abs. 2 BbgHG', 'class': 'NRM'}, {'start': 75, 'end': 85, 'text': '§ 68 BbgHG', 'class': 'NRM'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 117, 'end': 118, 'text': 'E', 'class': 'PER'}, {'start': 126, 'end': 134, 'text': 'K-Klinik', 'class': 'ORG'}, {'start': 160, 'end': 206, 'text': 'Medizinischen Dienst der Krankenversicherungen', 'class': 'ORG'}, {'start': 209, 'end': 212, 'text': 'MDK', 'class': 'ORG'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 550, 'end': 586, 'text': 'BGH , GRUR 2014 , 569 , Rn. 10 – HOT', 'class': 'RS'}, {'start': 589, 'end': 629, 'text': 'BGH , GRUR 2012 , 1143 , Rn. 9 – Starsat', 'class': 'RS'}, {'start': 632, 'end': 680, 'text': 'BGH , GRUR 2009 , 952 , Rn. 10 – DeutschlandCard', 'class': 'RS'}, {'start': 683, 'end': 732, 'text': 'BGH , GRUR 2006 , 850 , Rn. 19 – FUSSBALL WM 2006', 'class': 'RS'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 211, 'end': 264, 'text': 'EuGH GRUR 2010 , 228 Rn. 44 – VORSPRUNG DURCH TECHNIK', 'class': 'RS'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 36, 'end': 57, 'text': 'Landgericht Memmingen', 'class': 'ORG'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 207, 'end': 308, 'text': 'Stache in Bordewin / Brandt , EStG , § 38a RdNr 33 mwN , Stand der Einzelkommentierung September 2017', 'class': 'LIT'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 168, 'end': 253, 'text': 'Senatsurteil vom 30. November 2016 VI R 49/14 , BFHE 256 , 107 , BStBl II 2017 , 1011', 'class': 'RS'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 8237, 'end': 8241, 'text': 'ETSI', 'class': 'ORG'}, {'start': 8244, 'end': 8297, 'text': 'Europäisches Institut für Telekommunikationsstandards', 'class': 'ORG'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 0, 'end': 5, 'text': 'Brune', 'class': 'PER'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 277, 'end': 304, 'text': 'BSG SozR 4 - 3500 § 98 Nr 3', 'class': 'RS'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 45, 'end': 55, 'text': '§ 31 SGB V', 'class': 'NRM'}, {'start': 93, 'end': 124, 'text': '§ 10 Abs 2 der Prüfvereinbarung', 'class': 'REG'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 123, 'end': 140, 'text': '§ 349 Abs. 2 StPO', 'class': 'NRM'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 152, 'end': 198, 'text': 'EuGH GRUR 2010 , 1008 , 1009 ( Nr. 38 ) - Lego', 'class': 'RS'}, {'start': 201, 'end': 244, 'text': 'GRUR 2008 , 608 , 611 ( Nr. 66 ) - EUROHYPO', 'class': 'RS'}, {'start': 247, 'end': 291, 'text': 'GRUR 2006 , 233 , 235 , Nr. 45 - Standbeutel', 'class': 'RS'}, {'start': 294, 'end': 340, 'text': 'BGH GRUR 2015 , 173 , 174 ( Nr. 15 ) - for you', 'class': 'RS'}, {'start': 343, 'end': 380, 'text': 'GRUR 2009 , 949 ( Nr. 10 ) - My World', 'class': 'RS'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 155, 'end': 179, 'text': 'Bundesverwaltungsgericht', 'class': 'ORG'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 4, 'end': 12, 'text': 'NV Bühne', 'class': 'REG'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 117, 'end': 123, 'text': 'P GmbH', 'class': 'ORG'}]
# Output: {'entities': [{'text': 'P GmbH', 'start': 117, 'end': 123, 'type': 'ORG'}]}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# ...
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 162, 'end': 165, 'text': 'BSG', 'class': 'ORG'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 96, 'end': 133, 'text': 'Europäischen Menschenrechtskonvention', 'class': 'NRM'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 69, 'end': 72, 'text': 'BGH', 'class': 'ORG'}, {'start': 81, 'end': 101, 'text': 'Bundespatentgerichts', 'class': 'ORG'}, {'start': 189, 'end': 223, 'text': 'ISET / ISETsolar ( BGH I ZB 2/14 )', 'class': 'RS'}, {'start': 226, 'end': 257, 'text': '„ ume “ ( 27 W ( pat ) 539/14 )', 'class': 'RS'}, {'start': 263, 'end': 266, 'text': 'EHD', 'class': 'ORG'}, {'start': 269, 'end': 272, 'text': 'RSV', 'class': 'ORG'}, {'start': 275, 'end': 281, 'text': 'bb-nrw', 'class': 'ORG'}, {'start': 284, 'end': 287, 'text': 'CTL', 'class': 'ORG'}, {'start': 290, 'end': 293, 'text': 'CJD', 'class': 'ORG'}, {'start': 296, 'end': 299, 'text': 'RDB', 'class': 'ORG'}, {'start': 302, 'end': 305, 'text': 'UPW', 'class': 'ORG'}, {'start': 308, 'end': 311, 'text': 'TCP', 'class': 'ORG'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 239, 'end': 261, 'text': 'BT-Drucks 18/9984 S 90', 'class': 'LIT'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 127, 'end': 170, 'text': 'BVerfGE 8 , 222 < 225 f. > ; 78 , 58 < 68 >', 'class': 'RS'}, {'start': 173, 'end': 280, 'text': 'BVerfG , Beschluss der 2. Kammer des Ersten Senats vom 14. September 2009 - 1 BvR 1993/09 - , juris , Rn. 3', 'class': 'RS'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 0, 'end': 10, 'text': 'K. Schmidt', 'class': 'PER'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 109, 'end': 126, 'text': '§ 22 Abs 1 SGB II', 'class': 'NRM'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 134, 'end': 148, 'text': '§ 52 Abs. 2 AO', 'class': 'NRM'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 50, 'end': 56, 'text': 'Kundus', 'class': 'LOC'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 179, 'end': 242, 'text': 'BGH , Beschluss vom 23. März 2016 - VIII ZR 26/16 , juris Rn. 5', 'class': 'RS'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 38, 'end': 53, 'text': '§ 97 Abs. 1 ZPO', 'class': 'NRM'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 161, 'end': 220, 'text': 'Eichmann / v. Falckenstein / Kühne , a. a. O. , § 38 Rn. 45', 'class': 'LIT'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 200, 'end': 243, 'text': 'EuGH GRUR 2004 , 674 , Rn. 86 – Postkantoor', 'class': 'RS'}, {'start': 246, 'end': 282, 'text': 'BGH GRUR 2012 , 1143 Rn. 9 – Starsat', 'class': 'RS'}, {'start': 285, 'end': 322, 'text': 'GRUR 2012 , 270 Rn. 11 – Link economy', 'class': 'RS'}, {'start': 594, 'end': 642, 'text': 'BGH GRUR 2014 , 1204 Rn. 16 – DüsseldorfCongress', 'class': 'RS'}, {'start': 645, 'end': 679, 'text': 'a. a. O. Rn. 16 – Gute Laune Drops', 'class': 'RS'}, {'start': 682, 'end': 707, 'text': 'a. a. O. Rn. 23 – TOOOR !', 'class': 'RS'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 4, 'end': 10, 'text': 'Milger', 'class': 'PER'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 131, 'end': 158, 'text': '§ 22 Abs. 3 Satz 2 SGB VIII', 'class': 'NRM'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 70, 'end': 123, 'text': 'Entscheidungen der Finanzgerichte ( EFG ) 2016 , 1912', 'class': 'RS'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 40, 'end': 64, 'text': 'Bundesverwaltungsgericht', 'class': 'ORG'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 76, 'end': 79, 'text': 'BFH', 'class': 'ORG'}, {'start': 114, 'end': 124, 'text': '§ 7 g EStG', 'class': 'NRM'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 207, 'end': 216, 'text': '§ 712 ZPO', 'class': 'NRM'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 89, 'end': 98, 'text': '§ 195 BGB', 'class': 'NRM'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 29, 'end': 68, 'text': '§ 14 Abs. 2 Satz 1 Betriebsrentengesetz', 'class': 'NRM'}, {'start': 92, 'end': 139, 'text': 'Bundesanstalt für Finanzdienstleistungsaufsicht', 'class': 'ORG'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 74, 'end': 93, 'text': '§ 14 Abs. 1 TVÜ-VKA', 'class': 'REG'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 10, 'end': 12, 'text': 'Y.', 'class': 'ORG'}, {'start': 105, 'end': 107, 'text': 'V.', 'class': 'ORG'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 97, 'end': 160, 'text': 'BGH , Urteil vom 10. Juli 1989 - II ZR 30/89 - , juris , Rn. 19', 'class': 'RS'}, {'start': 192, 'end': 265, 'text': 'BAG , Urteil vom 29. November 2007 - 2 AZR 724/06 - , juris , Rn. 30 , 38', 'class': 'RS'}, {'start': 268, 'end': 343, 'text': 'Urteil vom 24. Mai 2012 - 2 AZR 206/11 - , www.bag.de , Rn. 17 f. , 23 , 26', 'class': 'RS'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 0, 'end': 7, 'text': 'Gallner', 'class': 'PER'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 25, 'end': 44, 'text': '§ 128 Abs 1 S 1 SGG', 'class': 'NRM'}, {'start': 75, 'end': 95, 'text': '§ 160 Abs 2 Nr 3 SGG', 'class': 'NRM'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 46, 'end': 64, 'text': '§ 2 Abs 7 S 2 BEEG', 'class': 'NRM'}, {'start': 67, 'end': 89, 'text': 'BT-Drucks 16/1889 S 21', 'class': 'LIT'}, {'start': 129, 'end': 135, 'text': 'SGB II', 'class': 'NRM'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 30, 'end': 50, 'text': '§ 51 Abs 1 Nr 4a SGG', 'class': 'NRM'}, {'start': 153, 'end': 159, 'text': 'SGB II', 'class': 'NRM'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 108, 'end': 152, 'text': '§ 48 Abs. 1 Nr. 1 Alternative 2 , Abs. 2 FGO', 'class': 'NRM'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 103, 'end': 120, 'text': 'Art. 20 Abs. 3 GG', 'class': 'NRM'}, {'start': 139, 'end': 156, 'text': 'Art. 14 Abs. 1 GG', 'class': 'NRM'}, {'start': 159, 'end': 175, 'text': 'Art. 2 Abs. 1 GG', 'class': 'NRM'}, {'start': 178, 'end': 195, 'text': 'Art. 19 Abs. 3 GG', 'class': 'NRM'}, {'start': 228, 'end': 244, 'text': 'Art. 3 Abs. 1 GG', 'class': 'NRM'}, {'start': 299, 'end': 324, 'text': 'Art. 101 Abs. 1 Satz 2 GG', 'class': 'NRM'}, {'start': 376, 'end': 394, 'text': 'Art. 103 Abs. 1 GG', 'class': 'NRM'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 105, 'end': 129, 'text': '§ 8 Abs. 2 Nr. 1 MarkenG', 'class': 'NRM'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 121, 'end': 165, 'text': 'BAG 6. Dezember 2017 - 5 AZR 864/16 - Rn. 19', 'class': 'RS'}, {'start': 168, 'end': 205, 'text': '16. Juli 2013 - 9 AZR 914/11 - Rn. 18', 'class': 'RS'}, {'start': 208, 'end': 247, 'text': 'BGH 26. März 2009 - I ZR 44/06 - Rn. 46', 'class': 'RS'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 27, 'end': 33, 'text': 'Bayern', 'class': 'LOC'}, {'start': 139, 'end': 156, 'text': 'BVerwGE 109 , 292', 'class': 'RS'}, {'start': 275, 'end': 292, 'text': 'Art. 33 Abs. 5 GG', 'class': 'NRM'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# [{'start': 17, 'end': 33, 'text': 'Bewertungsgesetz', 'class': 'NRM'}]
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------
# []
# Output: {}
# ---------------------------------------
# ---------------------------------------
# ---------------------------------------

# %%
rule_learner = RuleChefLearner(
    model="gpt-5-mini-2025-08-07",
    dataset="ler",
    allowed_classes="ORG",
    rule_file="gpt5-mini_ORG_negative_v2",
)
# Out:
# {'LIT', 'ORG', 'REG', 'RS', 'LOC', 'PERS', 'NRM'}

# %%
rule_learner.fit(sampled, negative)
# Out:
# ✓ Added example (buffer: 1 new, 1 total)
# ✓ Added example (buffer: 2 new, 2 total)
# ✓ Added example (buffer: 3 new, 3 total)
# ✓ Added example (buffer: 4 new, 4 total)
# ✓ Added example (buffer: 5 new, 5 total)
# ✓ Added example (buffer: 6 new, 6 total)
# ✗ Added negative example (buffer: 7 new, 7 total)
# ✗ Added negative example (buffer: 8 new, 8 total)
# ✗ Added negative example (buffer: 9 new, 9 total)
# ✗ Added negative example (buffer: 10 new, 10 total)
# ✗ Added negative example (buffer: 11 new, 11 total)
# ✗ Added negative example (buffer: 12 new, 12 total)
#
# 📥 Converting 12 buffered examples to dataset...
#    (0 corrections, 0 LLM, 12 human)
# ✓ Converted to dataset: 0 corrections, 12 examples
#
# ============================================================
# Learning rules from 12 training items
#   Corrections: 0 (high value)
#   Examples: 12
#   Mode: Synthesis + Refinement (max 3 iterations)
# ============================================================
#
# NEW PROMPT Task: Named Entity Recognition
# Description: Extract ORG: Organisationsnamen (Parteien, Vereine, Institutionen, Unternehmen) from text
#
# Input schema: {'text': 'str'}
# Output schema:
# entities: List[Entity]
#
# Entity:
#   text: string  # The matched text span
#   start: integer  # Start character offset
#   end: integer  # End character offset
#   type: string  # Entity label
#
# TRAINING EXAMPLES (6 shown):
#
# Input: {"text": "cc ) Eine die erh\u00f6hte Beweiskraft bewirkende Rechtsgrundlage f\u00fcr die Ausstellung der Zertifikate l\u00e4sst sich ebenso wenig der am 31. Oktober 2005 zwischen dem Bundesministerium f\u00fcr Verbraucherschutz , Ern\u00e4hrung und Landwirtschaft und dem ukrainischen Veterin\u00e4rdienst getroffenen \u00dcbereinkunft \u00fcber eine \" Veterin\u00e4rbescheinigung f\u00fcr die Ausfuhr von frischem Schweinefleisch aus der Bundesrepublik Deutschland in die Ukraine \" oder den beiden E-Mails des Bundesministeriums vom 4. November 2005 und vom 13. M\u00e4rz 2011 entnehmen ."}
# Output: {"entities": [{"text": "Bundesministerium f\u00fcr Verbraucherschutz , Ern\u00e4hrung und Landwirtschaft", "start": 158, "end": 228, "type": "ORG"}]}
#
# Input: {"text": "Nach der Rechtsprechung des Europ\u00e4ischen Gerichtshofs f\u00fcr Menschenrechte sei ein Versto\u00df gegen Art. 2 EMRK durch die Verh\u00e4ngung der Todesstrafe erst dann gegeben , wenn die ernsthafte Gefahr einer Vollstreckung bestehe ."}
# Output: {"entities": [{"text": "Europ\u00e4ischen Gerichtshofs f\u00fcr Menschenrechte", "start": 28, "end": 72, "type": "ORG"}]}
#
# Input: {"text": "Es ist nicht Aufgabe des Beschwerdegerichts , aus der Beschwerdebegr\u00fcndung unter Heranziehung von Verwaltungs- und Prozessakten das herauszusuchen , was m\u00f6glicherweise - bei wohlwollender Auslegung - zur Begr\u00fcndung der Beschwerde geeignet sein k\u00f6nnte ( BSG , aaO ) ."}
# Output: {"entities": [{"text": "BSG", "start": 253, "end": 256, "type": "ORG"}]}
#
# Input: {"text": "Mit diesem auf das Patenterteilungsverfahren bezogenen Grundsatz hat der Bundesgerichtshof jedoch lediglich klargestellt , dass nur so ein angemessener Patentschutz gew\u00e4hrt werden k\u00f6nne ."}
# Output: {"entities": [{"text": "Bundesgerichtshof", "start": 73, "end": 90, "type": "ORG"}]}
#
# Input: {"text": "Die Beschwerdef\u00fchrerin beantragt sinngem\u00e4\u00df , den Beschluss der Markenstelle f\u00fcr Klasse 35 des Deutschen Patent- und Markenamts vom 12. Juni 2015 insoweit aufzuheben , als die L\u00f6schung der angegriffenen Marke angeordnet worden ist ."}
# Output: {"entities": [{"text": "Markenstelle f\u00fcr Klasse 35 des Deutschen Patent- und Markenamts", "start": 63, "end": 126, "type": "ORG"}]}
#
# Input: {"text": "b ) Im Juli 2009 gr\u00fcndete der Angeklagte den Verein \u201e Neudeutschland \u201c mit ihm als \u201e unabw\u00e4hlbarem \u201c ersten Vorstand ."}
# Output: {"entities": [{"text": "\u201e Neudeutschland \u201c", "start": 52, "end": 70, "type": "ORG"}]}
# NEGATIVE TRAINING EXAMPLES (6 shown):
#
# The following are NEGATIVE examples that demonstrate incorrect or undesired behavior.
# DO NOT imitate these patterns or produce similar outputs.
#
# Input: {"text": "Aufgrund der dargelegten Sachlage h\u00e4tte die Pr\u00fcfungsstelle die Unwirksamkeit der Zustellungen erkennen k\u00f6nnen , insbesondere nachdem sie durch die Mitteilung von Patentanwalt B1 \u2026 vom 2. Mai 2013 Kenntnis von dem Bescheid der Patentanwaltskammer vom 4. April 2013 und damit von der Tatsache erhalten hat , dass die Kanzlei des beigeordneten Patentanwalts K \u2026 jedenfalls zum Zeit- punkt der vermeintlichen Zustellung der Fristverl\u00e4ngerung mit Beschlussank\u00fcndigung am 14. M\u00e4rz 2013 schon seit einiger Zeit verwaist war ."}
# Output: {"entities": [{"text": "B1 \u2026", "start": 175, "end": 179, "type": "PER"}, {"text": "K \u2026", "start": 355, "end": 358, "type": "PER"}]}
#
# Input: {"text": "D10 Khalil , M. S. : International Research and Development Trends and Problems of HVDC Cables with Polymeric Insulation ."}
# Output: {"entities": [{"text": "Khalil , M. S.", "start": 4, "end": 18, "type": "PER"}]}
#
# Input: {"text": "Eng damit zusammen h\u00e4ngt das ebenfalls aus Art 103 Abs 1 GG folgende Verbot von \" \u00dcberraschungsentscheidungen \" ."}
# Output: {"entities": [{"text": "Art 103 Abs 1 GG", "start": 43, "end": 59, "type": "NRM"}]}
#
# Input: {"text": "Deshalb hat die Partei regelm\u00e4\u00dfig ein Interesse daran , eine gerichtliche Entscheidung \u00fcber den vollen Betrag der wiederkehrenden Leistungen zu erstreiten ( vgl. BAG 8. M\u00e4rz 2017 - 3 AZN 886/16 ( A ) - Rn. 7 ; 14. Februar 2012 - 3 AZB 59/11 - Rn. 10 , BAGE 140 , 362 ) ."}
# Output: {"entities": [{"text": "BAG 8. M\u00e4rz 2017 - 3 AZN 886/16 ( A ) - Rn. 7", "start": 162, "end": 207, "type": "RS"}, {"text": "14. Februar 2012 - 3 AZB 59/11 - Rn. 10 , BAGE 140 , 362", "start": 210, "end": 266, "type": "RS"}]}
#
# Input: {"text": "Das streitgegenst\u00e4ndliche Verhalten sei nicht an der Beschlagnahmevorschrift des \u00a7 9 MVollzG zu messen , weil sich die Datei auf einem Klinikrechner und damit im Gewahrsam der Klinik befunden habe ."}
# Output: {"entities": [{"text": "\u00a7 9 MVollzG", "start": 81, "end": 92, "type": "NRM"}]}
#
# Input: {"text": "Eine Erhebung , Verarbeitung und Nutzung von Sozialdaten ist nur unter den Voraussetzungen des Zweiten Kapitels des SGB X zul\u00e4ssig ( \u00a7 35 Abs 2 SGB I ) ."}
# Output: {"entities": [{"text": "Zweiten Kapitels des SGB X", "start": 95, "end": 121, "type": "NRM"}, {"text": "\u00a7 35 Abs 2 SGB I", "start": 133, "end": 149, "type": "NRM"}]}
#
# YOUR TASK:
# Synthesize a complete ruleset (max 10 rules) that:
# 1. Handles all corrections correctly (CRITICAL - these show failure modes)
# 2. Works on all examples
# 3. Respects user feedback
# 4. Is general and minimal (avoid redundant rules)
#
# RULES CAN BE:- Regex patterns (for structured extraction)
#
# IMPORTANT: You must ONLY use the allowed formats listed above. Do NOT generate rules in other formats.
# IMPORTANT: Do NOT include Python/code rules. Only return the listed formats.
# IMPORTANT: Do NOT include spaCy rules. Only return the listed formats.
#
# SCHEMA-AWARE RULES:
# For this task, rules must include an output_template that maps matches to the output schema.
#
# Output schema:
# entities: List[Entity]
#
# Entity:
#   text: string  # The matched text span
#   start: integer  # Start character offset
#   end: integer  # End character offset
#   type: string  # Entity label
#
# Each rule needs:
# - pattern: The regex pattern to match
# - output_template: JSON template for each match, using variables:
#   - $0: Full match text
#   - $start: Start character offset
#   - $end: End character offset
#   - $1, $2, ...: Capture groups (regex only)
# - output_key: Which output array to populate (e.g., "entities")
#
# Return JSON:
# {
#   "analysis": "What patterns did you find? What went wrong in corrections?",
#   "strategy": "Overall approach",
#   "note": "Every rule must include both output_template and output_key",
#   "rules": [
#     {
#       "name": "Short rule name",
#       "description": "What this rule does",
#       "format": "regex",
#       "pattern": "regex pattern",
#       "output_template": {"text": "$0", "start": "$start", "end": "$end", "type": "LITERAL_OR_$VAR"},
#       "output_key": "entities",
#       "priority": 1-10 (higher = more important),
#       "reasoning": "Why this rule is needed"
#     }
#   ]
# }
#
# NER RULE EXAMPLES (regex):
#
# Example 1 - Organizations with corporate suffixes:
# {
#   "name": "corporate_suffixes",
#   "format": "regex",
#   "pattern": "\b([A-Z][a-z]+(?:\s+[A-Z][a-z]+)*)\s+(Inc\.|LLC|Corp\.|Corporation)\b",
#   "output_template": {"text": "$0", "start": "$start", "end": "$end", "type": "ORG"},
#   "output_key": "entities",
#   "priority": 9
# }
#
# Focus on learning from CORRECTIONS - they show exactly what went wrong!
#
# IMPORTANT: Return ONLY valid JSON. Ensure:
# - All strings use double quotes and are properly escaped
# - All braces and brackets are balanced
# - No trailing commas
# - Response is complete (not truncated)
#
# 📚 Synthesizing rules from dataset...
# ✓ Synthesized 6 rules (126.4s)
# ✓ Generated 6 rules
#
# 🔄 Refinement loop (max 3 iterations)
# [1/3] Evaluating rules...
# [1/3] Accuracy: 8.3% (1/12)
# [1/3] Refining based on 11 failures...
# [1/3] Refined 8 rules (123.6s)
# [2/3] Evaluating rules...
# [2/3] Accuracy: 25.0% (3/12)
# [2/3] Refining based on 9 failures...
# [2/3] Refined 13 rules (134.7s)
# [3/3] Evaluating rules...
# [3/3] Accuracy: 41.7% (5/12)
# [3/3] Refining based on 7 failures...
# [3/3] Refined 10 rules (118.9s)
#
# ============================================================
# Learning complete! (503.5s)
#   Rules: 13
#   Accuracy: 41.7% (5/12)
# ============================================================

# %%
rules_file = Path("./rulechef_data/gpt5-mini_ORG_negative_v2.json")
rules_data = json.loads(rules_file.read_text())

rules = [Rule.from_dict(r) for r in rules_data.get("rules")]
for rule in rules:
    print(rule.description)
    print(rule.content)
    print("####################")
# Out:
# Match the full name 'Bundesministerium für Verbraucherschutz, Ernährung und Landwirtschaft' (variants for umlauts and optional comma) as a single ORG to avoid partial duplicates.
# \bBundesministerium\s+f(?:u|\u00fc)r\s+Verbraucherschutz\s*,?\s*Ern(?:\u00e4|a)hrung\s+und\s+Landwirtschaft\b
# ####################
# Match full 'Markenstelle für Klasse <n> des Deutschen Patent- und Markenamts' as ORG to avoid the partial 'Markenstelle' duplicate.
# \bMarkenstelle\s+f(?:u|\u00fc)r\s+Klasse\s+\d+\s+des\s+Deutschen\s+Patent-?\s*und\s+Markenamts\b
# ####################
# Match quoted organization names when an explicit organization indicator (Verein/Partei/Firma/.../Ministerium) appears immediately before the quote. This avoids matching quoted document titles which lack such indicators.
# \b(?:Verein|Partei|Firma|Stiftung|Institut|Beh\u00f6rde|Behorde|Amt|Kammer|Konzern|Unternehmen|Gesellschaft|Bundesministerium|Ministerium)\s*(?:[:\s,]*)?(?:"|\u201e|\u201c)\s*[^"\u201e\u201c\u201d\u2019\u2018]{1,200}?(?:"|\u201d|\u2019)
# ####################
# Additional relaxed capture for cases where the quoted organization name appears after determiners like 'den Verein' or 'der Verein', including German opening quote variants.
# \b(?:der|den|einen|einer|den\s+)?Verein\s*(?:[:\s,]*)?(?:"|\u201e|\u201c)\s*[^"\u201e\u201c\u201d\u2019\u2018]{1,200}?(?:"|\u201d|\u2019)
# ####################
# Match redacted person placeholders like 'B1 …' or 'K …' (single letter/letter+digit plus ellipsis) as PER.
# \b[A-Z0-9]{1,3}\s*\u2026\b
# ####################
# Match bibliographic author names like 'Khalil , M. S.' as PER (surname followed by comma and initials).
# \b[A-ZÄÖÜ][a-zäöüßÄÖÜ\-]+\s*,\s*(?:[A-Z]\.)\s*(?:[A-Z]\.)?(?:\s*[A-Z]\.)?
# ####################
# Match references like 'Art 103 Abs 1 GG' as legal norm (NRM).
# \bArt\.?\s*\d+\s+Abs\.?\s*\d+\s+[A-Z]{1,6}\b
# ####################
# Match '§ <num> <Act>' possibly with 'Abs' as NRM (e.g., '§ 9 MVollzG', '§ 35 Abs 2 SGB I').
# \u00a7\s*\d+\s*(?:Abs\.?\s*\d+\s*)?[A-Z][A-Za-z0-9]{1,30}\b
# ####################
# Match chapter references like 'Zweiten Kapitels des SGB X' as NRM.
# \b(?:Ersten|Zweiten|Dritten|Vierten|F\u00fcnften|Sechsten)\s+Kapitels\s+des\s+SGB\s+[A-Z0-9]+\b
# ####################
# Match case citations that include court acronym and 'Rn.' with a decision/date block as RS (e.g., 'BAG 8. März 2017 - 3 AZN 886/16 ( A ) - Rn. 7').
# \b(?:BAG|BAGE|BVerfG|BGH|OLG|LG|BPatG)\b[\s\S]{0,120}?Rn\.\s*\d+\b
# ####################
# Capture longer official names that end in organization keywords (Ministerium, Bundesgerichtshof, Kammer, Institut, Stiftung, Verein, etc.). This requires the final token to be an org keyword to avoid matching long quoted document titles.
# \b(?:[A-ZÄÖÜ][\wäöüÄÖÜß\-\.\/&'’]*(?:\s|,|\-|\/|\.|&|'|\u2013|\u2014)?){0,8}(?:Ministerium|Bundesgerichtshof|Bundesverfassungsgericht|Bundesarbeitsgericht|Patent-?und-?Markenamt|Patent-?und\s*Markenamts|Kammer|Beh\u00f6rde|Behorde|Institut|Stiftung|Verein|Unternehmen|Gesellschaft|Konzern)\b
# ####################
# Refined capture of common institutional single tokens but with negative lookahead to avoid matching when they are part of longer official phrases (prevents duplicates).
# \b(?:Bundesgerichtshof|Bundesverfassungsgericht|Bundesarbeitsgericht|Patentanwaltskammer|Markenstelle|Ministerium)\b(?!\s+f(?:u|\u00fc)r)(?![\s\S]{0,40}?\bKlasse\b)(?![\s\S]{0,40}?\bVerbraucherschutz\b)
# ####################
# Low-priority, detection-only rule for long quoted spans (document titles) to avoid treating them as ORG by other weaker quoted rules. This rule is low priority and will not label them as ORG; it's intended to reduce false positive matches by other rules (captures as a generic token 'TITLE' if needed downstream).
# (?:"|\u201e|\u201c)[^"\u201e\u201c\u201d\u2019\u2018]{30,}(?:"|\u201d|\u2019)
# ####################

# %%
rule_learner = RuleChefLearner(
    model="gpt-5-mini-2025-08-07",
    dataset="ler",
    allowed_classes="ORG",
    rule_file="gpt5-mini_ORG_newprompt_v2",
)

rule_learner.fit(sampled)
# Out:
# {'PERS', 'RS', 'REG', 'NRM', 'ORG', 'LIT', 'LOC'}
# ✓ Loaded dataset: 0 corrections, 10 examples
# ✓ Added example (buffer: 1 new, 1 total)
# ✓ Added example (buffer: 2 new, 2 total)
# ✓ Added example (buffer: 3 new, 3 total)
# ✓ Added example (buffer: 4 new, 4 total)
# ✓ Added example (buffer: 5 new, 5 total)
#
# 📥 Converting 5 buffered examples to dataset...
#    (0 corrections, 0 LLM, 5 human)
# ✓ Converted to dataset: 0 corrections, 15 examples
#
# ============================================================
# Learning rules from 15 training items
#   Corrections: 0 (high value)
#   Examples: 15
#   Mode: Synthesis + Refinement (max 3 iterations)
# ============================================================
#
# NEW PROMPT Task: Named Entity Recognition
# Description: Extract ORG: Organisationsnamen (Parteien, Vereine, Institutionen, Unternehmen) from text
#
# Input schema: {'text': 'str'}
# Output schema:
# entities: List[Entity]
#
# Entity:
#   text: string  # The matched text span
#   start: integer  # Start character offset
#   end: integer  # End character offset
#   type: string  # Entity label
#
# TRAINING EXAMPLES (15 shown):
#
# Input: {"text": "cc ) Eine die erh\u00f6hte Beweiskraft bewirkende Rechtsgrundlage f\u00fcr die Ausstellung der Zertifikate l\u00e4sst sich ebenso wenig der am 31. Oktober 2005 zwischen dem Bundesministerium f\u00fcr Verbraucherschutz , Ern\u00e4hrung und Landwirtschaft und dem ukrainischen Veterin\u00e4rdienst getroffenen \u00dcbereinkunft \u00fcber eine \" Veterin\u00e4rbescheinigung f\u00fcr die Ausfuhr von frischem Schweinefleisch aus der Bundesrepublik Deutschland in die Ukraine \" oder den beiden E-Mails des Bundesministeriums vom 4. November 2005 und vom 13. M\u00e4rz 2011 entnehmen ."}
# Output: {"entities": [{"text": "Bundesministerium f\u00fcr Verbraucherschutz , Ern\u00e4hrung und Landwirtschaft", "start": 158, "end": 228, "type": "ORG"}]}
#
# Input: {"text": "Nach der Rechtsprechung des Europ\u00e4ischen Gerichtshofs f\u00fcr Menschenrechte sei ein Versto\u00df gegen Art. 2 EMRK durch die Verh\u00e4ngung der Todesstrafe erst dann gegeben , wenn die ernsthafte Gefahr einer Vollstreckung bestehe ."}
# Output: {"entities": [{"text": "Europ\u00e4ischen Gerichtshofs f\u00fcr Menschenrechte", "start": 28, "end": 72, "type": "ORG"}]}
#
# Input: {"text": "Es ist nicht Aufgabe des Beschwerdegerichts , aus der Beschwerdebegr\u00fcndung unter Heranziehung von Verwaltungs- und Prozessakten das herauszusuchen , was m\u00f6glicherweise - bei wohlwollender Auslegung - zur Begr\u00fcndung der Beschwerde geeignet sein k\u00f6nnte ( BSG , aaO ) ."}
# Output: {"entities": [{"text": "BSG", "start": 253, "end": 256, "type": "ORG"}]}
#
# Input: {"text": "Mit diesem auf das Patenterteilungsverfahren bezogenen Grundsatz hat der Bundesgerichtshof jedoch lediglich klargestellt , dass nur so ein angemessener Patentschutz gew\u00e4hrt werden k\u00f6nne ."}
# Output: {"entities": [{"text": "Bundesgerichtshof", "start": 73, "end": 90, "type": "ORG"}]}
#
# Input: {"text": "Die Beschwerdef\u00fchrerin beantragt sinngem\u00e4\u00df , den Beschluss der Markenstelle f\u00fcr Klasse 35 des Deutschen Patent- und Markenamts vom 12. Juni 2015 insoweit aufzuheben , als die L\u00f6schung der angegriffenen Marke angeordnet worden ist ."}
# Output: {"entities": [{"text": "Markenstelle f\u00fcr Klasse 35 des Deutschen Patent- und Markenamts", "start": 63, "end": 126, "type": "ORG"}]}
#
# Input: {"text": "cc ) Eine die erh\u00f6hte Beweiskraft bewirkende Rechtsgrundlage f\u00fcr die Ausstellung der Zertifikate l\u00e4sst sich ebenso wenig der am 31. Oktober 2005 zwischen dem Bundesministerium f\u00fcr Verbraucherschutz , Ern\u00e4hrung und Landwirtschaft und dem ukrainischen Veterin\u00e4rdienst getroffenen \u00dcbereinkunft \u00fcber eine \" Veterin\u00e4rbescheinigung f\u00fcr die Ausfuhr von frischem Schweinefleisch aus der Bundesrepublik Deutschland in die Ukraine \" oder den beiden E-Mails des Bundesministeriums vom 4. November 2005 und vom 13. M\u00e4rz 2011 entnehmen ."}
# Output: {"entities": [{"text": "Bundesministerium f\u00fcr Verbraucherschutz , Ern\u00e4hrung und Landwirtschaft", "start": 158, "end": 228, "type": "ORG"}]}
#
# Input: {"text": "Nach der Rechtsprechung des Europ\u00e4ischen Gerichtshofs f\u00fcr Menschenrechte sei ein Versto\u00df gegen Art. 2 EMRK durch die Verh\u00e4ngung der Todesstrafe erst dann gegeben , wenn die ernsthafte Gefahr einer Vollstreckung bestehe ."}
# Output: {"entities": [{"text": "Europ\u00e4ischen Gerichtshofs f\u00fcr Menschenrechte", "start": 28, "end": 72, "type": "ORG"}]}
#
# Input: {"text": "Es ist nicht Aufgabe des Beschwerdegerichts , aus der Beschwerdebegr\u00fcndung unter Heranziehung von Verwaltungs- und Prozessakten das herauszusuchen , was m\u00f6glicherweise - bei wohlwollender Auslegung - zur Begr\u00fcndung der Beschwerde geeignet sein k\u00f6nnte ( BSG , aaO ) ."}
# Output: {"entities": [{"text": "BSG", "start": 253, "end": 256, "type": "ORG"}]}
#
# Input: {"text": "Mit diesem auf das Patenterteilungsverfahren bezogenen Grundsatz hat der Bundesgerichtshof jedoch lediglich klargestellt , dass nur so ein angemessener Patentschutz gew\u00e4hrt werden k\u00f6nne ."}
# Output: {"entities": [{"text": "Bundesgerichtshof", "start": 73, "end": 90, "type": "ORG"}]}
#
# Input: {"text": "Die Beschwerdef\u00fchrerin beantragt sinngem\u00e4\u00df , den Beschluss der Markenstelle f\u00fcr Klasse 35 des Deutschen Patent- und Markenamts vom 12. Juni 2015 insoweit aufzuheben , als die L\u00f6schung der angegriffenen Marke angeordnet worden ist ."}
# Output: {"entities": [{"text": "Markenstelle f\u00fcr Klasse 35 des Deutschen Patent- und Markenamts", "start": 63, "end": 126, "type": "ORG"}]}
#
# Input: {"text": "cc ) Eine die erh\u00f6hte Beweiskraft bewirkende Rechtsgrundlage f\u00fcr die Ausstellung der Zertifikate l\u00e4sst sich ebenso wenig der am 31. Oktober 2005 zwischen dem Bundesministerium f\u00fcr Verbraucherschutz , Ern\u00e4hrung und Landwirtschaft und dem ukrainischen Veterin\u00e4rdienst getroffenen \u00dcbereinkunft \u00fcber eine \" Veterin\u00e4rbescheinigung f\u00fcr die Ausfuhr von frischem Schweinefleisch aus der Bundesrepublik Deutschland in die Ukraine \" oder den beiden E-Mails des Bundesministeriums vom 4. November 2005 und vom 13. M\u00e4rz 2011 entnehmen ."}
# Output: {"entities": [{"text": "Bundesministerium f\u00fcr Verbraucherschutz , Ern\u00e4hrung und Landwirtschaft", "start": 158, "end": 228, "type": "ORG"}]}
#
# Input: {"text": "Nach der Rechtsprechung des Europ\u00e4ischen Gerichtshofs f\u00fcr Menschenrechte sei ein Versto\u00df gegen Art. 2 EMRK durch die Verh\u00e4ngung der Todesstrafe erst dann gegeben , wenn die ernsthafte Gefahr einer Vollstreckung bestehe ."}
# Output: {"entities": [{"text": "Europ\u00e4ischen Gerichtshofs f\u00fcr Menschenrechte", "start": 28, "end": 72, "type": "ORG"}]}
#
# Input: {"text": "Es ist nicht Aufgabe des Beschwerdegerichts , aus der Beschwerdebegr\u00fcndung unter Heranziehung von Verwaltungs- und Prozessakten das herauszusuchen , was m\u00f6glicherweise - bei wohlwollender Auslegung - zur Begr\u00fcndung der Beschwerde geeignet sein k\u00f6nnte ( BSG , aaO ) ."}
# Output: {"entities": [{"text": "BSG", "start": 253, "end": 256, "type": "ORG"}]}
#
# Input: {"text": "Mit diesem auf das Patenterteilungsverfahren bezogenen Grundsatz hat der Bundesgerichtshof jedoch lediglich klargestellt , dass nur so ein angemessener Patentschutz gew\u00e4hrt werden k\u00f6nne ."}
# Output: {"entities": [{"text": "Bundesgerichtshof", "start": 73, "end": 90, "type": "ORG"}]}
#
# Input: {"text": "Die Beschwerdef\u00fchrerin beantragt sinngem\u00e4\u00df , den Beschluss der Markenstelle f\u00fcr Klasse 35 des Deutschen Patent- und Markenamts vom 12. Juni 2015 insoweit aufzuheben , als die L\u00f6schung der angegriffenen Marke angeordnet worden ist ."}
# Output: {"entities": [{"text": "Markenstelle f\u00fcr Klasse 35 des Deutschen Patent- und Markenamts", "start": 63, "end": 126, "type": "ORG"}]}
#
# YOUR TASK:
# Synthesize a complete ruleset (max 10 rules) that:
# 1. Handles all corrections correctly (CRITICAL - these show failure modes)
# 2. Works on all examples
# 3. Respects user feedback
# 4. Is general and minimal (avoid redundant rules)
# 5. Do not create overgeneralizing rules
#
# RULES CAN BE:- Regex patterns (for structured extraction)
#
# IMPORTANT: You must ONLY use the allowed formats listed above. Do NOT generate rules in other formats.
# IMPORTANT: Do NOT include Python/code rules. Only return the listed formats.
# IMPORTANT: Do NOT include spaCy rules. Only return the listed formats.
#
# SCHEMA-AWARE RULES:
# For this task, rules must include an output_template that maps matches to the output schema.
#
# Output schema:
# entities: List[Entity]
#
# Entity:
#   text: string  # The matched text span
#   start: integer  # Start character offset
#   end: integer  # End character offset
#   type: string  # Entity label
#
# Each rule needs:
# - pattern: The regex pattern to match
# - output_template: JSON template for each match, using variables:
#   - $0: Full match text
#   - $start: Start character offset
#   - $end: End character offset
#   - $1, $2, ...: Capture groups (regex only)
# - output_key: Which output array to populate (e.g., "entities")
#
# Return JSON:
# {
#   "analysis": "What patterns did you find? What went wrong in corrections?",
#   "strategy": "Overall approach",
#   "note": "Every rule must include both output_template and output_key",
#   "rules": [
#     {
#       "name": "Short rule name",
#       "description": "What this rule does",
#       "format": "regex",
#       "pattern": "regex pattern",
#       "output_template": {"text": "$0", "start": "$start", "end": "$end", "type": "LITERAL_OR_$VAR"},
#       "output_key": "entities",
#       "priority": 1-10 (higher = more important),
#       "reasoning": "Why this rule is needed"
#     }
#   ]
# }
#
# NER RULE EXAMPLES (regex):
#
# Example 1 - Organizations with corporate suffixes:
# {
#   "name": "corporate_suffixes",
#   "format": "regex",
#   "pattern": "\b([A-Z][a-z]+(?:\s+[A-Z][a-z]+)*)\s+(Inc\.|LLC|Corp\.|Corporation)\b",
#   "output_template": {"text": "$0", "start": "$start", "end": "$end", "type": "ORG"},
#   "output_key": "entities",
#   "priority": 9
# }
#
# Focus on learning from CORRECTIONS - they show exactly what went wrong!
#
# IMPORTANT: Return ONLY valid JSON. Ensure:
# - All strings use double quotes and are properly escaped
# - All braces and brackets are balanced
# - No trailing commas
# - Response is complete (not truncated)
#
# 📚 Synthesizing rules from dataset...
# ✓ Synthesized 6 rules (62.0s)
# ✓ Generated 6 rules
#
# 🔄 Refinement loop (max 3 iterations)
# [1/3] Evaluating rules...
# [1/3] Accuracy: 20.0% (3/15)
# [1/3] Refining based on 12 failures...
# [1/3] Refined 6 rules (93.8s)
# [2/3] Evaluating rules...
# [2/3] Accuracy: 0.0% (0/15)
# [2/3] Refining based on 15 failures...
# [2/3] Refined 5 rules (59.0s)
# [3/3] Evaluating rules...
# [3/3] Accuracy: 60.0% (9/15)
# [3/3] Refining based on 6 failures...
#       Validation error: look-behind requires fixed-width pattern
#    ⚠ Skipped invalid rule: abbreviations_in_parentheses_only_refined
# [3/3] Refined 4 rules (47.3s)
#
# ============================================================
# Learning complete! (262.1s)
#   Rules: 5
#   Accuracy: 60.0% (9/15)
# ============================================================

# %%
rule_learner = RuleChefLearner(
    model="gpt-5-mini-2025-08-07",
    dataset="ler",
    allowed_classes="ORG",
    rule_file="gpt5-mini_ORG_negative",
)
rule_learner.fit(sampled, negative)
# Out:
# {'NRM', 'LIT', 'LOC', 'PERS', 'RS', 'REG', 'ORG'}
# ✓ Loaded dataset: 0 corrections, 2 examples
# ✓ Added example (buffer: 1 new, 1 total)
# ✓ Added example (buffer: 2 new, 2 total)
# ✓ Added example (buffer: 3 new, 3 total)
# ✓ Added example (buffer: 4 new, 4 total)
# ✓ Added example (buffer: 5 new, 5 total)
# ✓ Added example (buffer: 6 new, 6 total)
# ✗ Added negative example (buffer: 7 new, 7 total)
# ✗ Added negative example (buffer: 8 new, 8 total)
# ✗ Added negative example (buffer: 9 new, 9 total)
# ✗ Added negative example (buffer: 10 new, 10 total)
# ✗ Added negative example (buffer: 11 new, 11 total)
# ✗ Added negative example (buffer: 12 new, 12 total)
#
# 📥 Converting 12 buffered examples to dataset...
#    (0 corrections, 0 LLM, 12 human)
# ✓ Converted to dataset: 0 corrections, 14 examples
#
# ============================================================
# Learning rules from 14 training items
#   Corrections: 0 (high value)
#   Examples: 14
#   Mode: Synthesis + Refinement (max 3 iterations)
# ============================================================
#
# NEW PROMPT Task: Named Entity Recognition
# Description: Extract ORG: Organisationsnamen (Parteien, Vereine, Institutionen, Unternehmen) from text
#
# Input schema: {'text': 'str'}
# Output schema:
# entities: List[Entity]
#
# Entity:
#   text: string  # The matched text span
#   start: integer  # Start character offset
#   end: integer  # End character offset
#   type: string  # Entity label
#
# TRAINING EXAMPLES (8 shown):
#
# Input: {"text": "cc ) Eine die erh\u00f6hte Beweiskraft bewirkende Rechtsgrundlage f\u00fcr die Ausstellung der Zertifikate l\u00e4sst sich ebenso wenig der am 31. Oktober 2005 zwischen dem Bundesministerium f\u00fcr Verbraucherschutz , Ern\u00e4hrung und Landwirtschaft und dem ukrainischen Veterin\u00e4rdienst getroffenen \u00dcbereinkunft \u00fcber eine \" Veterin\u00e4rbescheinigung f\u00fcr die Ausfuhr von frischem Schweinefleisch aus der Bundesrepublik Deutschland in die Ukraine \" oder den beiden E-Mails des Bundesministeriums vom 4. November 2005 und vom 13. M\u00e4rz 2011 entnehmen ."}
# Output: {"entities": [{"text": "Bundesministerium f\u00fcr Verbraucherschutz , Ern\u00e4hrung und Landwirtschaft", "start": 158, "end": 228, "type": "ORG"}]}
#
# Input: {"text": "Sie ist erforderlich iSd. \u00a7 10 Satz 2 AGG , wenn sie nicht \u00fcber das hinausgeht , was zur Erreichung des angestrebten Ziels notwendig ist ( vgl. EuGH 26. September 2013 - C- 546/11 - [ Dansk Jurist - og \u00d8konomforbund ] Rn. 59 ) ."}
# Output: {"entities": [{"text": "\u00a7 10 Satz 2 AGG", "start": 26, "end": 41, "type": "NRM"}, {"text": "EuGH 26. September 2013 - C- 546/11 - [ Dansk Jurist - og \u00d8konomforbund ] Rn. 59", "start": 144, "end": 224, "type": "RS"}]}
#
# Input: {"text": "cc ) Eine die erh\u00f6hte Beweiskraft bewirkende Rechtsgrundlage f\u00fcr die Ausstellung der Zertifikate l\u00e4sst sich ebenso wenig der am 31. Oktober 2005 zwischen dem Bundesministerium f\u00fcr Verbraucherschutz , Ern\u00e4hrung und Landwirtschaft und dem ukrainischen Veterin\u00e4rdienst getroffenen \u00dcbereinkunft \u00fcber eine \" Veterin\u00e4rbescheinigung f\u00fcr die Ausfuhr von frischem Schweinefleisch aus der Bundesrepublik Deutschland in die Ukraine \" oder den beiden E-Mails des Bundesministeriums vom 4. November 2005 und vom 13. M\u00e4rz 2011 entnehmen ."}
# Output: {"entities": [{"text": "Bundesministerium f\u00fcr Verbraucherschutz , Ern\u00e4hrung und Landwirtschaft", "start": 158, "end": 228, "type": "ORG"}]}
#
# Input: {"text": "Nach der Rechtsprechung des Europ\u00e4ischen Gerichtshofs f\u00fcr Menschenrechte sei ein Versto\u00df gegen Art. 2 EMRK durch die Verh\u00e4ngung der Todesstrafe erst dann gegeben , wenn die ernsthafte Gefahr einer Vollstreckung bestehe ."}
# Output: {"entities": [{"text": "Europ\u00e4ischen Gerichtshofs f\u00fcr Menschenrechte", "start": 28, "end": 72, "type": "ORG"}]}
#
# Input: {"text": "Es ist nicht Aufgabe des Beschwerdegerichts , aus der Beschwerdebegr\u00fcndung unter Heranziehung von Verwaltungs- und Prozessakten das herauszusuchen , was m\u00f6glicherweise - bei wohlwollender Auslegung - zur Begr\u00fcndung der Beschwerde geeignet sein k\u00f6nnte ( BSG , aaO ) ."}
# Output: {"entities": [{"text": "BSG", "start": 253, "end": 256, "type": "ORG"}]}
#
# Input: {"text": "Mit diesem auf das Patenterteilungsverfahren bezogenen Grundsatz hat der Bundesgerichtshof jedoch lediglich klargestellt , dass nur so ein angemessener Patentschutz gew\u00e4hrt werden k\u00f6nne ."}
# Output: {"entities": [{"text": "Bundesgerichtshof", "start": 73, "end": 90, "type": "ORG"}]}
#
# Input: {"text": "Die Beschwerdef\u00fchrerin beantragt sinngem\u00e4\u00df , den Beschluss der Markenstelle f\u00fcr Klasse 35 des Deutschen Patent- und Markenamts vom 12. Juni 2015 insoweit aufzuheben , als die L\u00f6schung der angegriffenen Marke angeordnet worden ist ."}
# Output: {"entities": [{"text": "Markenstelle f\u00fcr Klasse 35 des Deutschen Patent- und Markenamts", "start": 63, "end": 126, "type": "ORG"}]}
#
# Input: {"text": "b ) Im Juli 2009 gr\u00fcndete der Angeklagte den Verein \u201e Neudeutschland \u201c mit ihm als \u201e unabw\u00e4hlbarem \u201c ersten Vorstand ."}
# Output: {"entities": [{"text": "\u201e Neudeutschland \u201c", "start": 52, "end": 70, "type": "ORG"}]}
# NEGATIVE TRAINING EXAMPLES (6 shown):
#
# These examples contain spans that MUST NOT be extracted.
# They demonstrate NON-ORG entities
#
# Input: {"text": "Aufgrund der dargelegten Sachlage h\u00e4tte die Pr\u00fcfungsstelle die Unwirksamkeit der Zustellungen erkennen k\u00f6nnen , insbesondere nachdem sie durch die Mitteilung von Patentanwalt B1 \u2026 vom 2. Mai 2013 Kenntnis von dem Bescheid der Patentanwaltskammer vom 4. April 2013 und damit von der Tatsache erhalten hat , dass die Kanzlei des beigeordneten Patentanwalts K \u2026 jedenfalls zum Zeit- punkt der vermeintlichen Zustellung der Fristverl\u00e4ngerung mit Beschlussank\u00fcndigung am 14. M\u00e4rz 2013 schon seit einiger Zeit verwaist war ."}
# Output: {"entities": [{"text": "B1 \u2026", "start": 175, "end": 179, "type": "PER"}, {"text": "K \u2026", "start": 355, "end": 358, "type": "PER"}]}
#
# Input: {"text": "D10 Khalil , M. S. : International Research and Development Trends and Problems of HVDC Cables with Polymeric Insulation ."}
# Output: {"entities": [{"text": "Khalil , M. S.", "start": 4, "end": 18, "type": "PER"}]}
#
# Input: {"text": "Eng damit zusammen h\u00e4ngt das ebenfalls aus Art 103 Abs 1 GG folgende Verbot von \" \u00dcberraschungsentscheidungen \" ."}
# Output: {"entities": [{"text": "Art 103 Abs 1 GG", "start": 43, "end": 59, "type": "NRM"}]}
#
# Input: {"text": "Deshalb hat die Partei regelm\u00e4\u00dfig ein Interesse daran , eine gerichtliche Entscheidung \u00fcber den vollen Betrag der wiederkehrenden Leistungen zu erstreiten ( vgl. BAG 8. M\u00e4rz 2017 - 3 AZN 886/16 ( A ) - Rn. 7 ; 14. Februar 2012 - 3 AZB 59/11 - Rn. 10 , BAGE 140 , 362 ) ."}
# Output: {"entities": [{"text": "BAG 8. M\u00e4rz 2017 - 3 AZN 886/16 ( A ) - Rn. 7", "start": 162, "end": 207, "type": "RS"}, {"text": "14. Februar 2012 - 3 AZB 59/11 - Rn. 10 , BAGE 140 , 362", "start": 210, "end": 266, "type": "RS"}]}
#
# Input: {"text": "Das streitgegenst\u00e4ndliche Verhalten sei nicht an der Beschlagnahmevorschrift des \u00a7 9 MVollzG zu messen , weil sich die Datei auf einem Klinikrechner und damit im Gewahrsam der Klinik befunden habe ."}
# Output: {"entities": [{"text": "\u00a7 9 MVollzG", "start": 81, "end": 92, "type": "NRM"}]}
#
# Input: {"text": "Eine Erhebung , Verarbeitung und Nutzung von Sozialdaten ist nur unter den Voraussetzungen des Zweiten Kapitels des SGB X zul\u00e4ssig ( \u00a7 35 Abs 2 SGB I ) ."}
# Output: {"entities": [{"text": "Zweiten Kapitels des SGB X", "start": 95, "end": 121, "type": "NRM"}, {"text": "\u00a7 35 Abs 2 SGB I", "start": 133, "end": 149, "type": "NRM"}]}
# CRITICAL:
# - NONE of the entities shown below are ORG
# - You MUST NOT generate rules that extract these patterns.
# - You MUST NOT output these entity types under any circumstances
#
# EXISTING RULES (6 current):
#
# - ministries_and_authorities (priority 10, success: untested)
#   Format: regex
#   Pattern: \b[A-ZÄÖÜ][A-Za-zäöüÄÖÜß\.,\-/\s\(\)"']{0,200}?(?:Bundesministerium|Ministerium\s+für|Ministerium|Bu...
#   Confidence: 0.50
#
# - corporate_suffixes_german (priority 9, success: untested)
#   Format: regex
#   Pattern: \b([A-ZÄÖÜ][\wäöüÄÖÜß\.-]*(?:\s+[A-ZÄÖÜ][\wäöüÄÖÜß\.-]*){0,6})\s+(GmbH|GmbH\s*&\s*Co\.\s*KG|AG|e\.V\...
#   Confidence: 0.50
#
# - universities_and_institutes (priority 9, success: untested)
#   Format: regex
#   Pattern: \b[A-ZÄÖÜ][A-Za-zäöüÄÖÜß\.\-\/\s]{0,80}?(?:Universität|Universitaet|Hochschule|Institut|Fakultät|Zen...
#   Confidence: 0.50
#
# - political_parties_and_factions (priority 8, success: untested)
#   Format: regex
#   Pattern: \b(Bündnis(?:\s*90)?\s*\/?\s*Die\s+Grünen|Die\s+Linke|SPD|CDU|CSU|FDP|AfD)\b
#   Confidence: 0.50
#
# - organization_keywords_generic (priority 7, success: untested)
#   Format: regex
#   Pattern: \b[A-ZÄÖÜ][A-Za-zäöüÄÖÜß\.-/\s]{0,80}?(?:Gesellschaft|Verein|Partei|Fraktion|Kommission|Rat|Gericht|...
#   Confidence: 0.50
#
# - capitalized_multiword_fallback (priority 1, success: untested)
#   Format: regex
#   Pattern: \b([A-ZÄÖÜ][\wäöüÄÖÜß\.-]+(?:\s+[A-ZÄÖÜ][\wäöüÄÖÜß\.-]+){1,6})\b
#   Confidence: 0.50
#
# CONSIDER:
# - Refine existing high-performing rules
# - Fix or replace low-performing rules
# - Keep rules that work well
# - Add new rules for uncovered patterns
#
# YOUR TASK:
# Update and refine ruleset (max 10 rules) that:
# 1. Handles all corrections correctly (CRITICAL - these show failure modes)
# 2. Works on all examples
# 3. Respects user feedback
# 4. Is general and minimal (avoid redundant rules)
#
# RULES CAN BE:- Regex patterns (for structured extraction)
#
# IMPORTANT: You must ONLY use the allowed formats listed above. Do NOT generate rules in other formats.
# IMPORTANT: Do NOT include Python/code rules. Only return the listed formats.
# IMPORTANT: Do NOT include spaCy rules. Only return the listed formats.
#
# SCHEMA-AWARE RULES:
# For this task, rules must include an output_template that maps matches to the output schema.
#
# Output schema:
# entities: List[Entity]
#
# Entity:
#   text: string  # The matched text span
#   start: integer  # Start character offset
#   end: integer  # End character offset
#   type: string  # Entity label
#
# Each rule needs:
# - pattern: The regex pattern to match
# - output_template: JSON template for each match, using variables:
#   - $0: Full match text
#   - $start: Start character offset
#   - $end: End character offset
#   - $1, $2, ...: Capture groups (regex only)
# - output_key: Which output array to populate (e.g., "entities")
#
# Return JSON:
# {
#   "analysis": "What patterns did you find? What went wrong in corrections?",
#   "strategy": "Overall approach",
#   "note": "Every rule must include both output_template and output_key",
#   "rules": [
#     {
#       "name": "Short rule name",
#       "description": "What this rule does",
#       "format": "regex",
#       "pattern": "regex pattern",
#       "output_template": {"text": "$0", "start": "$start", "end": "$end", "type": "LITERAL_OR_$VAR"},
#       "output_key": "entities",
#       "priority": 1-10 (higher = more important),
#       "reasoning": "Why this rule is needed"
#     }
#   ]
# }
#
# NER RULE EXAMPLES (regex):
#
# Example 1 - Organizations with corporate suffixes:
# {
#   "name": "corporate_suffixes",
#   "format": "regex",
#   "pattern": "\b([A-Z][a-z]+(?:\s+[A-Z][a-z]+)*)\s+(Inc\.|LLC|Corp\.|Corporation)\b",
#   "output_template": {"text": "$0", "start": "$start", "end": "$end", "type": "ORG"},
#   "output_key": "entities",
#   "priority": 9
# }
#
# Focus on learning from CORRECTIONS - they show exactly what went wrong!
#
# IMPORTANT: Return ONLY valid JSON. Ensure:
# - All strings use double quotes and are properly escaped
# - All braces and brackets are balanced
# - No trailing commas
# - Response is complete (not truncated)
#
# 📚 Synthesizing rules from dataset...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 7
#       1 rule_learner = RuleChefLearner(
#       2     model="gpt-5-mini-2025-08-07",
#       3     dataset="ler",
#       4     allowed_classes="ORG",
#       5     rule_file="gpt5-mini_ORG_negative",
#       6 )
# ----> 7 rule_learner.fit(sampled, negative)
#
# File ~/CLEAR-anonymization/clear_anonymization/models/rulelearner.py:101, in RuleChefLearner.fit(self, samples, negative_samples)
#      95     for negative_sample in negative_samples:
#      96         self.chef.add_negative_example(
#      97             {"text": negative_sample["text"]},
#      98             {"entities": negative_sample["entities"]},
#      99         )
# --> 101 self.chef.learn_rules()
#
# File ~/rulechef/rulechef/engine.py:311, in RuleChef.learn_rules(self, run_evaluation, min_examples, max_refinement_iterations, sampling_strategy, incremental_only)
#     307     rules = self._merge_rules(self.dataset.rules, patch_rules)
#     308     # Run evaluate/refine on merged set
#     309 else:
#     310     # Synthesize initial ruleset
# --> 311     rules = self.learner.synthesize_ruleset(self.dataset)
#     313     if not rules:
#     314         print("Failed to synthesize rules")
#
# File ~/rulechef/rulechef/learner.py:69, in RuleLearner.synthesize_ruleset(self, dataset, max_rules)
#      66 start = time.time()
#      68 try:
# ---> 69     response = self.llm.chat.completions.create(
#      70         model=self.model,
#      71         max_completion_tokens=8192,
#      72         messages=[{"role": "user", "content": prompt}],
#      73         response_format={"type": "json_object"},
#      74     )
#      76     result = self._parse_json(response.choices[0].message.content)
#      77     rules = self._parse_rules_from_response(result, max_rules, dataset)
#
# File ~/CLEAR-anonymization/clearvenv/lib/python3.12/site-packages/openai/_utils/_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File ~/CLEAR-anonymization/clearvenv/lib/python3.12/site-packages/openai/resources/chat/completions/completions.py:1189, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1142 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1143 def create(
#    1144     self,
#    (...)   1186     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1187 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1188     validate_response_format(response_format)
# -> 1189     return self._post(
#    1190         "/chat/completions",
#    1191         body=maybe_transform(
#    1192             {
#    1193                 "messages": messages,
#    1194                 "model": model,
#    1195                 "audio": audio,
#    1196                 "frequency_penalty": frequency_penalty,
#    1197                 "function_call": function_call,
#    1198                 "functions": functions,
#    1199                 "logit_bias": logit_bias,
#    1200                 "logprobs": logprobs,
#    1201                 "max_completion_tokens": max_completion_tokens,
#    1202                 "max_tokens": max_tokens,
#    1203                 "metadata": metadata,
#    1204                 "modalities": modalities,
#    1205                 "n": n,
#    1206                 "parallel_tool_calls": parallel_tool_calls,
#    1207                 "prediction": prediction,
#    1208                 "presence_penalty": presence_penalty,
#    1209                 "prompt_cache_key": prompt_cache_key,
#    1210                 "prompt_cache_retention": prompt_cache_retention,
#    1211                 "reasoning_effort": reasoning_effort,
#    1212                 "response_format": response_format,
#    1213                 "safety_identifier": safety_identifier,
#    1214                 "seed": seed,
#    1215                 "service_tier": service_tier,
#    1216                 "stop": stop,
#    1217                 "store": store,
#    1218                 "stream": stream,
#    1219                 "stream_options": stream_options,
#    1220                 "temperature": temperature,
#    1221                 "tool_choice": tool_choice,
#    1222                 "tools": tools,
#    1223                 "top_logprobs": top_logprobs,
#    1224                 "top_p": top_p,
#    1225                 "user": user,
#    1226                 "verbosity": verbosity,
#    1227                 "web_search_options": web_search_options,
#    1228             },
#    1229             completion_create_params.CompletionCreateParamsStreaming
#    1230             if stream
#    1231             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1232         ),
#    1233         options=make_request_options(
#    1234             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1235         ),
#    1236         cast_to=ChatCompletion,
#    1237         stream=stream or False,
#    1238         stream_cls=Stream[ChatCompletionChunk],
#    1239     )
#
# File ~/CLEAR-anonymization/clearvenv/lib/python3.12/site-packages/openai/_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/CLEAR-anonymization/clearvenv/lib/python3.12/site-packages/openai/_base_client.py:982, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#     980 response = None
#     981 try:
# --> 982     response = self._client.send(
#     983         request,
#     984         stream=stream or self._should_stream_response_body(request=request),
#     985         **kwargs,
#     986     )
#     987 except httpx.TimeoutException as err:
#     988     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~/CLEAR-anonymization/clearvenv/lib/python3.12/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/CLEAR-anonymization/clearvenv/lib/python3.12/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/CLEAR-anonymization/clearvenv/lib/python3.12/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/CLEAR-anonymization/clearvenv/lib/python3.12/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~/CLEAR-anonymization/clearvenv/lib/python3.12/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File ~/CLEAR-anonymization/clearvenv/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~/CLEAR-anonymization/clearvenv/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~/CLEAR-anonymization/clearvenv/lib/python3.12/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File ~/CLEAR-anonymization/clearvenv/lib/python3.12/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File ~/CLEAR-anonymization/clearvenv/lib/python3.12/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File ~/CLEAR-anonymization/clearvenv/lib/python3.12/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File ~/CLEAR-anonymization/clearvenv/lib/python3.12/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/CLEAR-anonymization/clearvenv/lib/python3.12/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File ~/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/ssl.py:1232, in SSLSocket.recv(self, buflen, flags)
#    1228     if flags != 0:
#    1229         raise ValueError(
#    1230             "non-zero flags not allowed in calls to recv() on %s" %
#    1231             self.__class__)
# -> 1232     return self.read(buflen)
#    1233 else:
#    1234     return super().recv(buflen, flags)
#
# File ~/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/ssl.py:1105, in SSLSocket.read(self, len, buffer)
#    1103         return self._sslobj.read(len, buffer)
#    1104     else:
# -> 1105         return self._sslobj.read(len)
#    1106 except SSLError as x:
#    1107     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
rules_file = Path("./rulechef_data/gpt5-mini_ORG_negative.json")
rules_data = json.loads(rules_file.read_text())

rules = [Rule.from_dict(r) for r in rules_data.get("rules")]
for rule in rules:
    print(rule.description)
    print(rule.content)
    print("####################")
# Out:
# Match ministries, federal/state authorities and similar institutional names containing strong keywords (Bundesministerium, Ministerium für, Bundesamt, Landesamt, Behörde, Senatsverwaltung, Bundeskanzleramt, Veterinärdienst, Staatsministerium, Regierungspräsidium, Polizei). Captures surrounding multi-word names with commas/slashes/parentheses.
# \b[A-ZÄÖÜ][A-Za-zäöüÄÖÜß\.,\-/\s\(\)"']{0,200}?(?:Bundesministerium|Ministerium\s+für|Ministerium|Bundesamt|Landesamt|Behörde|Senatsverwaltung|Bundeskanzleramt|Veterinärdienst|Staatsministerium|Regierungspräsidium|Polizei)[A-Za-zäöüÄÖÜß\.,\-/\s\(\)"']{0,80}
# ####################
# Match company names that include common German corporate suffixes (GmbH, GmbH & Co. KG, AG, e.V., eV, KG, OHG, UG), capturing preceding capitalized name tokens.
# \b([A-ZÄÖÜ][\wäöüÄÖÜß\.-]*(?:\s+[A-ZÄÖÜ][\wäöüÄÖÜß\.-]*){0,6})\s+(GmbH|GmbH\s*&\s*Co\.\s*KG|AG|e\.V\.|eV|KG|OHG|UG)\b
# ####################
# Match universities, institutes, faculties, centers, foundations, clinics and similar research/education/medical organizations by looking for these keywords and capturing surrounding name context.
# \b[A-ZÄÖÜ][A-Za-zäöüÄÖÜß\.\-\/\s]{0,80}?(?:Universität|Universitaet|Hochschule|Institut|Fakultät|Zentrum|Stiftung|Klinikum|Klinik|Bibliothek|Archiv|Lehrstuhl)\b[A-Za-zäöüÄÖÜß\.,\-/\s]{0,40}
# ####################
# Match common German political parties and coalition names (Bündnis 90/Die Grünen, Die Linke, SPD, CDU, CSU, FDP, AfD) including optional variants.
# \b(Bündnis(?:\s*90)?\s*\/?\s*Die\s+Grünen|Die\s+Linke|SPD|CDU|CSU|FDP|AfD)\b
# ####################
# Match multi-word names that contain strong organization keywords such as Gesellschaft, Verein, Partei, Fraktion, Kommission, Rat, Gericht, Konferenz, Verband, Verwaltung. This is broader but still keyword-anchored.
# \b[A-ZÄÖÜ][A-Za-zäöüÄÖÜß\.-/\s]{0,80}?(?:Gesellschaft|Verein|Partei|Fraktion|Kommission|Rat|Gericht|Konferenz|Stiftung|Behörde|Verband|Verwaltung)\b
# ####################
# Fallback: capture multi-word sequences of capitalized tokens (at least two) as possible organization names. Lower priority to reduce false positives; avoids single-token acronyms and short capitalized words.
# \b([A-ZÄÖÜ][\wäöüÄÖÜß\.-]+(?:\s+[A-ZÄÖÜ][\wäöüÄÖÜß\.-]+){1,6})\b
# ####################

# %%
rules = [Rule.from_dict(r) for r in rules_data.get("rules")]
# print(rules)

RuleChefExtractor = factory.make_extractor(
    "rulechef",
    dataset="ler",
    rules=rules,
)

print(RuleChefExtractor.predict({"text": "Nadia arbeitet beim AG GmbH."}))
# Out:
# {'entities': [{'text': 'AG GmbH', 'start': 20, 'end': 27, 'type': 'ORG'}]}

# %%
for rule in rules:
    print(rule.description)
    print(rule.content)
    print("####################")
# Out:
# Match long 'Bundesministerium für ...' official names (e.g., 'Bundesministerium für Verbraucherschutz, Ernährung und Landwirtschaft'). Captures sequences of capitalized components, commas and 'und' following 'für'.
# \bBundesministerium\s+f(?:ü|ue)r(?:\s*,?\s*(?:[A-ZÄÖÜ][A-Za-zäöüÄÖÜß\-]*|und|&|,))+
# ####################
# Match German phrases for the European Court of Human Rights (various grammatical forms: 'Europäischen Gerichtshofs für Menschenrechte', 'Europäischer Gerichtshof für Menschenrechte').
# \bEurop(?:ä|ae)ischen\s+Gerichtshofs\s+f(?:ü|ue)r\s+Menschenrechte\b|\bEurop(?:ä|ae)ischer\s+Gerichtshof\s+f(?:ü|ue)r\s+Menschenrechte\b
# ####################
# Match 'Markenstelle für Klasse <num> des Deutschen Patent- und Markenamts' and similar full phrases including optional class numbers.
# \bMarkenstelle\s+f(?:ü|ue)r(?:\s+Klasse\s+\d+)?\s+des\s+Deutschen\s+Patent-?\s*und\s*Markenamts\b
# ####################
# Match frequent single-token or tightly hyphenated German institutional names (e.g., 'Bundesgerichtshof', 'Patent- und Markenamt', 'Markenamt').
# \b(?:Bundesgerichtshof|Patent-?\s*und\s*Markenamt|Markenamt)\b
# ####################
# Match uppercase abbreviations only when they appear inside parentheses (e.g., '(BSG)'). This avoids capturing standalone uppercase tokens outside parentheses.
# (?<=\()\s*\b[A-ZÄÖÜ]{2,6}\b(?=\s*(?:,|\)))
# ####################

# %%
print_rule_result(rules[0], "Nadia arbeitet beim Bundesverfassungsgericht.")
# Out:
# RULE
# (?<!\S)\b(?:Bundesministerium|Ministerium|Bundesgerichtshof|Bundesverfassungsgericht|Gerichtshof|Markenstelle|Patent(?:\s*-\s*und\s*Markenamt|\s*und\s*Markenamt|(?:-?\s*Markenamts?)?)|Patent-\s*und\s*Markenamt)\b(?:(?:[\s,:\.\-\u2013\u2014]+(?:für|der|des|und|von|zu|am|im|dem|die|den|Klasse|\d+|[A-ZÄÖÜ][\wäöüßÄÖÜ-]*)))*\b(?!\s+und\s+[a-zäöüß])
# regex.Regex('(?<!\\S)\\b(?:Bundesministerium|Ministerium|Bundesgerichtshof|Bundesverfassungsgericht|Gerichtshof|Markenstelle|Patent(?:\\s*-\\s*und\\s*Markenamt|\\s*und\\s*Markenamt|(?:-?\\s*Markenamts?)?)|Patent-\\s*und\\s*Markenamt)\\b(?:(?:[\\s,:\\.\\-\\u2013\\u2014]+(?:für|der|des|und|von|zu|am|im|dem|die|den|Klasse|\\d+|[A-ZÄÖÜ][\\wäöüßÄÖÜ-]*)))*\\b(?!\\s+und\\s+[a-zäöüß])', flags=regex.V0)
# ######
# RESULT
# Bundesverfassungsgericht
# Bundesverfassungsgericht
# -----------------------

# %%
print_rule_result(rules[1], "Nadia arbeitet beim 1. Zivilkammer")
# DOES NOT FIND IT

print_rule_result(rules[1], "Nadia arbeitet beim 1. Zivilkammer des Landesgerichtswien")
# Out:
# RULE
# (?<!\b(?:des|der|dem|den)\s)\b[A-ZÄÖÜ][\wäöüßÄÖÜ-]*(?:\s+[A-ZÄÖÜ][\wäöüßÄÖÜ-]*)?\s+(?:Gerichtshofs?|Gericht|Ministerium|Ministeriums?|Amt|Behörde|Dienst|Stelle|Zentrum|Institut|Universit(?:ät)|Agentur|Kammer|Senat|Rat|Anstalt|Abteilung)\b(?:(?:[\s,:\.\-\u2013\u2014]+(?:für|der|des|und|von|zu|am|im|dem|die|den|Klasse|\d+|[A-ZÄÖÜ][\wäöüßÄÖÜ-]*)))*\b(?!\s+und\s+[a-zäöüß])
# regex.Regex('(?<!\\b(?:des|der|dem|den)\\s)\\b[A-ZÄÖÜ][\\wäöüßÄÖÜ-]*(?:\\s+[A-ZÄÖÜ][\\wäöüßÄÖÜ-]*)?\\s+(?:Gerichtshofs?|Gericht|Ministerium|Ministeriums?|Amt|Behörde|Dienst|Stelle|Zentrum|Institut|Universit(?:ät)|Agentur|Kammer|Senat|Rat|Anstalt|Abteilung)\\b(?:(?:[\\s,:\\.\\-\\u2013\\u2014]+(?:für|der|des|und|von|zu|am|im|dem|die|den|Klasse|\\d+|[A-ZÄÖÜ][\\wäöüßÄÖÜ-]*)))*\\b(?!\\s+und\\s+[a-zäöüß])', flags=regex.V0)
# ######
# RESULT
# -----------------------
# RULE
# (?<!\b(?:des|der|dem|den)\s)\b[A-ZÄÖÜ][\wäöüßÄÖÜ-]*(?:\s+[A-ZÄÖÜ][\wäöüßÄÖÜ-]*)?\s+(?:Gerichtshofs?|Gericht|Ministerium|Ministeriums?|Amt|Behörde|Dienst|Stelle|Zentrum|Institut|Universit(?:ät)|Agentur|Kammer|Senat|Rat|Anstalt|Abteilung)\b(?:(?:[\s,:\.\-\u2013\u2014]+(?:für|der|des|und|von|zu|am|im|dem|die|den|Klasse|\d+|[A-ZÄÖÜ][\wäöüßÄÖÜ-]*)))*\b(?!\s+und\s+[a-zäöüß])
# regex.Regex('(?<!\\b(?:des|der|dem|den)\\s)\\b[A-ZÄÖÜ][\\wäöüßÄÖÜ-]*(?:\\s+[A-ZÄÖÜ][\\wäöüßÄÖÜ-]*)?\\s+(?:Gerichtshofs?|Gericht|Ministerium|Ministeriums?|Amt|Behörde|Dienst|Stelle|Zentrum|Institut|Universit(?:ät)|Agentur|Kammer|Senat|Rat|Anstalt|Abteilung)\\b(?:(?:[\\s,:\\.\\-\\u2013\\u2014]+(?:für|der|des|und|von|zu|am|im|dem|die|den|Klasse|\\d+|[A-ZÄÖÜ][\\wäöüßÄÖÜ-]*)))*\\b(?!\\s+und\\s+[a-zäöüß])', flags=regex.V0)
# ######
# RESULT
# -----------------------

# %%
print_rule_result(rules[3], "Beim FA habe ich mich beworben")
# Out:
# RULE
# \b[A-ZÄÖÜ][\wäöüßÄÖÜ-]*(?:\s+[A-ZÄÖÜ][\wäöüßÄÖÜ-]*)*\s+(?:GmbH|AG|KG|OHG|UG|e\.V\.)\b
# regex.Regex('\\b[A-ZÄÖÜ][\\wäöüßÄÖÜ-]*(?:\\s+[A-ZÄÖÜ][\\wäöüßÄÖÜ-]*)*\\s+(?:GmbH|AG|KG|OHG|UG|e\\.V\\.)\\b', flags=regex.V0)
# ######
# RESULT
# -----------------------

# %%
print_rule_result(rules[4], "Nadia hat sich beim AG GmbH beworben")

# %%
print_rule_result(rules[5], "Ich arbeite beim Finanzgericht")

# %%
print_rule_result(rules[6], "ich studiere an der TU Hochschule")
