# %%
import random
from pathlib import Path

import regex as re
from rulechef import Rule, RuleChef, Task, TaskType
from rulechef.core import RuleFormat
from rulechef.executor import RuleExecutor

from clear_anonymization.extractors import factory
from clear_anonymization.extractors.base import BaseExtractor
from clear_anonymization.extractors.ruleextractor import RuleExtractor
from clear_anonymization.models.rulelearner import RuleChefLearner
from clear_anonymization.ner_datasets.ner_dataset import NERData, NERSample

# %%
def sample_data(samples, allowed_classes, k=6, seed=12):
    random.seed(seed)
    relevant_samples = []
    negative_samples = []
    for sample in samples:
        relevant_spans = []
        negative_spans = []

        for label in sample.labels:
            if label["class"] in allowed_classes:
                relevant_spans.append(
                    {
                        "text": label["text"],
                        "start": label["start"],
                        "end": label["end"],
                        "type": label["class"],
                    }
                )
            else:
                negative_spans.append(
                    {
                        "text": label["text"],
                        "start": label["start"],
                        "end": label["end"],
                        "type": label["class"],
                    }
                )

        if relevant_spans:
            relevant_samples.append(
                {
                    "text": sample.text,
                    "entities": list(relevant_spans),
                }
            )
        if negative_spans:
            negative_samples.append(
                {
                    "text": sample.text,
                    "entities": list(negative_spans),
                }
            )

    k = min(k, len(relevant_samples))

    return relevant_samples, random.sample(negative_samples, 6)

# %%
def print_rule_result(rule):
    print("CONTENT", rule.description)
    pattern = re.compile(rule.content)
    print(pattern)

# %%
# Data from the Ler dataset
input_dir = Path("data/ler/ler_data.json")
data = NERData.from_json(json.loads(input_dir.read_text()))
train_samples = [s for s in data.samples if s.split == "train"]

test_samples = [s for s in data.samples if s.split == "validation"]

sampled, negative = sample_data(train_samples, "ORG")

# %%
# My Examples

# positive Examples
positive_examples = [
    {
        "text": "Frau Müller arbeitet beim Bundesverfassungsgericht in Wien.",
        "entities": [
            {"text": "Bundesverfassungsgericht", "start": 26, "end": 50, "type": "ORG"}
        ],
    },
    {
        "text": "Nadia studiert an der Technische Universität Wien.",
        "entities": [
            {
                "text": "Technische Universität Wien",
                "start": 22,
                "end": 49,
                "type": "ORG",
            }
        ],
    },
    {
        "text": "Im Juli 2009 gründete der Angeklagte den Verein „ Neudeutschland “ mit ihm als „ unabwählbarem “ ersten Vorstand.",
        "entities": [
            {"text": "Verein „ Neudeutschland “", "start": 41, "end": 66, "type": "ORG"}
        ],
    },
]

# Negative Examples

negative_examples = [
    {
        "text": "Herr Rules kommt heute besuchen in Berlin.",
        "entities": [
            {"text": "Herr Rules", "start": 0, "end": 10, "type": "PER"},
            {"text": "Berlin", "start": 35, "end": 41, "type": "LOC"},
        ],
    },
]

# %% [markdown]
# #### Manual rules

# %%
from datetime import date

rules_manual = [
    {
        "id": "m1",
        "name": "german_corporate_suffix",
        "description": "matches german corporate suffix",
        "format": RuleFormat.REGEX,
        "content": "\\b([A-Z][a-z0-9]+(?:\\s+[A-Z][a-z]+)*)\\s+(AG|GmbH|KG|UG|OHG|Gbr)\\b",
        "priority": 5,
        "confidence": 0.5,
        "times_applied": 0,
        "successes": 0,
        "failures": 0,
        "created_at": date.fromisoformat("2026-01-29"),
    },
    {
        "id": "m2",
        "name": "university_clubs",
        "description": "matches university names",
        "format": RuleFormat.REGEX,
        "content": "\\b(?:[A-ZÄÖÜa-zäöü0-9]+\\s+)?(Universität|Fachhochschule|Uni|Verein|Partei)(?:\\s+[A-ZÄÖÜ][a-zäöüA-ZÄÖÜ]+)*\\b",
        "priority": 5,
        "confidence": 0.5,
        "times_applied": 0,
        "successes": 0,
        "failures": 0,
        "created_at": date.fromisoformat("2026-01-29"),
    },
    {
        "id": "m2",
        "name": "gerichte",
        "description": "court_names",
        "format": RuleFormat.REGEX,
        "content": "\\b[A-ZÄÖÜ][a-zäöüA-ZÄÖÜ]+gericht(?:\\s+[A-ZÄÖÜ][a-zäöüA-ZÄÖÜ]+)*\\b",
        "priority": 5,
        "confidence": 0.5,
        "times_applied": 0,
        "successes": 0,
        "failures": 0,
        "created_at": date.fromisoformat("2026-01-29"),
    },
]

with open("./rulechef_data/ORG_manual_rules.json", "w", encoding="utf-8") as f:
    json.dump(
        [Rule(**r).to_dict() for r in rules_manual],
        f,
        indent=2,
        ensure_ascii=False,
        default=str,
    )

# %% [markdown]
# #### Added negative examples, plus instructions not to follow those examples.

# %%
rule_learner = RuleChefLearner(
    model="gpt-5-mini-2025-08-07",
    dataset="ler",
    allowed_classes="ORG",
    rule_file="2025-02-02_ORG_ler_myexamp",
    lang="de",
)
rule_learner.fit(positive_examples, negative_examples)
# Out:
# {'NRM', 'LIT', 'PERS', 'REG', 'ORG', 'LOC', 'RS'}
# ✓ Added example (buffer: 1 new, 1 total)
# ✓ Added example (buffer: 2 new, 2 total)
# ✓ Added example (buffer: 3 new, 3 total)
# ✗ Added negative example (buffer: 4 new, 4 total)
#
# 📥 Converting 4 buffered examples to dataset...
#    (0 corrections, 0 LLM, 4 human)
# ✓ Converted to dataset: 0 corrections, 4 examples
#
# ============================================================
# Learning rules from 4 training items
#   Corrections: 0 (high value)
#   Examples: 4
#   Mode: Synthesis + Refinement (max 3 iterations)
# ============================================================
#
# de
# NEW PROMPT Task: Named Entity Recognition
# Description: Extract ORG: Organisationsnamen (Parteien, Vereine, Institutionen, Unternehmen) from German text
# Input schema: {'text': 'str'}
# Output schema:
# entities: List[Entity]
#
# Entity:
#   text: string  # The matched text span
#   start: integer  # Start character offset
#   end: integer  # End character offset
#   type: string  # Entity label
#
# TRAINING EXAMPLES (3 shown):
# - Learn rules from these examples:
#
# Input: {"text": "Frau M\u00fcller arbeitet beim Bundesverfassungsgericht in Wien."}
# Output: {"entities": [{"text": "Bundesverfassungsgericht", "start": 26, "end": 50, "type": "ORG"}]}
#
# Input: {"text": "Nadia studiert an der Technische Universit\u00e4t Wien."}
# Output: {"entities": [{"text": "Technische Universit\u00e4t Wien", "start": 22, "end": 49, "type": "ORG"}]}
#
# Input: {"text": "Im Juli 2009 gr\u00fcndete der Angeklagte den Verein \u201e Neudeutschland \u201c mit ihm als \u201e unabw\u00e4hlbarem \u201c ersten Vorstand."}
# Output: {"entities": [{"text": "Verein \u201e Neudeutschland \u201c", "start": 41, "end": 66, "type": "ORG"}]}
# NEGATIVE TRAINING EXAMPLES (1 shown):
# - Some  TEXT SPANS may look similar to organizations but are NOT organizations.
# - You MUST NOT generate rules that extract such TEXT SPANS as ORG.
#
# Input: {"text": "Herr Rules kommt heute besuchen in Berlin."}
# Output: {"entities": [{"text": "Herr Rules", "start": 0, "end": 10, "type": "PER"}, {"text": "Berlin", "start": 35, "end": 41, "type": "LOC"}]}
#
# YOUR TASK:
# Synthesize a complete ruleset (max 10 rules) that:
# 1. Rely only on the data provided
# 2. Handles all corrections correctly (CRITICAL - these show failure modes)
# 3. Works on all examples
# 4. Respects user feedback
# 5. Is general and minimal (avoid redundant rules)
#
# RULES CAN BE:- Regex patterns (for structured extraction)
#
# IMPORTANT: You must ONLY use the allowed formats listed above. Do NOT generate rules in other formats.
# IMPORTANT: Do NOT include Python/code rules. Only return the listed formats.
# IMPORTANT: Do NOT include spaCy rules. Only return the listed formats.
#
# SCHEMA-AWARE RULES:
# For this task, rules must include an output_template that maps matches to the output schema.
#
# Output schema:
# entities: List[Entity]
#
# Entity:
#   text: string  # The matched text span
#   start: integer  # Start character offset
#   end: integer  # End character offset
#   type: string  # Entity label
#
# Each rule needs:
# - pattern: The regex pattern to match
# - output_template: JSON template for each match, using variables:
#   - $0: Full match text
#   - $start: Start character offset
#   - $end: End character offset
#   - $1, $2, ...: Capture groups (regex only)
# - output_key: Which output array to populate (e.g., "entities")
#
# Return JSON:
# {
#   "analysis": "What patterns did you find? What went wrong in corrections?",
#   "strategy": "Overall approach",
#   "note": "Every rule must include both output_template and output_key",
#   "rules": [
#     {
#       "name": "Short rule name",
#       "description": "What this rule does",
#       "format": "regex",
#       "pattern": "regex pattern",
#       "output_template": {"text": "$0", "start": "$start", "end": "$end", "type": "LITERAL_OR_$VAR"},
#       "output_key": "entities",
#       "priority": 1-10 (higher = more important),
#       "reasoning": "Why this rule is needed"
#     }
#   ]
# }
#
# NER RULE EXAMPLES (regex):
#
#
# Example 1 - Organizations with corporate suffixes:
# {
#   "name": "corporate_suffixes",
#   "format": "regex",
#   "pattern": "\b([A-Z][a-z0-9]+(?:\s+[A-Z][a-z]+)*)\s+(AG|GmbH|KG|UG|OHG|Gbr)\b",
#   "output_template": {"text": "$0", "start": "$start", "end": "$end", "type": "ORG"},
#   "output_key": "entities",
#   "priority": 9
# }
#
# Focus on learning from CORRECTIONS - they show exactly what went wrong!
#
# IMPORTANT: Return ONLY valid JSON. Ensure:
# - All strings use double quotes and are properly escaped
# - All braces and brackets are balanced
# - No trailing commas
# - Response is complete (not truncated)
#
# 📚 Synthesizing rules from dataset...
#       Validation error: bad character range \w-" at position 165
#    ⚠ Skipped invalid rule: explicit_org_keywords
# ✓ Synthesized 4 rules (60.0s)
# ✓ Generated 4 rules
#
# 🔄 Refinement loop (max 3 iterations)
# [1/3] Evaluating rules...
# [1/3] Accuracy: 50.0% (2/4)
# [1/3] Refining based on 2 failures...
# de
# [1/3] Refined 7 rules (64.2s)
# [2/3] Evaluating rules...
# [2/3] Accuracy: 75.0% (3/4)
# [2/3] Refining based on 1 failures...
# de
# [2/3] Refined 9 rules (48.2s)
# [3/3] Evaluating rules...
# [3/3] Accuracy: 50.0% (2/4)
# [3/3] Refining based on 2 failures...
# de
# [3/3] Refined 7 rules (52.8s)
#
# ============================================================
# Learning complete! (225.2s)
#   Rules: 7
#   Accuracy: 75.0% (3/4)
# ============================================================

# %%
rules_file = Path("./rulechef_data/2025-02-02_ORG_ler_myexamp.json")
rules_data = json.loads(rules_file.read_text())

rules = [Rule.from_dict(r) for r in rules_data.get("rules")]
for rule in rules:
    print_rule_result(rule)
    print("###########")
# Out:
# CONTENT Match companies that use standard corporate suffixes (GmbH, AG, KG, UG, OHG, Gbr, e.V., GmbH & Co. KG, etc.). High precision to avoid person-name false positives.
# regex.Regex('\\b[A-ZÄÖÜ][\\wäöüÄÖÜß-]*(?:\\s+[A-ZÄÖÜ][\\wäöüÄÖÜß-]*)*\\s+(?:GmbH(?:\\s*&\\s*Co\\.\\s*KG)?|AG|KG|UG|OHG|Gbr|e\\.V\\.?|eV)\\b', flags=regex.V0)
# ###########
# CONTENT Match named courts and judicial bodies, including concatenated German compounds like Bundesverfassungsgericht.
# regex.Regex('\\b(?:Bundesverfassungsgericht|Verfassungsgerichtshof|Bundesgerichtshof|Bundesgericht|Landesgericht|Amtsgericht|Verwaltungsgericht|Finanzgericht|Arbeitsgericht|Sozialgericht|Gericht)\\b', flags=regex.V0)
# ###########
# CONTENT Match universities and related institutional names containing 'Universität' or 'University' with up to a few surrounding capitalized tokens.
# regex.Regex('\\b(?:[A-ZÄÖÜ][\\wäöüÄÖÜß-]*(?:\\s+[A-ZÄÖÜ][\\wäöüÄÖÜß-]*){0,3}\\s+)?Universit(?:ät|y)(?:\\s+[A-ZÄÖÜ][\\wäöüÄÖÜß-]*){0,3}\\b', flags=regex.V0)
# ###########
# CONTENT Match ministries, offices and public authorities (Ministerium, Amt, Behörde, Senat, plus concatenated tokens like Bundeskanzleramt).
# regex.Regex('\\b(?:Bundeskanzleramt|Bundesministerium(?:\\s+[A-ZÄÖÜ][\\wäöüÄÖÜß-]*)*|Landesministerium(?:\\s+[A-ZÄÖÜ][\\wäöüÄÖÜß-]*)*|Ministerium|Senat|Behörde|Amt|Bezirksamt)\\b', flags=regex.V0)
# ###########
# CONTENT Match Verein with either a quoted name or a following capitalized multiword name (e.g., Verein "Die Guten", Verein Deutscher ...).
# regex.Regex('\\bVerein\\b(?:\\s+(?:["\'“„«»][^"\'“„«»]+["\'“„«»]|[A-ZÄÖÜ][\\wäöüÄÖÜß-]*(?:\\s+[A-ZÄÖÜ][\\wäöüÄÖÜß-]*)*))', flags=regex.V0)
# ###########
# CONTENT Match organizations that end with common organizational suffixes (Verband, Stiftung, Institut, Partei, Kammer, Union, Konzern).
# regex.Regex('\\b[A-ZÄÖÜ][\\wäöüÄÖÜß-]*(?:\\s+[A-ZÄÖÜ][\\wäöüÄÖÜß-]*)*\\s+(?:Verband|Stiftung|Institut|Partei|Konzern|Kammer|Union|Organisation)\\b', flags=regex.V0)
# ###########
# CONTENT Match multi-letter acronyms in all caps as organizations (e.g., EU, UNO, NATO, BKA). Requires at least two uppercase letters to reduce false positives.
# regex.Regex('\\b[A-ZÄÖÜ]{2,}(?:\\/[A-ZÄÖÜ]{2,})?\\b', flags=regex.V0)
# ###########

# %%
def predict(rules, text):
    RuleChefExtractor = factory.make_extractor(
        "rulechef",
        dataset="ler",
        rules=rules,
    )
    print(RuleChefExtractor.predict({"text": text}))

# %%
predict(
    rules,
    "Frau Müller kommt jetzt. Sie geht heute zum Bundesgericht Öst. Nadia studiert an der Technische Universität Wien.",
)
# Out:
# {'entities': [{'text': 'Bundesgericht', 'start': 44, 'end': 57, 'type': 'ORG'}, {'text': 'Technische Universität Wien', 'start': 85, 'end': 112, 'type': 'ORG'}]}

# %%
predict(rules, "UNO City befindet sich in der Nähe von Donauzentrum.")
# Out:
# {'entities': [{'text': 'UNO', 'start': 0, 'end': 3, 'type': 'ORG'}]}

# %%
predict(rules, "Max M ist Teil dieser Tierschutz Organisation.")
# Out:
# {'entities': [{'text': 'Tierschutz Organisation', 'start': 22, 'end': 45, 'type': 'ORG'}]}

# %%
predict(rules, "Anna studiert an der Universität Wien.")
# Out:
# {'entities': [{'text': 'Universität Wien', 'start': 21, 'end': 37, 'type': 'ORG'}]}

# %%
predict(rules, "Mn GmbH hat eine grosse Spende für Kinder in Not geleistet.")
# Out:
# {'entities': [{'text': 'Mn GmbH', 'start': 0, 'end': 7, 'type': 'ORG'}]}

# %%
predict(
    rules, "XX GmbH hat eine grosse Spende für Kinder in Not geleistet."
)  ## XX considered also as a separate ORG
# Out:
# {'entities': [{'text': 'XX GmbH', 'start': 0, 'end': 7, 'type': 'ORG'}, {'text': 'XX', 'start': 0, 'end': 2, 'type': 'ORG'}]}

# %% [markdown]
# #### Added xml tags such as <negative>, <positive> for clearer instructions

# %%
rule_learner = RuleChefLearner(
    model="gpt-5-mini-2025-08-07",
    dataset="ler",
    allowed_classes="ORG",
    rule_file="2025-02-02_ORG_ler_myexamp_v2",
    lang="de",
)
rule_learner.fit(positive_examples, negative_examples)
# Out:
# {'REG', 'ORG', 'LOC', 'RS', 'PERS', 'NRM', 'LIT'}
# ✓ Added example (buffer: 1 new, 1 total)
# ✓ Added example (buffer: 2 new, 2 total)
# ✓ Added example (buffer: 3 new, 3 total)
# ✗ Added negative example (buffer: 4 new, 4 total)
#
# 📥 Converting 4 buffered examples to dataset...
#    (0 corrections, 0 LLM, 4 human)
# ✓ Converted to dataset: 0 corrections, 4 examples
#
# ============================================================
# Learning rules from 4 training items
#   Corrections: 0 (high value)
#   Examples: 4
#   Mode: Synthesis + Refinement (max 3 iterations)
# ============================================================
#
# de
# NEW PROMPT Task: Named Entity Recognition
# Description: Extract ORG: Organisationsnamen (Parteien, Vereine, Institutionen, Unternehmen) from German text
# Input schema: {'text': 'str'}
# Output schema:
# entities: List[Entity]
#
# Entity:
#   text: string  # The matched text span
#   start: integer  # Start character offset
#   end: integer  # End character offset
#   type: string  # Entity label
#
# TRAINING EXAMPLES (3 shown):
# - Learn rules from the <positive>...</positive> examples:
# <positive>
#
# Input: {"text": "Frau M\u00fcller arbeitet beim Bundesverfassungsgericht in Wien."}
# Output: {"entities": [{"text": "Bundesverfassungsgericht", "start": 26, "end": 50, "type": "ORG"}]}
#
# Input: {"text": "Nadia studiert an der Technische Universit\u00e4t Wien."}
# Output: {"entities": [{"text": "Technische Universit\u00e4t Wien", "start": 22, "end": 49, "type": "ORG"}]}
#
# Input: {"text": "Im Juli 2009 gr\u00fcndete der Angeklagte den Verein \u201e Neudeutschland \u201c mit ihm als \u201e unabw\u00e4hlbarem \u201c ersten Vorstand."}
# Output: {"entities": [{"text": "Verein \u201e Neudeutschland \u201c", "start": 41, "end": 66, "type": "ORG"}]}
# </positive>
# NEGATIVE TRAINING EXAMPLES (1 shown):
# - Some TEXT SPANS in <negative>..</negative> may look similar to organizations but are NOT organizations.
# - You MUST NOT generate rules that extract such TEXT SPANS in <negative>..</negative> as ORG.
# <negative>
#
# Input: {"text": "Herr Rules kommt heute besuchen in Berlin."}
# Output: {"entities": [{"text": "Herr Rules", "start": 0, "end": 10, "type": "PER"}, {"text": "Berlin", "start": 35, "end": 41, "type": "LOC"}]}
# </negative>
#
# YOUR TASK:
# Synthesize a complete ruleset (max 10 rules) that:
# 1. Rely only on the data provided
# 2. Handles all corrections correctly (CRITICAL - these show failure modes)
# 3. Works on all examples
# 4. Respects user feedback
# 5. Is general and minimal (avoid redundant rules)
#
# RULES CAN BE:- Regex patterns (for structured extraction)
#
# IMPORTANT: You must ONLY use the allowed formats listed above. Do NOT generate rules in other formats.
# IMPORTANT: Do NOT include Python/code rules. Only return the listed formats.
# IMPORTANT: Do NOT include spaCy rules. Only return the listed formats.
#
# SCHEMA-AWARE RULES:
# For this task, rules must include an output_template that maps matches to the output schema.
#
# Output schema:
# entities: List[Entity]
#
# Entity:
#   text: string  # The matched text span
#   start: integer  # Start character offset
#   end: integer  # End character offset
#   type: string  # Entity label
#
# Each rule needs:
# - pattern: The regex pattern to match
# - output_template: JSON template for each match, using variables:
#   - $0: Full match text
#   - $start: Start character offset
#   - $end: End character offset
#   - $1, $2, ...: Capture groups (regex only)
# - output_key: Which output array to populate (e.g., "entities")
#
# Return JSON:
# {
#   "analysis": "What patterns did you find? What went wrong in corrections?",
#   "strategy": "Overall approach",
#   "note": "Every rule must include both output_template and output_key",
#   "rules": [
#     {
#       "name": "Short rule name",
#       "description": "What this rule does",
#       "format": "regex",
#       "pattern": "regex pattern",
#       "output_template": {"text": "$0", "start": "$start", "end": "$end", "type": "LITERAL_OR_$VAR"},
#       "output_key": "entities",
#       "priority": 1-10 (higher = more important),
#       "reasoning": "Why this rule is needed"
#     }
#   ]
# }
#
# NER RULE EXAMPLES (regex):
#
#
# Example 1 - Organizations with corporate suffixes:
# {
#   "name": "corporate_suffixes",
#   "format": "regex",
#   "pattern": "\b([A-Z][a-z0-9]+(?:\s+[A-Z][a-z]+)*)\s+(AG|GmbH|KG|UG|OHG|Gbr)\b",
#   "output_template": {"text": "$0", "start": "$start", "end": "$end", "type": "ORG"},
#   "output_key": "entities",
#   "priority": 9
# }
#
# Focus on learning from CORRECTIONS - they show exactly what went wrong!
#
# IMPORTANT: Return ONLY valid JSON. Ensure:
# - All strings use double quotes and are properly escaped
# - All braces and brackets are balanced
# - No trailing commas
# - Response is complete (not truncated)
#
# 📚 Synthesizing rules from dataset...
# ✓ Synthesized 4 rules (58.7s)
# ✓ Generated 4 rules
#
# 🔄 Refinement loop (max 3 iterations)
# [1/3] Evaluating rules...
# [1/3] Accuracy: 50.0% (2/4)
# [1/3] Refining based on 2 failures...
# de
# [1/3] Refined 5 rules (58.9s)
# [2/3] Evaluating rules...
# [2/3] Accuracy: 75.0% (3/4)
# [2/3] Refining based on 1 failures...
# de
# [2/3] Refined 5 rules (55.6s)
# [3/3] Evaluating rules...
# [3/3] Accuracy: 50.0% (2/4)
# [3/3] Refining based on 2 failures...
# de
# [3/3] Refined 10 rules (105.4s)
#
# ============================================================
# Learning complete! (278.5s)
#   Rules: 5
#   Accuracy: 75.0% (3/4)
# ============================================================

# %%
rules_file = Path("./rulechef_data/2025-02-02_ORG_ler_myexamp_v2.json")
rules_data = json.loads(rules_file.read_text())

rules = [Rule.from_dict(r) for r in rules_data.get("rules")]
for rule in rules:
    print_rule_result(rule)
    print("############")
# Out:
# CONTENT Match organization labels (Verein, Partei, Club, Verband, Initiative, etc.) followed by a quoted name. Accepts many Unicode quote characters and allows spaces inside quotes so full quoted name is captured (fixes the truncated-quote failure).
# regex.Regex('\\b(?:Verein|Partei|Club|Organisation|Verband|Initiative|Bündnis|Freundeskreis|Gruppe)\\b\\s*(?:["\'\\u201c\\u201d\\u201e\\u201a\\u201b\\u2018\\u2019\\u00ab\\u00bb])\\s*[A-ZÄÖÜ0-9][^"\'\\u201c\\u201d\\u201e\\u201a\\u201b\\u2018\\u2019\\u00ab\\u00bb]+?\\s*(?:["\'\\u201c\\u201d\\u201e\\u201a\\u201b\\u2018\\u2019\\u00ab\\u00bb])', flags=regex.V0)
# ############
# CONTENT Match multi-word organization names that end with common corporate/legal suffixes (GmbH, AG, KG, e.V., KGaA, etc.).
# regex.Regex('\\b([A-ZÄÖÜ][A-Za-zÄÖÜäöüß0-9\\-&]*(?:\\s+[A-ZÄÖÜ][A-Za-zÄÖÜäöüß0-9\\-&]*)*)\\s+(?:AG|GmbH|KG|UG|OHG|Gbr|GbR|e\\.V\\.|eV|SE|KGaA|&\\s*Co\\.\\s*KG|Co\\.\\s*KG)\\b', flags=regex.V0)
# ############
# CONTENT Match institution names that contain keywords like Universität, Hochschule, Institut, Stiftung, Behörde, Ministerium, Senat, Rathaus, Kanzlei, Kirche, Land(e)samt and allow optional capitalized tail (e.g., 'Universität zu Köln').
# regex.Regex('\\b([A-ZÄÖÜ][A-Za-zÄÖÜäöüß0-9\\-]*(?:\\s+[A-ZÄÖÜ][A-Za-zÄÖÜäöüß0-9\\-]*)*)\\s+(?:Universit(?:ä|ae)t|Hochschule|Institut|Stiftung|Behörde|Ministerium|Senat|Rathaus|Kanzlei|Kirche|Landesamt|Akademie|Bibliothek)\\b(?:\\s+[A-ZÄÖÜ][A-Za-zÄÖÜäöüß0-9\\-]*)*', flags=regex.V0)
# ############
# CONTENT Match compound single-token court names that end with 'gericht' (e.g., 'Landgericht', 'Bundesverfassungsgericht').
# regex.Regex('\\b[A-ZÄÖÜ][A-Za-zÄÖÜäöüß0-9\\-]*gericht\\b', flags=regex.V0)
# ############
# CONTENT Match names ending with common organization keywords such as Bank, Sparkasse, Bahn, Stiftung, Agentur, Kommission, Gewerkschaft, Verband, Fraktion, Regierung, Kammer, Parlament, Zentrale, Büro.
# regex.Regex('\\b([A-ZÄÖÜ][A-Za-zÄÖÜäöüß0-9\\-]*(?:\\s+[A-ZÄÖÜ][A-Za-zÄÖÜäöüß0-9\\-]*)*)\\s+(?:Bank|Sparkasse|Bahn|Stiftung|Agentur|Kommission|Gewerkschaft|Verband|Fraktion|Regierung|Kammer|Parlament|Zentrale|Büro|Direktion|Konzern|Fond)\\b', flags=regex.V0)
# ############

# %%
predict(
    rules,
    "Frau Müller kommt jetzt. Sie geht heute zum Bundesgericht Öst. Nadia studiert an der Technische Universität Wien.",
)
# Out:
# {'entities': [{'text': 'Technische Universität Wien', 'start': 85, 'end': 112, 'type': 'ORG'}, {'text': 'Bundesgericht', 'start': 44, 'end': 57, 'type': 'ORG'}]}

# %%
predict(rules, "UNO City befindet sich in der Nähe von Donauzentrum.")
# Out:
# {}

# %%
predict(rules, "Max M ist Teil dieser Tierschutz Verband.")
# Out:
# {'entities': [{'text': 'Tierschutz Verband', 'start': 22, 'end': 40, 'type': 'ORG'}]}

# %%
predict(
    rules, "Max M ist Teil 'der Grüne' Partei"
)  # wrong because the quotes should be after ORG
# Out:
# {}

# %%
predict(rules, "Max M ist Teil der Partei 'Der Grüne'")
# Out:
# {'entities': [{'text': "Partei 'Der Grüne'", 'start': 19, 'end': 37, 'type': 'ORG'}]}

# %%
predict(
    rules, "Anna studiert an der Universität Wien."
)  # wrong because requires word in the beginning
# Out:
# {}

# %%
predict(rules, "MM GmbH hat eine grosse Spende für Kinder in Not geleistet.")
# Out:
# {'entities': [{'text': 'MM GmbH', 'start': 0, 'end': 7, 'type': 'ORG'}]}

# %% [markdown]
# #### Removed xml tags, adding some additional instructions
# Every rule must be justified by POSITIVE examples AND must exclude NEGATIVE examples.

# %%
rule_learner = RuleChefLearner(
    model="gpt-5-mini-2025-08-07",
    dataset="ler",
    allowed_classes="ORG",
    rule_file="2025-02-02_ORG_ler_myexamp_v3",
    lang="de",
)
rule_learner.fit(positive_examples, negative_examples)
# Out:
# {'PERS', 'LOC', 'NRM', 'RS', 'ORG', 'LIT', 'REG'}
# ✓ Added example (buffer: 1 new, 1 total)
# ✓ Added example (buffer: 2 new, 2 total)
# ✓ Added example (buffer: 3 new, 3 total)
# ✗ Added negative example (buffer: 4 new, 4 total)
#
# 📥 Converting 4 buffered examples to dataset...
#    (0 corrections, 0 LLM, 4 human)
# ✓ Converted to dataset: 0 corrections, 4 examples
#
# ============================================================
# Learning rules from 4 training items
#   Corrections: 0 (high value)
#   Examples: 4
#   Mode: Synthesis + Refinement (max 3 iterations)
# ============================================================
#
# de
# NEW PROMPT Task: Named Entity Recognition
# Description: Extract ORG: Organisationsnamen (Parteien, Vereine, Institutionen, Unternehmen) from German text
# Input schema: {'text': 'str'}
# Output schema:
# entities: List[Entity]
#
# Entity:
#   text: string  # The matched text span
#   start: integer  # Start character offset
#   end: integer  # End character offset
#   type: string  # Entity label
#
# TRAINING EXAMPLES (3 shown):
# Learn rules from the these examples:
#
# Input: {"text": "Frau M\u00fcller arbeitet beim Bundesverfassungsgericht in Wien."}
# Output: {"entities": [{"text": "Bundesverfassungsgericht", "start": 26, "end": 50, "type": "ORG"}]}
#
# Input: {"text": "Nadia studiert an der Technische Universit\u00e4t Wien."}
# Output: {"entities": [{"text": "Technische Universit\u00e4t Wien", "start": 22, "end": 49, "type": "ORG"}]}
#
# Input: {"text": "Im Juli 2009 gr\u00fcndete der Angeklagte den Verein \u201e Neudeutschland \u201c mit ihm als \u201e unabw\u00e4hlbarem \u201c ersten Vorstand."}
# Output: {"entities": [{"text": "Verein \u201e Neudeutschland \u201c", "start": 41, "end": 66, "type": "ORG"}]}
#
#
# NEGATIVE TRAINING EXAMPLES (1 shown):
# These examples show spans that must not be extracted.
# Rules that match these spans are wrong and must be avoided.
#
# Input: {"text": "Herr Rules kommt heute besuchen in Berlin."}
# Output: {"entities": [{"text": "Herr Rules", "start": 0, "end": 10, "type": "PER"}, {"text": "Berlin", "start": 35, "end": 41, "type": "LOC"}]}
#
# YOUR TASK:
# Synthesize a complete ruleset (max 10 rules) that:
# 1. Rely ONLY on the data provided
# 2. Every rule must be justified by POSITIVE examples AND must exclude NEGATIVE examples.
# 3. Handles all corrections correctly (CRITICAL - these show failure modes)
# 4. Works on all examples
# 5. Respects user feedback
# 6. Is general and minimal (avoid redundant rules)
#
# RULES CAN BE:- Regex patterns (for structured extraction)
#
# IMPORTANT: You must ONLY use the allowed formats listed above. Do NOT generate rules in other formats.
# IMPORTANT: Do NOT include Python/code rules. Only return the listed formats.
# IMPORTANT: Do NOT include spaCy rules. Only return the listed formats.
#
# SCHEMA-AWARE RULES:
# For this task, rules must include an output_template that maps matches to the output schema.
#
# Output schema:
# entities: List[Entity]
#
# Entity:
#   text: string  # The matched text span
#   start: integer  # Start character offset
#   end: integer  # End character offset
#   type: string  # Entity label
#
# Each rule needs:
# - pattern: The regex pattern to match
# - output_template: JSON template for each match, using variables:
#   - $0: Full match text
#   - $start: Start character offset
#   - $end: End character offset
#   - $1, $2, ...: Capture groups (regex only)
# - output_key: Which output array to populate (e.g., "entities")
#
# Return JSON:
# {
#   "analysis": "What patterns did you find? What went wrong in corrections?",
#   "strategy": "Overall approach",
#   "note": "Every rule must include both output_template and output_key",
#   "rules": [
#     {
#       "name": "Short rule name",
#       "description": "What this rule does",
#       "format": "regex",
#       "pattern": "regex pattern",
#       "output_template": {"text": "$0", "start": "$start", "end": "$end", "type": "LITERAL_OR_$VAR"},
#       "output_key": "entities",
#       "priority": 1-10 (higher = more important),
#       "reasoning": "Why this rule is needed"
#     }
#   ]
# }
#
# NER RULE EXAMPLES (regex):
#
#
# Example 1 - Organizations with corporate suffixes:
# {
#   "name": "corporate_suffixes",
#   "format": "regex",
#   "pattern": "\b([A-Z][a-z0-9]+(?:\s+[A-Z][a-z]+)*)\s+(AG|GmbH|KG|UG|OHG|Gbr)\b",
#   "output_template": {"text": "$0", "start": "$start", "end": "$end", "type": "ORG"},
#   "output_key": "entities",
#   "priority": 9
# }
#
# Focus on learning from CORRECTIONS - they show exactly what went wrong!
#
# IMPORTANT: Return ONLY valid JSON. Ensure:
# - All strings use double quotes and are properly escaped
# - All braces and brackets are balanced
# - No trailing commas
# - Response is complete (not truncated)
#
# 📚 Synthesizing rules from dataset...
# ✓ Synthesized 3 rules (69.9s)
# ✓ Generated 3 rules
#
# 🔄 Refinement loop (max 3 iterations)
# [1/3] Evaluating rules...
# [1/3] Accuracy: 50.0% (2/4)
# [1/3] Refining based on 2 failures...
# de
# [1/3] Refined 7 rules (40.7s)
# [2/3] Evaluating rules...
# [2/3] Accuracy: 50.0% (2/4)
# [2/3] Refining based on 2 failures...
# de
#       Validation error: look-behind requires fixed-width pattern
#    ⚠ Skipped invalid rule: location_after_preposition_in
# [2/3] Refined 8 rules (62.8s)
# [3/3] Evaluating rules...
# [3/3] Accuracy: 50.0% (2/4)
# [3/3] Refining based on 2 failures...
# de
# [3/3] Refined 9 rules (52.5s)
#
# ============================================================
# Learning complete! (225.8s)
#   Rules: 8
#   Accuracy: 50.0% (2/4)
# ============================================================

# %%
rules_file = Path("./rulechef_data/2025-02-02_ORG_ler_myexamp_v3.json")
rules_data = json.loads(rules_file.read_text())

rules = [Rule.from_dict(r) for r in rules_data.get("rules")]
for rule in rules:
    print_rule_result(rule)
    print("####################")
# Out:
# CONTENT Match the exact word Bundesverfassungsgericht (federal constitutional court).
# regex.Regex('\\bBundesverfassungsgericht\\b', flags=regex.V0)
# ####################
# CONTENT Match compound names ending with 'Verfassungsgericht', e.g. Staatsverfassungsgericht.
# regex.Regex('\\b[A-ZÄÖÜ][\\wäöüÄÖÜß\\-]*Verfassungsgericht\\b', flags=regex.V0)
# ####################
# CONTENT Match university names (single or two-word variants around 'Universit*').
# regex.Regex('\\b(?:[A-ZÄÖÜ][\\wäöüÄÖÜß]+\\s+)?Universit\\w+(?:\\s+[A-ZÄÖÜ][\\wäöüÄÖÜß]+)?\\b', flags=regex.V0)
# ####################
# CONTENT Match corporate names with common German legal suffixes (AG, GmbH, KG, UG, OHG, Gbr, GmbH & Co. KG variants).
# regex.Regex('\\b[A-ZÄÖÜ][\\wäöüÄÖÜß\\-]*(?:\\s+[A-ZÄÖÜ][\\wäöüÄÖÜß\\-]*)*\\s+(?:AG|GmbH|KG|UG|OHG|Gbr|GmbH\\s*&\\s*Co\\.\\s*KG)\\b', flags=regex.V0)
# ####################
# CONTENT Match 'Verein' followed by a quoted name using various quote characters (handles Unicode quotes and optional inner spaces).
# regex.Regex('\\bVerein\\s+[\\u201e\\u201c"\'\\u00ab\\u00bb][\\s\\S]{0,200}?[\\u201e\\u201c"\'\\u00ab\\u00bb]', flags=regex.V0)
# ####################
# CONTENT Match 'Verein' followed by a name, optional 'e.V.' variants.
# regex.Regex("\\bVerein\\s+[A-ZÄÖÜ][\\wäöüÄÖÜß\\-\\.\\s']{1,120}(?:\\s+(?:e\\.V\\.|eV|ev|eingetragener\\s+Verein))?\\b", flags=regex.V0)
# ####################
# CONTENT Generic institution terms following a capitalized headword (Amt, Behörde, Institut, Verband, Ministerium, Stiftung, Zentrale, Anstalt, Senat, Landesamt, Kammer).
# regex.Regex('\\b[A-ZÄÖÜ][\\wäöüÄÖÜß\\-]+\\s+(?:Amt|Behörde|Institut(?:\\s+für)?|Verband|Ministerium|Stiftung|Zentrale|Anstalt|Senat|Landesamt|Kammer)\\b', flags=regex.V0)
# ####################
# CONTENT Match persons with common German titles (Herr, Frau, Dr., Prof.).
# regex.Regex('\\b(?:Herr|Frau|Dr\\.?|Prof\\.?)\\s+[A-ZÄÖÜ][\\wäöüÄÖÜß\\-]{1,50}\\b', flags=regex.V0)
# ####################

# %%
predict(
    rules,
    "Frau Müller kommt jetzt. Sie geht heute zum Bundesgericht Öst. Nadia studiert an der Technische Universität Wien.",
)  # WRONG
# Out:
# {'entities': [{'text': 'Technische Universität Wien', 'start': 85, 'end': 112, 'type': 'ORG'}, {'text': 'Bundesgericht', 'start': 44, 'end': 57, 'type': 'ORG'}]}

# %% [markdown]
# #### removed this line from prompt
# Every rule must be justified by POSITIVE examples AND must exclude NEGATIVE examples.

# %%
rule_learner = RuleChefLearner(
    model="gpt-5-mini-2025-08-07",
    dataset="ler",
    allowed_classes="ORG",
    rule_file="2025-02-02_ORG_ler_myexamp_v4",
    lang="de",
)
rule_learner.fit(positive_examples, negative_examples)
# Out:
# {'LOC', 'NRM', 'PERS', 'LIT', 'RS', 'REG', 'ORG'}
# ✓ Added example (buffer: 1 new, 1 total)
# ✓ Added example (buffer: 2 new, 2 total)
# ✓ Added example (buffer: 3 new, 3 total)
# ✗ Added negative example (buffer: 4 new, 4 total)
#
# 📥 Converting 4 buffered examples to dataset...
#    (0 corrections, 0 LLM, 4 human)
# ✓ Converted to dataset: 0 corrections, 4 examples
#
# ============================================================
# Learning rules from 4 training items
#   Corrections: 0 (high value)
#   Examples: 4
#   Mode: Synthesis + Refinement (max 3 iterations)
# ============================================================
#
# de
# NEW PROMPT Task: Named Entity Recognition
# Description: Extract ORG: Organisationsnamen (Parteien, Vereine, Institutionen, Unternehmen) from German text
# Input schema: {'text': 'str'}
# Output schema:
# entities: List[Entity]
#
# Entity:
#   text: string  # The matched text span
#   start: integer  # Start character offset
#   end: integer  # End character offset
#   type: string  # Entity label
#
# TRAINING EXAMPLES (3 shown):
# Learn rules from the these examples:
#
# Input: {"text": "Frau M\u00fcller arbeitet beim Bundesverfassungsgericht in Wien."}
# Output: {"entities": [{"text": "Bundesverfassungsgericht", "start": 26, "end": 50, "type": "ORG"}]}
#
# Input: {"text": "Nadia studiert an der Technische Universit\u00e4t Wien."}
# Output: {"entities": [{"text": "Technische Universit\u00e4t Wien", "start": 22, "end": 49, "type": "ORG"}]}
#
# Input: {"text": "Im Juli 2009 gr\u00fcndete der Angeklagte den Verein \u201e Neudeutschland \u201c mit ihm als \u201e unabw\u00e4hlbarem \u201c ersten Vorstand."}
# Output: {"entities": [{"text": "Verein \u201e Neudeutschland \u201c", "start": 41, "end": 66, "type": "ORG"}]}
#
#
# NEGATIVE TRAINING EXAMPLES (1 shown):
# These examples show spans that must not be extracted.
# Rules that match these spans are wrong and must be avoided.
#
# Input: {"text": "Herr Rules kommt heute besuchen in Berlin."}
# Output: {"entities": [{"text": "Herr Rules", "start": 0, "end": 10, "type": "PER"}, {"text": "Berlin", "start": 35, "end": 41, "type": "LOC"}]}
#
# YOUR TASK:
# Synthesize a complete ruleset (max 10 rules) that:
# 1. Rely ONLY on the data provided
# 2. Handles all corrections correctly (CRITICAL - these show failure modes)
# 3. Works on all examples
# 4. Respects user feedback
# 5. Is general and minimal (avoid redundant rules)
#
# RULES CAN BE:- Regex patterns (for structured extraction)
#
# IMPORTANT: You must ONLY use the allowed formats listed above. Do NOT generate rules in other formats.
# IMPORTANT: Do NOT include Python/code rules. Only return the listed formats.
# IMPORTANT: Do NOT include spaCy rules. Only return the listed formats.
#
# SCHEMA-AWARE RULES:
# For this task, rules must include an output_template that maps matches to the output schema.
#
# Output schema:
# entities: List[Entity]
#
# Entity:
#   text: string  # The matched text span
#   start: integer  # Start character offset
#   end: integer  # End character offset
#   type: string  # Entity label
#
# Each rule needs:
# - pattern: The regex pattern to match
# - output_template: JSON template for each match, using variables:
#   - $0: Full match text
#   - $start: Start character offset
#   - $end: End character offset
#   - $1, $2, ...: Capture groups (regex only)
# - output_key: Which output array to populate (e.g., "entities")
#
# Return JSON:
# {
#   "analysis": "What patterns did you find? What went wrong in corrections?",
#   "strategy": "Overall approach",
#   "note": "Every rule must include both output_template and output_key",
#   "rules": [
#     {
#       "name": "Short rule name",
#       "description": "What this rule does",
#       "format": "regex",
#       "pattern": "regex pattern",
#       "output_template": {"text": "$0", "start": "$start", "end": "$end", "type": "LITERAL_OR_$VAR"},
#       "output_key": "entities",
#       "priority": 1-10 (higher = more important),
#       "reasoning": "Why this rule is needed"
#     }
#   ]
# }
#
# NER RULE EXAMPLES (regex):
#
#
# Example 1 - Organizations with corporate suffixes:
# {
#   "name": "corporate_suffixes",
#   "format": "regex",
#   "pattern": "\b([A-Z][a-z0-9]+(?:\s+[A-Z][a-z]+)*)\s+(AG|GmbH|KG|UG|OHG|Gbr)\b",
#   "output_template": {"text": "$0", "start": "$start", "end": "$end", "type": "ORG"},
#   "output_key": "entities",
#   "priority": 9
# }
#
# Focus on learning from CORRECTIONS - they show exactly what went wrong!
#
# IMPORTANT: Return ONLY valid JSON. Ensure:
# - All strings use double quotes and are properly escaped
# - All braces and brackets are balanced
# - No trailing commas
# - Response is complete (not truncated)
#
# 📚 Synthesizing rules from dataset...
# ✓ Synthesized 5 rules (60.1s)
# ✓ Generated 5 rules
#
# 🔄 Refinement loop (max 3 iterations)
# [1/3] Evaluating rules...
# [1/3] Accuracy: 50.0% (2/4)
# [1/3] Refining based on 2 failures...
# de
# [1/3] Refined 8 rules (91.9s)
# [2/3] Evaluating rules...
# [2/3] Accuracy: 50.0% (2/4)
# [2/3] Refining based on 2 failures...
# de
# [2/3] Refined 6 rules (64.4s)
# [3/3] Evaluating rules...
# [3/3] Accuracy: 75.0% (3/4)
# [3/3] Refining based on 1 failures...
# de
# [3/3] Refined 7 rules (49.7s)
#
# ============================================================
# Learning complete! (266.1s)
#   Rules: 6
#   Accuracy: 75.0% (3/4)
# ============================================================

# %%
rules_file = Path("./rulechef_data/2025-02-02_ORG_ler_myexamp_v4.json")
rules_data = json.loads(rules_file.read_text())

rules = [Rule.from_dict(r) for r in rules_data.get("rules")]
for rule in rules:
    print_rule_result(rule)
    print("####################")
# Out:
# CONTENT Match company names followed by common corporate legal suffixes, including variants like 'GmbH & Co. KG'.
# regex.Regex('\\b([A-ZÄÖÜ][\\wäöüÄÖÜß]*(?:\\s+[A-ZÄÖÜ][\\wäöüÄÖÜß]*){0,4})\\s+(?:AG|GmbH(?:\\s*&\\s*Co\\.\\s*KG|&Co\\.KG|&Co\\. KG|\\.?\\s*Co\\.?\\s*KG)?|KG|UG|OHG|Gbr|SE|GmbH&Co\\.KG)\\b', flags=regex.V0)
# ####################
# CONTENT Match universities, technical universities, Hochschulen and Akademien with following capitalized location or name parts (e.g. 'Technische Universität Wien').
# regex.Regex('\\b(?:Technische|Hochschule|Universit(?:ät|y)|Akademie)(?:\\s+(?:[A-ZÄÖÜ][\\wäöüÄÖÜß-]{1,60})){0,4}\\b', flags=regex.V0)
# ####################
# CONTENT Match German court names that end with 'gericht' (case-insensitive endings with proper capitalization at start).
# regex.Regex('\\b[A-ZÄÖÜ][A-Za-zäöüÄÖÜß-]*gericht\\b', flags=regex.V0)
# ####################
# CONTENT Match institution keywords (Partei, Stiftung, Institut, Behörde, Ministerium, Amt, Bank, Konzern) with either a quoted name or following capitalized tokens.
# regex.Regex('\\b(?:Partei|Stiftung|Institut|Behörde|Ministerium|Amt|Bank|Konzern)\\b\\s*(?:["\'\\u201e\\u201c]\\s*[^"\'\\u201e\\u201c\\n]{1,60}\\s*["\'\\u201e\\u201c]|(?:\\s+(?:[A-ZÄÖÜ][\\wäöüÄÖÜß-]{1,60})(?:\\s+(?:[A-ZÄÖÜ][\\wäöüÄÖÜß-]{1,60})){0,3}))', flags=regex.V0)
# ####################
# CONTENT Match 'Verein' followed by a quoted name, e.g. Verein "Freunde der Musik".
# regex.Regex('\\bVerein\\b\\s*(?:["\'\\u201e\\u201c]\\s*[^"\'\\u201e\\u201c\\n]{1,60}\\s*["\'\\u201e\\u201c])', flags=regex.V0)
# ####################
# CONTENT Match 'Verein' followed by a short capitalized name (up to 3 tokens), e.g. 'Verein Deutscher Ingenieure'.
# regex.Regex('\\bVerein\\b\\s+(?:[A-ZÄÖÜ][\\wäöüÄÖÜß-]+(?:\\s+[A-ZÄÖÜ][\\wäöüÄÖÜß-]+){0,2})\\b', flags=regex.V0)
# ####################

# %%
predict(
    rules,
    "Frau Müller kommt jetzt. Sie geht heute zum Finanzgericht Öst. Nadia studiert an der Technische Universität Wien.",
)
# Out:
# {'entities': [{'text': 'Technische Universität Wien', 'start': 85, 'end': 112, 'type': 'ORG'}, {'text': 'Finanzgericht', 'start': 44, 'end': 57, 'type': 'ORG'}]}

# %%
predict(
    rules,
    "UNO City befindet sich in der Nähe von Donauzentrum. Dort befindet sich auch A GmbH.",
)
# Out:
# {'entities': [{'text': 'A GmbH', 'start': 77, 'end': 83, 'type': 'ORG'}]}

# %%
predict(rules, "Max M ist Teil dieser Tierschutz Verband.")
# Out:
# {}

# %%
predict(
    rules, "Max M ist Teil 'der Grüne' Partei"
)  # wrong because the quotes should be after ORG
# Out:
# {}

# %%
predict(rules, "Max M ist Teil der Partei 'Der Grüne'")
# Out:
# {'entities': [{'text': "Partei 'Der Grüne'", 'start': 19, 'end': 37, 'type': 'ORG'}]}

# %%
predict(
    rules, "Anna studiert an der Universität Wien."
)  # wrong because requires word in the beginning
# Out:
# {'entities': [{'text': 'Universität Wien', 'start': 21, 'end': 37, 'type': 'ORG'}]}

# %%
predict(rules, "MM KG hat eine grosse Spende für Kinder in Not geleistet.")
# Out:
# {'entities': [{'text': 'MM KG', 'start': 0, 'end': 5, 'type': 'ORG'}]}

# %% [markdown]
# ### Changed my negative example

# %%
# My Examples

# positive Examples
positive_examples = [
    {
        "text": "Frau Müller arbeitet beim Bundesverfassungsgericht in Wien.",
        "entities": [
            {"text": "Bundesverfassungsgericht", "start": 26, "end": 50, "type": "ORG"}
        ],
    },
    {
        "text": "Nadia studiert an der Technische Universität Wien.",
        "entities": [
            {
                "text": "Technische Universität Wien",
                "start": 22,
                "end": 49,
                "type": "ORG",
            }
        ],
    },
    {
        "text": "Im Juli 2009 gründete der Angeklagte den Verein „ Neudeutschland “ mit ihm als „ unabwählbarem “ ersten Vorstand.",
        "entities": [
            {"text": "Verein „ Neudeutschland “", "start": 41, "end": 66, "type": "ORG"}
        ],
    },
]

# Negative Examples

negative_examples = [
    {
        "text": "Frau Müller arbeitet beim Bundesverfassungsgericht in Wien.",
        "entities": [
            {"text": "Frau Müller", "start": 0, "end": 11, "type": "PER"},
            {"text": "Wien", "start": 54, "end": 58, "type": "LOC"},
        ],
    },
]

# %%
rule_learner = RuleChefLearner(
    model="gpt-5-mini-2025-08-07",
    dataset="ler",
    allowed_classes="ORG",
    rule_file="2025-02-02_ORG_ler_myexamp_v5",
    lang="de",
)
rule_learner.fit(positive_examples, negative_examples)
# Out:
# {'LOC', 'NRM', 'PERS', 'LIT', 'RS', 'REG', 'ORG'}
# ✓ Added example (buffer: 1 new, 1 total)
# ✓ Added example (buffer: 2 new, 2 total)
# ✓ Added example (buffer: 3 new, 3 total)
# ✗ Added negative example (buffer: 4 new, 4 total)
#
# 📥 Converting 4 buffered examples to dataset...
#    (0 corrections, 0 LLM, 4 human)
# ✓ Converted to dataset: 0 corrections, 4 examples
#
# ============================================================
# Learning rules from 4 training items
#   Corrections: 0 (high value)
#   Examples: 4
#   Mode: Synthesis + Refinement (max 3 iterations)
# ============================================================
#
# de
# NEW PROMPT Task: Named Entity Recognition
# Description: Extract ORG: Organisationsnamen (Parteien, Vereine, Institutionen, Unternehmen) from German text
# Input schema: {'text': 'str'}
# Output schema:
# entities: List[Entity]
#
# Entity:
#   text: string  # The matched text span
#   start: integer  # Start character offset
#   end: integer  # End character offset
#   type: string  # Entity label
#
# TRAINING EXAMPLES (3 shown):
# Learn rules from the these examples:
#
# Input: {"text": "Frau M\u00fcller arbeitet beim Bundesverfassungsgericht in Wien."}
# Output: {"entities": [{"text": "Bundesverfassungsgericht", "start": 26, "end": 50, "type": "ORG"}]}
#
# Input: {"text": "Nadia studiert an der Technische Universit\u00e4t Wien."}
# Output: {"entities": [{"text": "Technische Universit\u00e4t Wien", "start": 22, "end": 49, "type": "ORG"}]}
#
# Input: {"text": "Im Juli 2009 gr\u00fcndete der Angeklagte den Verein \u201e Neudeutschland \u201c mit ihm als \u201e unabw\u00e4hlbarem \u201c ersten Vorstand."}
# Output: {"entities": [{"text": "Verein \u201e Neudeutschland \u201c", "start": 41, "end": 66, "type": "ORG"}]}
#
#
# NEGATIVE TRAINING EXAMPLES (1 shown):
# These examples show spans that must not be extracted.
# Rules that match these spans are wrong and must be avoided.
#
# Input: {"text": "Frau M\u00fcller arbeitet beim Bundesverfassungsgericht in Wien."}
# Output: {"entities": [{"text": "Frau M\u00fcller", "start": 0, "end": 11, "type": "PER"}, {"text": "Wien", "start": 54, "end": 58, "type": "LOC"}]}
#
# YOUR TASK:
# Synthesize a complete ruleset (max 10 rules) that:
# 1. Rely ONLY on the data provided
# 2. Handles all corrections correctly (CRITICAL - these show failure modes)
# 3. Works on all examples
# 4. Respects user feedback
# 5. Is general and minimal (avoid redundant rules)
#
# RULES CAN BE:- Regex patterns (for structured extraction)
#
# IMPORTANT: You must ONLY use the allowed formats listed above. Do NOT generate rules in other formats.
# IMPORTANT: Do NOT include Python/code rules. Only return the listed formats.
# IMPORTANT: Do NOT include spaCy rules. Only return the listed formats.
#
# SCHEMA-AWARE RULES:
# For this task, rules must include an output_template that maps matches to the output schema.
#
# Output schema:
# entities: List[Entity]
#
# Entity:
#   text: string  # The matched text span
#   start: integer  # Start character offset
#   end: integer  # End character offset
#   type: string  # Entity label
#
# Each rule needs:
# - pattern: The regex pattern to match
# - output_template: JSON template for each match, using variables:
#   - $0: Full match text
#   - $start: Start character offset
#   - $end: End character offset
#   - $1, $2, ...: Capture groups (regex only)
# - output_key: Which output array to populate (e.g., "entities")
#
# Return JSON:
# {
#   "analysis": "What patterns did you find? What went wrong in corrections?",
#   "strategy": "Overall approach",
#   "note": "Every rule must include both output_template and output_key",
#   "rules": [
#     {
#       "name": "Short rule name",
#       "description": "What this rule does",
#       "format": "regex",
#       "pattern": "regex pattern",
#       "output_template": {"text": "$0", "start": "$start", "end": "$end", "type": "LITERAL_OR_$VAR"},
#       "output_key": "entities",
#       "priority": 1-10 (higher = more important),
#       "reasoning": "Why this rule is needed"
#     }
#   ]
# }
#
# NER RULE EXAMPLES (regex):
#
#
# Example 1 - Organizations with corporate suffixes:
# {
#   "name": "corporate_suffixes",
#   "format": "regex",
#   "pattern": "\b([A-Z][a-z0-9]+(?:\s+[A-Z][a-z]+)*)\s+(AG|GmbH|KG|UG|OHG|Gbr)\b",
#   "output_template": {"text": "$0", "start": "$start", "end": "$end", "type": "ORG"},
#   "output_key": "entities",
#   "priority": 9
# }
#
# Focus on learning from CORRECTIONS - they show exactly what went wrong!
#
# IMPORTANT: Return ONLY valid JSON. Ensure:
# - All strings use double quotes and are properly escaped
# - All braces and brackets are balanced
# - No trailing commas
# - Response is complete (not truncated)
#
# 📚 Synthesizing rules from dataset...
# ✓ Synthesized 5 rules (62.6s)
# ✓ Generated 5 rules
#
# 🔄 Refinement loop (max 3 iterations)
# [1/3] Evaluating rules...
# [1/3] Accuracy: 75.0% (3/4)
# [1/3] Refining based on 1 failures...
# de
#       Validation error: look-behind requires fixed-width pattern
#    ⚠ Skipped invalid rule: location_after_preposition
# [1/3] Refined 5 rules (94.4s)
# [2/3] Evaluating rules...
# [2/3] Accuracy: 0.0% (0/4)
# [2/3] Refining based on 4 failures...
# de
# [2/3] Refined 6 rules (98.9s)
# [3/3] Evaluating rules...
# [3/3] Accuracy: 50.0% (2/4)
# [3/3] Refining based on 2 failures...
# de
# [3/3] Refined 6 rules (80.4s)
#
# ============================================================
# Learning complete! (336.4s)
#   Rules: 5
#   Accuracy: 75.0% (3/4)
# ============================================================

# %%
rules_file = Path("./rulechef_data/2025-02-02_ORG_ler_myexamp_v5.json")
rules_data = json.loads(rules_file.read_text())

rules = [Rule.from_dict(r) for r in rules_data.get("rules")]
for rule in rules:
    print_rule_result(rule)
    print("####################")
# Out:
# CONTENT Match organization labels (Verein, Partei, Firma, Institut, Behörde, Stiftung, Organisation, Unternehmen) followed by a quoted name (various quote characters). This captures examples like 'Verein „ Neudeutschland “'.
# regex.Regex('\\b(?:Verein|Partei|Organisation|Firma|Unternehmen|Institut|Behörde|Stiftung)\\s*[„"“”\'‹›]\\s*[^„"“”\'‹›]+?\\s*[„"“”\'‹›]', flags=regex.V0)
# ####################
# CONTENT Match multi-word names that include a leading capitalized sequence and a following organizational keyword (Universität, Hochschule, Institut, Akademie, Fakultät, Zentrum, Ministerium, Behörde, Parlament, Kammer, Stiftung, Fraktion, Regierung, Senat, Verein, Gericht). Allows trailing capitalized location or descriptor (e.g., 'Technische Universität Wien').
# regex.Regex('\\b(?:[A-ZÄÖÜ][\\wäöüÄÖÜß]+(?:\\s+[A-ZÄÖÜ][\\wäöüÄÖÜß]+){0,3})\\s+(?:Universität|Universitaet|Hochschule|Institut|Akademie|Fakultät|Zentrum|Ministerium|Behörde|Parlament|Kammer|Stiftung|Fraktion|Regierung|Senat|Verein|Gericht)\\b(?:\\s+[A-ZÄÖÜ][\\wäöüÄÖÜß]+)*', flags=regex.V0)
# ####################
# CONTENT Match well-known standalone court/tribunal tokens that may appear alone (e.g., Bundesverfassungsgericht).
# regex.Regex('\\b(?:Bundesverfassungsgericht|Bundesgerichtshof|Verfassungsgericht|Landesgericht|Oberlandesgericht|Gericht)\\b', flags=regex.V0)
# ####################
# CONTENT Match company names that end with corporate/legal suffixes (GmbH, AG, KG, UG, OHG, Gbr, e.V. etc.), capturing preceding capitalized name parts as part of the org.
# regex.Regex('\\b(?:[A-ZÄÖÜ][\\wäöüÄÖÜß]+(?:\\s+[A-ZÄÖÜ][\\wäöüÄÖÜß]+)*)\\s+(?:GmbH|AG|KG|UG|OHG|Gbr|GbR|e\\.V\\.|eV)\\b', flags=regex.V0)
# ####################
# CONTENT Match cases where an organizational label (Verein, Partei, Institut, Stiftung, Organisation, Firma) is followed by an unquoted multiword name (e.g., 'der Angeklagte den Verein Neudeutschland').
# regex.Regex('\\b(?:Verein|Partei|Organisation|Firma|Unternehmen|Institut|Behörde|Stiftung)\\s+(?:[A-ZÄÖÜ][\\wäöüÄÖÜß]+(?:\\s+[A-ZÄÖÜ][\\wäöüÄÖÜß]+)*)', flags=regex.V0)
# ####################

# %%
predict(
    rules,
    "Frau Müller kommt jetzt. Sie geht heute zum Finanzgericht Öst in Wien. Nadia studiert an der Technische Universität Wien.",
)
# Out:
# {'entities': [{'text': 'Technische Universität Wien', 'start': 93, 'end': 120, 'type': 'ORG'}]}

# %%
predict(
    rules,
    "UNO City befindet sich in der Nähe von Donauzentrum. Dort befindet sich auch Aa GmbH.",
)
# Out:
# {'entities': [{'text': 'Aa GmbH', 'start': 77, 'end': 84, 'type': 'ORG'}]}

# %%
predict(rules, "Max M ist Teil des Verein 'Sport'.")
# Out:
# {'entities': [{'text': "Verein 'Sport'", 'start': 19, 'end': 33, 'type': 'ORG'}]}

# %%
predict(rules, "Max M ist eine Angeklagte an Gericht des Finanz.")
# Out:
# {'entities': [{'text': 'Gericht', 'start': 29, 'end': 36, 'type': 'ORG'}]}

# %% [markdown]
# ### LER dataset

# %%
rule_learner = RuleChefLearner(
    model="gpt-5-mini-2025-08-07",
    dataset="ler",
    allowed_classes="ORG",
    rule_file="2025-02-02_ORG_ler_dataset_v2",
    lang="de",
)
rule_learner.fit(sampled, negative)
# Out:
# {'REG', 'ORG', 'LIT', 'LOC', 'RS', 'NRM', 'PERS'}
# ✓ Loaded dataset: 0 corrections, 4944 examples
# ✓ Added example (buffer: 1 new, 1 total)
# ✓ Added example (buffer: 2 new, 2 total)
# ✓ Added example (buffer: 3 new, 3 total)
# ✓ Added example (buffer: 4 new, 4 total)
# ✓ Added example (buffer: 5 new, 5 total)
# ✓ Added example (buffer: 6 new, 6 total)
# ✓ Added example (buffer: 7 new, 7 total)
# ✓ Added example (buffer: 8 new, 8 total)
# ✓ Added example (buffer: 9 new, 9 total)
# ✓ Added example (buffer: 10 new, 10 total)
# ✓ Added example (buffer: 11 new, 11 total)
# ✓ Added example (buffer: 12 new, 12 total)
# ✓ Added example (buffer: 13 new, 13 total)
# ✓ Added example (buffer: 14 new, 14 total)
# ✓ Added example (buffer: 15 new, 15 total)
# ✓ Added example (buffer: 16 new, 16 total)
# ✓ Added example (buffer: 17 new, 17 total)
# ✓ Added example (buffer: 18 new, 18 total)
# ✓ Added example (buffer: 19 new, 19 total)
# ✓ Added example (buffer: 20 new, 20 total)
# ✓ Added example (buffer: 21 new, 21 total)
# ✓ Added example (buffer: 22 new, 22 total)
# ✓ Added example (buffer: 23 new, 23 total)
# ✓ Added example (buffer: 24 new, 24 total)
# ✓ Added example (buffer: 25 new, 25 total)
# ✓ Added example (buffer: 26 new, 26 total)
# ✓ Added example (buffer: 27 new, 27 total)
# ✓ Added example (buffer: 28 new, 28 total)
# ✓ Added example (buffer: 29 new, 29 total)
# ✓ Added example (buffer: 30 new, 30 total)
# ✓ Added example (buffer: 31 new, 31 total)
# ✓ Added example (buffer: 32 new, 32 total)
# ✓ Added example (buffer: 33 new, 33 total)
# ✓ Added example (buffer: 34 new, 34 total)
# ✓ Added example (buffer: 35 new, 35 total)
# ✓ Added example (buffer: 36 new, 36 total)
# ✓ Added example (buffer: 37 new, 37 total)
# ✓ Added example (buffer: 38 new, 38 total)
# ✓ Added example (buffer: 39 new, 39 total)
# ✓ Added example (buffer: 40 new, 40 total)
# ✓ Added example (buffer: 41 new, 41 total)
# ✓ Added example (buffer: 42 new, 42 total)
# ✓ Added example (buffer: 43 new, 43 total)
# ✓ Added example (buffer: 44 new, 44 total)
# ✓ Added example (buffer: 45 new, 45 total)
# ✓ Added example (buffer: 46 new, 46 total)
# ✓ Added example (buffer: 47 new, 47 total)
# ✓ Added example (buffer: 48 new, 48 total)
# ✓ Added example (buffer: 49 new, 49 total)
# ✓ Added example (buffer: 50 new, 50 total)
# ✓ Added example (buffer: 51 new, 51 total)
# ✓ Added example (buffer: 52 new, 52 total)
# ✓ Added example (buffer: 53 new, 53 total)
# ✓ Added example (buffer: 54 new, 54 total)
# ✓ Added example (buffer: 55 new, 55 total)
# ✓ Added example (buffer: 56 new, 56 total)
# ✓ Added example (buffer: 57 new, 57 total)
# ✓ Added example (buffer: 58 new, 58 total)
# ✓ Added example (buffer: 59 new, 59 total)
# ✓ Added example (buffer: 60 new, 60 total)
# ✓ Added example (buffer: 61 new, 61 total)
# ✓ Added example (buffer: 62 new, 62 total)
# ✓ Added example (buffer: 63 new, 63 total)
# ✓ Added example (buffer: 64 new, 64 total)
# ✓ Added example (buffer: 65 new, 65 total)
# ✓ Added example (buffer: 66 new, 66 total)
# ✓ Added example (buffer: 67 new, 67 total)
# ✓ Added example (buffer: 68 new, 68 total)
# ✓ Added example (buffer: 69 new, 69 total)
# ✓ Added example (buffer: 70 new, 70 total)
# ✓ Added example (buffer: 71 new, 71 total)
# ✓ Added example (buffer: 72 new, 72 total)
# ✓ Added example (buffer: 73 new, 73 total)
# ✓ Added example (buffer: 74 new, 74 total)
# ✓ Added example (buffer: 75 new, 75 total)
# ✓ Added example (buffer: 76 new, 76 total)
# ✓ Added example (buffer: 77 new, 77 total)
# ✓ Added example (buffer: 78 new, 78 total)
# ✓ Added example (buffer: 79 new, 79 total)
# ✓ Added example (buffer: 80 new, 80 total)
# ✓ Added example (buffer: 81 new, 81 total)
# ✓ Added example (buffer: 82 new, 82 total)
# ✓ Added example (buffer: 83 new, 83 total)
# ✓ Added example (buffer: 84 new, 84 total)
# ✓ Added example (buffer: 85 new, 85 total)
# ✓ Added example (buffer: 86 new, 86 total)
# ✓ Added example (buffer: 87 new, 87 total)
# ✓ Added example (buffer: 88 new, 88 total)
# ✓ Added example (buffer: 89 new, 89 total)
# ✓ Added example (buffer: 90 new, 90 total)
# ✓ Added example (buffer: 91 new, 91 total)
# ✓ Added example (buffer: 92 new, 92 total)
# ✓ Added example (buffer: 93 new, 93 total)
# ✓ Added example (buffer: 94 new, 94 total)
# ✓ Added example (buffer: 95 new, 95 total)
# ✓ Added example (buffer: 96 new, 96 total)
# ✓ Added example (buffer: 97 new, 97 total)
# ✓ Added example (buffer: 98 new, 98 total)
# ✓ Added example (buffer: 99 new, 99 total)
# ✓ Added example (buffer: 100 new, 100 total)
# ✓ Added example (buffer: 101 new, 101 total)
# ✓ Added example (buffer: 102 new, 102 total)
# ✓ Added example (buffer: 103 new, 103 total)
# ✓ Added example (buffer: 104 new, 104 total)
# ✓ Added example (buffer: 105 new, 105 total)
# ✓ Added example (buffer: 106 new, 106 total)
# ✓ Added example (buffer: 107 new, 107 total)
# ✓ Added example (buffer: 108 new, 108 total)
# ✓ Added example (buffer: 109 new, 109 total)
# ✓ Added example (buffer: 110 new, 110 total)
# ✓ Added example (buffer: 111 new, 111 total)
# ✓ Added example (buffer: 112 new, 112 total)
# ✓ Added example (buffer: 113 new, 113 total)
# ✓ Added example (buffer: 114 new, 114 total)
# ✓ Added example (buffer: 115 new, 115 total)
# ✓ Added example (buffer: 116 new, 116 total)
# ✓ Added example (buffer: 117 new, 117 total)
# ✓ Added example (buffer: 118 new, 118 total)
# ✓ Added example (buffer: 119 new, 119 total)
# ✓ Added example (buffer: 120 new, 120 total)
# ✓ Added example (buffer: 121 new, 121 total)
# ✓ Added example (buffer: 122 new, 122 total)
# ✓ Added example (buffer: 123 new, 123 total)
# ✓ Added example (buffer: 124 new, 124 total)
# ✓ Added example (buffer: 125 new, 125 total)
# ✓ Added example (buffer: 126 new, 126 total)
# ✓ Added example (buffer: 127 new, 127 total)
# ✓ Added example (buffer: 128 new, 128 total)
# ✓ Added example (buffer: 129 new, 129 total)
# ✓ Added example (buffer: 130 new, 130 total)
# ✓ Added example (buffer: 131 new, 131 total)
# ✓ Added example (buffer: 132 new, 132 total)
# ✓ Added example (buffer: 133 new, 133 total)
# ✓ Added example (buffer: 134 new, 134 total)
# ✓ Added example (buffer: 135 new, 135 total)
# ✓ Added example (buffer: 136 new, 136 total)
# ✓ Added example (buffer: 137 new, 137 total)
# ✓ Added example (buffer: 138 new, 138 total)
# ✓ Added example (buffer: 139 new, 139 total)
# ✓ Added example (buffer: 140 new, 140 total)
# ✓ Added example (buffer: 141 new, 141 total)
# ✓ Added example (buffer: 142 new, 142 total)
# ✓ Added example (buffer: 143 new, 143 total)
# ✓ Added example (buffer: 144 new, 144 total)
# ✓ Added example (buffer: 145 new, 145 total)
# ✓ Added example (buffer: 146 new, 146 total)
# ✓ Added example (buffer: 147 new, 147 total)
# ✓ Added example (buffer: 148 new, 148 total)
# ✓ Added example (buffer: 149 new, 149 total)
# ✓ Added example (buffer: 150 new, 150 total)
# ✓ Added example (buffer: 151 new, 151 total)
# ✓ Added example (buffer: 152 new, 152 total)
# ✓ Added example (buffer: 153 new, 153 total)
# ✓ Added example (buffer: 154 new, 154 total)
# ✓ Added example (buffer: 155 new, 155 total)
# ✓ Added example (buffer: 156 new, 156 total)
# ✓ Added example (buffer: 157 new, 157 total)
# ✓ Added example (buffer: 158 new, 158 total)
# ✓ Added example (buffer: 159 new, 159 total)
# ✓ Added example (buffer: 160 new, 160 total)
# ✓ Added example (buffer: 161 new, 161 total)
# ✓ Added example (buffer: 162 new, 162 total)
# ✓ Added example (buffer: 163 new, 163 total)
# ✓ Added example (buffer: 164 new, 164 total)
# ✓ Added example (buffer: 165 new, 165 total)
# ✓ Added example (buffer: 166 new, 166 total)
# ✓ Added example (buffer: 167 new, 167 total)
# ✓ Added example (buffer: 168 new, 168 total)
# ✓ Added example (buffer: 169 new, 169 total)
# ✓ Added example (buffer: 170 new, 170 total)
# ✓ Added example (buffer: 171 new, 171 total)
# ✓ Added example (buffer: 172 new, 172 total)
# ✓ Added example (buffer: 173 new, 173 total)
# ✓ Added example (buffer: 174 new, 174 total)
# ✓ Added example (buffer: 175 new, 175 total)
# ✓ Added example (buffer: 176 new, 176 total)
# ✓ Added example (buffer: 177 new, 177 total)
# ✓ Added example (buffer: 178 new, 178 total)
# ✓ Added example (buffer: 179 new, 179 total)
# ✓ Added example (buffer: 180 new, 180 total)
# ✓ Added example (buffer: 181 new, 181 total)
# ✓ Added example (buffer: 182 new, 182 total)
# ✓ Added example (buffer: 183 new, 183 total)
# ✓ Added example (buffer: 184 new, 184 total)
# ✓ Added example (buffer: 185 new, 185 total)
# ✓ Added example (buffer: 186 new, 186 total)
# ✓ Added example (buffer: 187 new, 187 total)
# ✓ Added example (buffer: 188 new, 188 total)
# ✓ Added example (buffer: 189 new, 189 total)
# ✓ Added example (buffer: 190 new, 190 total)
# ✓ Added example (buffer: 191 new, 191 total)
# ✓ Added example (buffer: 192 new, 192 total)
# ✓ Added example (buffer: 193 new, 193 total)
# ✓ Added example (buffer: 194 new, 194 total)
# ✓ Added example (buffer: 195 new, 195 total)
# ✓ Added example (buffer: 196 new, 196 total)
# ✓ Added example (buffer: 197 new, 197 total)
# ✓ Added example (buffer: 198 new, 198 total)
# ✓ Added example (buffer: 199 new, 199 total)
# ✓ Added example (buffer: 200 new, 200 total)
# ✓ Added example (buffer: 201 new, 201 total)
# ✓ Added example (buffer: 202 new, 202 total)
# ✓ Added example (buffer: 203 new, 203 total)
# ✓ Added example (buffer: 204 new, 204 total)
# ✓ Added example (buffer: 205 new, 205 total)
# ✓ Added example (buffer: 206 new, 206 total)
# ✓ Added example (buffer: 207 new, 207 total)
# ✓ Added example (buffer: 208 new, 208 total)
# ✓ Added example (buffer: 209 new, 209 total)
# ✓ Added example (buffer: 210 new, 210 total)
# ✓ Added example (buffer: 211 new, 211 total)
# ✓ Added example (buffer: 212 new, 212 total)
# ✓ Added example (buffer: 213 new, 213 total)
# ✓ Added example (buffer: 214 new, 214 total)
# ✓ Added example (buffer: 215 new, 215 total)
# ✓ Added example (buffer: 216 new, 216 total)
# ✓ Added example (buffer: 217 new, 217 total)
# ✓ Added example (buffer: 218 new, 218 total)
# ✓ Added example (buffer: 219 new, 219 total)
# ✓ Added example (buffer: 220 new, 220 total)
# ✓ Added example (buffer: 221 new, 221 total)
# ✓ Added example (buffer: 222 new, 222 total)
# ✓ Added example (buffer: 223 new, 223 total)
# ✓ Added example (buffer: 224 new, 224 total)
# ✓ Added example (buffer: 225 new, 225 total)
# ✓ Added example (buffer: 226 new, 226 total)
# ✓ Added example (buffer: 227 new, 227 total)
# ✓ Added example (buffer: 228 new, 228 total)
# ✓ Added example (buffer: 229 new, 229 total)
# ✓ Added example (buffer: 230 new, 230 total)
# ✓ Added example (buffer: 231 new, 231 total)
# ✓ Added example (buffer: 232 new, 232 total)
# ✓ Added example (buffer: 233 new, 233 total)
# ✓ Added example (buffer: 234 new, 234 total)
# ✓ Added example (buffer: 235 new, 235 total)
# ✓ Added example (buffer: 236 new, 236 total)
# ✓ Added example (buffer: 237 new, 237 total)
# ✓ Added example (buffer: 238 new, 238 total)
# ✓ Added example (buffer: 239 new, 239 total)
# ✓ Added example (buffer: 240 new, 240 total)
# ✓ Added example (buffer: 241 new, 241 total)
# ✓ Added example (buffer: 242 new, 242 total)
# ✓ Added example (buffer: 243 new, 243 total)
# ✓ Added example (buffer: 244 new, 244 total)
# ✓ Added example (buffer: 245 new, 245 total)
# ✓ Added example (buffer: 246 new, 246 total)
# ✓ Added example (buffer: 247 new, 247 total)
# ✓ Added example (buffer: 248 new, 248 total)
# ✓ Added example (buffer: 249 new, 249 total)
# ✓ Added example (buffer: 250 new, 250 total)
# ✓ Added example (buffer: 251 new, 251 total)
# ✓ Added example (buffer: 252 new, 252 total)
# ✓ Added example (buffer: 253 new, 253 total)
# ✓ Added example (buffer: 254 new, 254 total)
# ✓ Added example (buffer: 255 new, 255 total)
# ✓ Added example (buffer: 256 new, 256 total)
# ✓ Added example (buffer: 257 new, 257 total)
# ✓ Added example (buffer: 258 new, 258 total)
# ✓ Added example (buffer: 259 new, 259 total)
# ✓ Added example (buffer: 260 new, 260 total)
# ✓ Added example (buffer: 261 new, 261 total)
# ✓ Added example (buffer: 262 new, 262 total)
# ✓ Added example (buffer: 263 new, 263 total)
# ✓ Added example (buffer: 264 new, 264 total)
# ✓ Added example (buffer: 265 new, 265 total)
# ✓ Added example (buffer: 266 new, 266 total)
# ✓ Added example (buffer: 267 new, 267 total)
# ✓ Added example (buffer: 268 new, 268 total)
# ✓ Added example (buffer: 269 new, 269 total)
# ✓ Added example (buffer: 270 new, 270 total)
# ✓ Added example (buffer: 271 new, 271 total)
# ✓ Added example (buffer: 272 new, 272 total)
# ✓ Added example (buffer: 273 new, 273 total)
# ✓ Added example (buffer: 274 new, 274 total)
# ✓ Added example (buffer: 275 new, 275 total)
# ✓ Added example (buffer: 276 new, 276 total)
# ✓ Added example (buffer: 277 new, 277 total)
# ✓ Added example (buffer: 278 new, 278 total)
# ✓ Added example (buffer: 279 new, 279 total)
# ✓ Added example (buffer: 280 new, 280 total)
# ✓ Added example (buffer: 281 new, 281 total)
# ✓ Added example (buffer: 282 new, 282 total)
# ✓ Added example (buffer: 283 new, 283 total)
# ✓ Added example (buffer: 284 new, 284 total)
# ✓ Added example (buffer: 285 new, 285 total)
# ✓ Added example (buffer: 286 new, 286 total)
# ✓ Added example (buffer: 287 new, 287 total)
# ✓ Added example (buffer: 288 new, 288 total)
# ✓ Added example (buffer: 289 new, 289 total)
# ✓ Added example (buffer: 290 new, 290 total)
# ✓ Added example (buffer: 291 new, 291 total)
# ✓ Added example (buffer: 292 new, 292 total)
# ✓ Added example (buffer: 293 new, 293 total)
# ✓ Added example (buffer: 294 new, 294 total)
# ✓ Added example (buffer: 295 new, 295 total)
# ✓ Added example (buffer: 296 new, 296 total)
# ✓ Added example (buffer: 297 new, 297 total)
# ✓ Added example (buffer: 298 new, 298 total)
# ✓ Added example (buffer: 299 new, 299 total)
# ✓ Added example (buffer: 300 new, 300 total)
# ✓ Added example (buffer: 301 new, 301 total)
# ✓ Added example (buffer: 302 new, 302 total)
# ✓ Added example (buffer: 303 new, 303 total)
# ✓ Added example (buffer: 304 new, 304 total)
# ✓ Added example (buffer: 305 new, 305 total)
# ✓ Added example (buffer: 306 new, 306 total)
# ✓ Added example (buffer: 307 new, 307 total)
# ✓ Added example (buffer: 308 new, 308 total)
# ✓ Added example (buffer: 309 new, 309 total)
# ✓ Added example (buffer: 310 new, 310 total)
# ✓ Added example (buffer: 311 new, 311 total)
# ✓ Added example (buffer: 312 new, 312 total)
# ✓ Added example (buffer: 313 new, 313 total)
# ✓ Added example (buffer: 314 new, 314 total)
# ✓ Added example (buffer: 315 new, 315 total)
# ✓ Added example (buffer: 316 new, 316 total)
# ✓ Added example (buffer: 317 new, 317 total)
# ✓ Added example (buffer: 318 new, 318 total)
# ✓ Added example (buffer: 319 new, 319 total)
# ✓ Added example (buffer: 320 new, 320 total)
# ✓ Added example (buffer: 321 new, 321 total)
# ✓ Added example (buffer: 322 new, 322 total)
# ✓ Added example (buffer: 323 new, 323 total)
# ✓ Added example (buffer: 324 new, 324 total)
# ✓ Added example (buffer: 325 new, 325 total)
# ✓ Added example (buffer: 326 new, 326 total)
# ✓ Added example (buffer: 327 new, 327 total)
# ✓ Added example (buffer: 328 new, 328 total)
# ✓ Added example (buffer: 329 new, 329 total)
# ✓ Added example (buffer: 330 new, 330 total)
# ✓ Added example (buffer: 331 new, 331 total)
# ✓ Added example (buffer: 332 new, 332 total)
# ✓ Added example (buffer: 333 new, 333 total)
# ✓ Added example (buffer: 334 new, 334 total)
# ✓ Added example (buffer: 335 new, 335 total)
# ✓ Added example (buffer: 336 new, 336 total)
# ✓ Added example (buffer: 337 new, 337 total)
# ✓ Added example (buffer: 338 new, 338 total)
# ✓ Added example (buffer: 339 new, 339 total)
# ✓ Added example (buffer: 340 new, 340 total)
# ✓ Added example (buffer: 341 new, 341 total)
# ✓ Added example (buffer: 342 new, 342 total)
# ✓ Added example (buffer: 343 new, 343 total)
# ✓ Added example (buffer: 344 new, 344 total)
# ✓ Added example (buffer: 345 new, 345 total)
# ✓ Added example (buffer: 346 new, 346 total)
# ✓ Added example (buffer: 347 new, 347 total)
# ✓ Added example (buffer: 348 new, 348 total)
# ✓ Added example (buffer: 349 new, 349 total)
# ✓ Added example (buffer: 350 new, 350 total)
# ✓ Added example (buffer: 351 new, 351 total)
# ✓ Added example (buffer: 352 new, 352 total)
# ✓ Added example (buffer: 353 new, 353 total)
# ✓ Added example (buffer: 354 new, 354 total)
# ✓ Added example (buffer: 355 new, 355 total)
# ✓ Added example (buffer: 356 new, 356 total)
# ✓ Added example (buffer: 357 new, 357 total)
# ✓ Added example (buffer: 358 new, 358 total)
# ✓ Added example (buffer: 359 new, 359 total)
# ✓ Added example (buffer: 360 new, 360 total)
# ✓ Added example (buffer: 361 new, 361 total)
# ✓ Added example (buffer: 362 new, 362 total)
# ✓ Added example (buffer: 363 new, 363 total)
# ✓ Added example (buffer: 364 new, 364 total)
# ✓ Added example (buffer: 365 new, 365 total)
# ✓ Added example (buffer: 366 new, 366 total)
# ✓ Added example (buffer: 367 new, 367 total)
# ✓ Added example (buffer: 368 new, 368 total)
# ✓ Added example (buffer: 369 new, 369 total)
# ✓ Added example (buffer: 370 new, 370 total)
# ✓ Added example (buffer: 371 new, 371 total)
# ✓ Added example (buffer: 372 new, 372 total)
# ✓ Added example (buffer: 373 new, 373 total)
# ✓ Added example (buffer: 374 new, 374 total)
# ✓ Added example (buffer: 375 new, 375 total)
# ✓ Added example (buffer: 376 new, 376 total)
# ✓ Added example (buffer: 377 new, 377 total)
# ✓ Added example (buffer: 378 new, 378 total)
# ✓ Added example (buffer: 379 new, 379 total)
# ✓ Added example (buffer: 380 new, 380 total)
# ✓ Added example (buffer: 381 new, 381 total)
# ✓ Added example (buffer: 382 new, 382 total)
# ✓ Added example (buffer: 383 new, 383 total)
# ✓ Added example (buffer: 384 new, 384 total)
# ✓ Added example (buffer: 385 new, 385 total)
# ✓ Added example (buffer: 386 new, 386 total)
# ✓ Added example (buffer: 387 new, 387 total)
# ✓ Added example (buffer: 388 new, 388 total)
# ✓ Added example (buffer: 389 new, 389 total)
# ✓ Added example (buffer: 390 new, 390 total)
# ✓ Added example (buffer: 391 new, 391 total)
# ✓ Added example (buffer: 392 new, 392 total)
# ✓ Added example (buffer: 393 new, 393 total)
# ✓ Added example (buffer: 394 new, 394 total)
# ✓ Added example (buffer: 395 new, 395 total)
# ✓ Added example (buffer: 396 new, 396 total)
# ✓ Added example (buffer: 397 new, 397 total)
# ✓ Added example (buffer: 398 new, 398 total)
# ✓ Added example (buffer: 399 new, 399 total)
# ✓ Added example (buffer: 400 new, 400 total)
# ✓ Added example (buffer: 401 new, 401 total)
# ✓ Added example (buffer: 402 new, 402 total)
# ✓ Added example (buffer: 403 new, 403 total)
# ✓ Added example (buffer: 404 new, 404 total)
# ✓ Added example (buffer: 405 new, 405 total)
# ✓ Added example (buffer: 406 new, 406 total)
# ✓ Added example (buffer: 407 new, 407 total)
# ✓ Added example (buffer: 408 new, 408 total)
# ✓ Added example (buffer: 409 new, 409 total)
# ✓ Added example (buffer: 410 new, 410 total)
# ✓ Added example (buffer: 411 new, 411 total)
# ✓ Added example (buffer: 412 new, 412 total)
# ✓ Added example (buffer: 413 new, 413 total)
# ✓ Added example (buffer: 414 new, 414 total)
# ✓ Added example (buffer: 415 new, 415 total)
# ✓ Added example (buffer: 416 new, 416 total)
# ✓ Added example (buffer: 417 new, 417 total)
# ✓ Added example (buffer: 418 new, 418 total)
# ✓ Added example (buffer: 419 new, 419 total)
# ✓ Added example (buffer: 420 new, 420 total)
# ✓ Added example (buffer: 421 new, 421 total)
# ✓ Added example (buffer: 422 new, 422 total)
# ✓ Added example (buffer: 423 new, 423 total)
# ✓ Added example (buffer: 424 new, 424 total)
# ✓ Added example (buffer: 425 new, 425 total)
# ✓ Added example (buffer: 426 new, 426 total)
# ✓ Added example (buffer: 427 new, 427 total)
# ✓ Added example (buffer: 428 new, 428 total)
# ✓ Added example (buffer: 429 new, 429 total)
# ✓ Added example (buffer: 430 new, 430 total)
# ✓ Added example (buffer: 431 new, 431 total)
# ✓ Added example (buffer: 432 new, 432 total)
# ✓ Added example (buffer: 433 new, 433 total)
# ✓ Added example (buffer: 434 new, 434 total)
# ✓ Added example (buffer: 435 new, 435 total)
# ✓ Added example (buffer: 436 new, 436 total)
# ✓ Added example (buffer: 437 new, 437 total)
# ✓ Added example (buffer: 438 new, 438 total)
# ✓ Added example (buffer: 439 new, 439 total)
# ✓ Added example (buffer: 440 new, 440 total)
# ✓ Added example (buffer: 441 new, 441 total)
# ✓ Added example (buffer: 442 new, 442 total)
# ✓ Added example (buffer: 443 new, 443 total)
# ✓ Added example (buffer: 444 new, 444 total)
# ✓ Added example (buffer: 445 new, 445 total)
# ✓ Added example (buffer: 446 new, 446 total)
# ✓ Added example (buffer: 447 new, 447 total)
# ✓ Added example (buffer: 448 new, 448 total)
# ✓ Added example (buffer: 449 new, 449 total)
# ✓ Added example (buffer: 450 new, 450 total)
# ✓ Added example (buffer: 451 new, 451 total)
# ✓ Added example (buffer: 452 new, 452 total)
# ✓ Added example (buffer: 453 new, 453 total)
# ✓ Added example (buffer: 454 new, 454 total)
# ✓ Added example (buffer: 455 new, 455 total)
# ✓ Added example (buffer: 456 new, 456 total)
# ✓ Added example (buffer: 457 new, 457 total)
# ✓ Added example (buffer: 458 new, 458 total)
# ✓ Added example (buffer: 459 new, 459 total)
# ✓ Added example (buffer: 460 new, 460 total)
# ✓ Added example (buffer: 461 new, 461 total)
# ✓ Added example (buffer: 462 new, 462 total)
# ✓ Added example (buffer: 463 new, 463 total)
# ✓ Added example (buffer: 464 new, 464 total)
# ✓ Added example (buffer: 465 new, 465 total)
# ✓ Added example (buffer: 466 new, 466 total)
# ✓ Added example (buffer: 467 new, 467 total)
# ✓ Added example (buffer: 468 new, 468 total)
# ✓ Added example (buffer: 469 new, 469 total)
# ✓ Added example (buffer: 470 new, 470 total)
# ✓ Added example (buffer: 471 new, 471 total)
# ✓ Added example (buffer: 472 new, 472 total)
# ✓ Added example (buffer: 473 new, 473 total)
# ✓ Added example (buffer: 474 new, 474 total)
# ✓ Added example (buffer: 475 new, 475 total)
# ✓ Added example (buffer: 476 new, 476 total)
# ✓ Added example (buffer: 477 new, 477 total)
# ✓ Added example (buffer: 478 new, 478 total)
# ✓ Added example (buffer: 479 new, 479 total)
# ✓ Added example (buffer: 480 new, 480 total)
# ✓ Added example (buffer: 481 new, 481 total)
# ✓ Added example (buffer: 482 new, 482 total)
# ✓ Added example (buffer: 483 new, 483 total)
# ✓ Added example (buffer: 484 new, 484 total)
# ✓ Added example (buffer: 485 new, 485 total)
# ✓ Added example (buffer: 486 new, 486 total)
# ✓ Added example (buffer: 487 new, 487 total)
# ✓ Added example (buffer: 488 new, 488 total)
# ✓ Added example (buffer: 489 new, 489 total)
# ✓ Added example (buffer: 490 new, 490 total)
# ✓ Added example (buffer: 491 new, 491 total)
# ✓ Added example (buffer: 492 new, 492 total)
# ✓ Added example (buffer: 493 new, 493 total)
# ✓ Added example (buffer: 494 new, 494 total)
# ✓ Added example (buffer: 495 new, 495 total)
# ✓ Added example (buffer: 496 new, 496 total)
# ✓ Added example (buffer: 497 new, 497 total)
# ✓ Added example (buffer: 498 new, 498 total)
# ✓ Added example (buffer: 499 new, 499 total)
# ✓ Added example (buffer: 500 new, 500 total)
# ✓ Added example (buffer: 501 new, 501 total)
# ✓ Added example (buffer: 502 new, 502 total)
# ✓ Added example (buffer: 503 new, 503 total)
# ✓ Added example (buffer: 504 new, 504 total)
# ✓ Added example (buffer: 505 new, 505 total)
# ✓ Added example (buffer: 506 new, 506 total)
# ✓ Added example (buffer: 507 new, 507 total)
# ✓ Added example (buffer: 508 new, 508 total)
# ✓ Added example (buffer: 509 new, 509 total)
# ✓ Added example (buffer: 510 new, 510 total)
# ✓ Added example (buffer: 511 new, 511 total)
# ✓ Added example (buffer: 512 new, 512 total)
# ✓ Added example (buffer: 513 new, 513 total)
# ✓ Added example (buffer: 514 new, 514 total)
# ✓ Added example (buffer: 515 new, 515 total)
# ✓ Added example (buffer: 516 new, 516 total)
# ✓ Added example (buffer: 517 new, 517 total)
# ✓ Added example (buffer: 518 new, 518 total)
# ✓ Added example (buffer: 519 new, 519 total)
# ✓ Added example (buffer: 520 new, 520 total)
# ✓ Added example (buffer: 521 new, 521 total)
# ✓ Added example (buffer: 522 new, 522 total)
# ✓ Added example (buffer: 523 new, 523 total)
# ✓ Added example (buffer: 524 new, 524 total)
# ✓ Added example (buffer: 525 new, 525 total)
# ✓ Added example (buffer: 526 new, 526 total)
# ✓ Added example (buffer: 527 new, 527 total)
# ✓ Added example (buffer: 528 new, 528 total)
# ✓ Added example (buffer: 529 new, 529 total)
# ✓ Added example (buffer: 530 new, 530 total)
# ✓ Added example (buffer: 531 new, 531 total)
# ✓ Added example (buffer: 532 new, 532 total)
# ✓ Added example (buffer: 533 new, 533 total)
# ✓ Added example (buffer: 534 new, 534 total)
# ✓ Added example (buffer: 535 new, 535 total)
# ✓ Added example (buffer: 536 new, 536 total)
# ✓ Added example (buffer: 537 new, 537 total)
# ✓ Added example (buffer: 538 new, 538 total)
# ✓ Added example (buffer: 539 new, 539 total)
# ✓ Added example (buffer: 540 new, 540 total)
# ✓ Added example (buffer: 541 new, 541 total)
# ✓ Added example (buffer: 542 new, 542 total)
# ✓ Added example (buffer: 543 new, 543 total)
# ✓ Added example (buffer: 544 new, 544 total)
# ✓ Added example (buffer: 545 new, 545 total)
# ✓ Added example (buffer: 546 new, 546 total)
# ✓ Added example (buffer: 547 new, 547 total)
# ✓ Added example (buffer: 548 new, 548 total)
# ✓ Added example (buffer: 549 new, 549 total)
# ✓ Added example (buffer: 550 new, 550 total)
# ✓ Added example (buffer: 551 new, 551 total)
# ✓ Added example (buffer: 552 new, 552 total)
# ✓ Added example (buffer: 553 new, 553 total)
# ✓ Added example (buffer: 554 new, 554 total)
# ✓ Added example (buffer: 555 new, 555 total)
# ✓ Added example (buffer: 556 new, 556 total)
# ✓ Added example (buffer: 557 new, 557 total)
# ✓ Added example (buffer: 558 new, 558 total)
# ✓ Added example (buffer: 559 new, 559 total)
# ✓ Added example (buffer: 560 new, 560 total)
# ✓ Added example (buffer: 561 new, 561 total)
# ✓ Added example (buffer: 562 new, 562 total)
# ✓ Added example (buffer: 563 new, 563 total)
# ✓ Added example (buffer: 564 new, 564 total)
# ✓ Added example (buffer: 565 new, 565 total)
# ✓ Added example (buffer: 566 new, 566 total)
# ✓ Added example (buffer: 567 new, 567 total)
# ✓ Added example (buffer: 568 new, 568 total)
# ✓ Added example (buffer: 569 new, 569 total)
# ✓ Added example (buffer: 570 new, 570 total)
# ✓ Added example (buffer: 571 new, 571 total)
# ✓ Added example (buffer: 572 new, 572 total)
# ✓ Added example (buffer: 573 new, 573 total)
# ✓ Added example (buffer: 574 new, 574 total)
# ✓ Added example (buffer: 575 new, 575 total)
# ✓ Added example (buffer: 576 new, 576 total)
# ✓ Added example (buffer: 577 new, 577 total)
# ✓ Added example (buffer: 578 new, 578 total)
# ✓ Added example (buffer: 579 new, 579 total)
# ✓ Added example (buffer: 580 new, 580 total)
# ✓ Added example (buffer: 581 new, 581 total)
# ✓ Added example (buffer: 582 new, 582 total)
# ✓ Added example (buffer: 583 new, 583 total)
# ✓ Added example (buffer: 584 new, 584 total)
# ✓ Added example (buffer: 585 new, 585 total)
# ✓ Added example (buffer: 586 new, 586 total)
# ✓ Added example (buffer: 587 new, 587 total)
# ✓ Added example (buffer: 588 new, 588 total)
# ✓ Added example (buffer: 589 new, 589 total)
# ✓ Added example (buffer: 590 new, 590 total)
# ✓ Added example (buffer: 591 new, 591 total)
# ✓ Added example (buffer: 592 new, 592 total)
# ✓ Added example (buffer: 593 new, 593 total)
# ✓ Added example (buffer: 594 new, 594 total)
# ✓ Added example (buffer: 595 new, 595 total)
# ✓ Added example (buffer: 596 new, 596 total)
# ✓ Added example (buffer: 597 new, 597 total)
# ✓ Added example (buffer: 598 new, 598 total)
# ✓ Added example (buffer: 599 new, 599 total)
# ✓ Added example (buffer: 600 new, 600 total)
# ✓ Added example (buffer: 601 new, 601 total)
# ✓ Added example (buffer: 602 new, 602 total)
# ✓ Added example (buffer: 603 new, 603 total)
# ✓ Added example (buffer: 604 new, 604 total)
# ✓ Added example (buffer: 605 new, 605 total)
# ✓ Added example (buffer: 606 new, 606 total)
# ✓ Added example (buffer: 607 new, 607 total)
# ✓ Added example (buffer: 608 new, 608 total)
# ✓ Added example (buffer: 609 new, 609 total)
# ✓ Added example (buffer: 610 new, 610 total)
# ✓ Added example (buffer: 611 new, 611 total)
# ✓ Added example (buffer: 612 new, 612 total)
# ✓ Added example (buffer: 613 new, 613 total)
# ✓ Added example (buffer: 614 new, 614 total)
# ✓ Added example (buffer: 615 new, 615 total)
# ✓ Added example (buffer: 616 new, 616 total)
# ✓ Added example (buffer: 617 new, 617 total)
# ✓ Added example (buffer: 618 new, 618 total)
# ✓ Added example (buffer: 619 new, 619 total)
# ✓ Added example (buffer: 620 new, 620 total)
# ✓ Added example (buffer: 621 new, 621 total)
# ✓ Added example (buffer: 622 new, 622 total)
# ✓ Added example (buffer: 623 new, 623 total)
# ✓ Added example (buffer: 624 new, 624 total)
# ✓ Added example (buffer: 625 new, 625 total)
# ✓ Added example (buffer: 626 new, 626 total)
# ✓ Added example (buffer: 627 new, 627 total)
# ✓ Added example (buffer: 628 new, 628 total)
# ✓ Added example (buffer: 629 new, 629 total)
# ✓ Added example (buffer: 630 new, 630 total)
# ✓ Added example (buffer: 631 new, 631 total)
# ✓ Added example (buffer: 632 new, 632 total)
# ✓ Added example (buffer: 633 new, 633 total)
# ✓ Added example (buffer: 634 new, 634 total)
# ✓ Added example (buffer: 635 new, 635 total)
# ✓ Added example (buffer: 636 new, 636 total)
# ✓ Added example (buffer: 637 new, 637 total)
# ✓ Added example (buffer: 638 new, 638 total)
# ✓ Added example (buffer: 639 new, 639 total)
# ✓ Added example (buffer: 640 new, 640 total)
# ✓ Added example (buffer: 641 new, 641 total)
# ✓ Added example (buffer: 642 new, 642 total)
# ✓ Added example (buffer: 643 new, 643 total)
# ✓ Added example (buffer: 644 new, 644 total)
# ✓ Added example (buffer: 645 new, 645 total)
# ✓ Added example (buffer: 646 new, 646 total)
# ✓ Added example (buffer: 647 new, 647 total)
# ✓ Added example (buffer: 648 new, 648 total)
# ✓ Added example (buffer: 649 new, 649 total)
# ✓ Added example (buffer: 650 new, 650 total)
# ✓ Added example (buffer: 651 new, 651 total)
# ✓ Added example (buffer: 652 new, 652 total)
# ✓ Added example (buffer: 653 new, 653 total)
# ✓ Added example (buffer: 654 new, 654 total)
# ✓ Added example (buffer: 655 new, 655 total)
# ✓ Added example (buffer: 656 new, 656 total)
# ✓ Added example (buffer: 657 new, 657 total)
# ✓ Added example (buffer: 658 new, 658 total)
# ✓ Added example (buffer: 659 new, 659 total)
# ✓ Added example (buffer: 660 new, 660 total)
# ✓ Added example (buffer: 661 new, 661 total)
# ✓ Added example (buffer: 662 new, 662 total)
# ✓ Added example (buffer: 663 new, 663 total)
# ✓ Added example (buffer: 664 new, 664 total)
# ✓ Added example (buffer: 665 new, 665 total)
# ✓ Added example (buffer: 666 new, 666 total)
# ✓ Added example (buffer: 667 new, 667 total)
# ✓ Added example (buffer: 668 new, 668 total)
# ✓ Added example (buffer: 669 new, 669 total)
# ✓ Added example (buffer: 670 new, 670 total)
# ✓ Added example (buffer: 671 new, 671 total)
# ✓ Added example (buffer: 672 new, 672 total)
# ✓ Added example (buffer: 673 new, 673 total)
# ✓ Added example (buffer: 674 new, 674 total)
# ✓ Added example (buffer: 675 new, 675 total)
# ✓ Added example (buffer: 676 new, 676 total)
# ✓ Added example (buffer: 677 new, 677 total)
# ✓ Added example (buffer: 678 new, 678 total)
# ✓ Added example (buffer: 679 new, 679 total)
# ✓ Added example (buffer: 680 new, 680 total)
# ✓ Added example (buffer: 681 new, 681 total)
# ✓ Added example (buffer: 682 new, 682 total)
# ✓ Added example (buffer: 683 new, 683 total)
# ✓ Added example (buffer: 684 new, 684 total)
# ✓ Added example (buffer: 685 new, 685 total)
# ✓ Added example (buffer: 686 new, 686 total)
# ✓ Added example (buffer: 687 new, 687 total)
# ✓ Added example (buffer: 688 new, 688 total)
# ✓ Added example (buffer: 689 new, 689 total)
# ✓ Added example (buffer: 690 new, 690 total)
# ✓ Added example (buffer: 691 new, 691 total)
# ✓ Added example (buffer: 692 new, 692 total)
# ✓ Added example (buffer: 693 new, 693 total)
# ✓ Added example (buffer: 694 new, 694 total)
# ✓ Added example (buffer: 695 new, 695 total)
# ✓ Added example (buffer: 696 new, 696 total)
# ✓ Added example (buffer: 697 new, 697 total)
# ✓ Added example (buffer: 698 new, 698 total)
# ✓ Added example (buffer: 699 new, 699 total)
# ✓ Added example (buffer: 700 new, 700 total)
# ✓ Added example (buffer: 701 new, 701 total)
# ✓ Added example (buffer: 702 new, 702 total)
# ✓ Added example (buffer: 703 new, 703 total)
# ✓ Added example (buffer: 704 new, 704 total)
# ✓ Added example (buffer: 705 new, 705 total)
# ✓ Added example (buffer: 706 new, 706 total)
# ✓ Added example (buffer: 707 new, 707 total)
# ✓ Added example (buffer: 708 new, 708 total)
# ✓ Added example (buffer: 709 new, 709 total)
# ✓ Added example (buffer: 710 new, 710 total)
# ✓ Added example (buffer: 711 new, 711 total)
# ✓ Added example (buffer: 712 new, 712 total)
# ✓ Added example (buffer: 713 new, 713 total)
# ✓ Added example (buffer: 714 new, 714 total)
# ✓ Added example (buffer: 715 new, 715 total)
# ✓ Added example (buffer: 716 new, 716 total)
# ✓ Added example (buffer: 717 new, 717 total)
# ✓ Added example (buffer: 718 new, 718 total)
# ✓ Added example (buffer: 719 new, 719 total)
# ✓ Added example (buffer: 720 new, 720 total)
# ✓ Added example (buffer: 721 new, 721 total)
# ✓ Added example (buffer: 722 new, 722 total)
# ✓ Added example (buffer: 723 new, 723 total)
# ✓ Added example (buffer: 724 new, 724 total)
# ✓ Added example (buffer: 725 new, 725 total)
# ✓ Added example (buffer: 726 new, 726 total)
# ✓ Added example (buffer: 727 new, 727 total)
# ✓ Added example (buffer: 728 new, 728 total)
# ✓ Added example (buffer: 729 new, 729 total)
# ✓ Added example (buffer: 730 new, 730 total)
# ✓ Added example (buffer: 731 new, 731 total)
# ✓ Added example (buffer: 732 new, 732 total)
# ✓ Added example (buffer: 733 new, 733 total)
# ✓ Added example (buffer: 734 new, 734 total)
# ✓ Added example (buffer: 735 new, 735 total)
# ✓ Added example (buffer: 736 new, 736 total)
# ✓ Added example (buffer: 737 new, 737 total)
# ✓ Added example (buffer: 738 new, 738 total)
# ✓ Added example (buffer: 739 new, 739 total)
# ✓ Added example (buffer: 740 new, 740 total)
# ✓ Added example (buffer: 741 new, 741 total)
# ✓ Added example (buffer: 742 new, 742 total)
# ✓ Added example (buffer: 743 new, 743 total)
# ✓ Added example (buffer: 744 new, 744 total)
# ✓ Added example (buffer: 745 new, 745 total)
# ✓ Added example (buffer: 746 new, 746 total)
# ✓ Added example (buffer: 747 new, 747 total)
# ✓ Added example (buffer: 748 new, 748 total)
# ✓ Added example (buffer: 749 new, 749 total)
# ✓ Added example (buffer: 750 new, 750 total)
# ✓ Added example (buffer: 751 new, 751 total)
# ✓ Added example (buffer: 752 new, 752 total)
# ✓ Added example (buffer: 753 new, 753 total)
# ✓ Added example (buffer: 754 new, 754 total)
# ✓ Added example (buffer: 755 new, 755 total)
# ✓ Added example (buffer: 756 new, 756 total)
# ✓ Added example (buffer: 757 new, 757 total)
# ✓ Added example (buffer: 758 new, 758 total)
# ✓ Added example (buffer: 759 new, 759 total)
# ✓ Added example (buffer: 760 new, 760 total)
# ✓ Added example (buffer: 761 new, 761 total)
# ✓ Added example (buffer: 762 new, 762 total)
# ✓ Added example (buffer: 763 new, 763 total)
# ✓ Added example (buffer: 764 new, 764 total)
# ✓ Added example (buffer: 765 new, 765 total)
# ✓ Added example (buffer: 766 new, 766 total)
# ✓ Added example (buffer: 767 new, 767 total)
# ✓ Added example (buffer: 768 new, 768 total)
# ✓ Added example (buffer: 769 new, 769 total)
# ✓ Added example (buffer: 770 new, 770 total)
# ✓ Added example (buffer: 771 new, 771 total)
# ✓ Added example (buffer: 772 new, 772 total)
# ✓ Added example (buffer: 773 new, 773 total)
# ✓ Added example (buffer: 774 new, 774 total)
# ✓ Added example (buffer: 775 new, 775 total)
# ✓ Added example (buffer: 776 new, 776 total)
# ✓ Added example (buffer: 777 new, 777 total)
# ✓ Added example (buffer: 778 new, 778 total)
# ✓ Added example (buffer: 779 new, 779 total)
# ✓ Added example (buffer: 780 new, 780 total)
# ✓ Added example (buffer: 781 new, 781 total)
# ✓ Added example (buffer: 782 new, 782 total)
# ✓ Added example (buffer: 783 new, 783 total)
# ✓ Added example (buffer: 784 new, 784 total)
# ✓ Added example (buffer: 785 new, 785 total)
# ✓ Added example (buffer: 786 new, 786 total)
# ✓ Added example (buffer: 787 new, 787 total)
# ✓ Added example (buffer: 788 new, 788 total)
# ✓ Added example (buffer: 789 new, 789 total)
# ✓ Added example (buffer: 790 new, 790 total)
# ✓ Added example (buffer: 791 new, 791 total)
# ✓ Added example (buffer: 792 new, 792 total)
# ✓ Added example (buffer: 793 new, 793 total)
# ✓ Added example (buffer: 794 new, 794 total)
# ✓ Added example (buffer: 795 new, 795 total)
# ✓ Added example (buffer: 796 new, 796 total)
# ✓ Added example (buffer: 797 new, 797 total)
# ✓ Added example (buffer: 798 new, 798 total)
# ✓ Added example (buffer: 799 new, 799 total)
# ✓ Added example (buffer: 800 new, 800 total)
# ✓ Added example (buffer: 801 new, 801 total)
# ✓ Added example (buffer: 802 new, 802 total)
# ✓ Added example (buffer: 803 new, 803 total)
# ✓ Added example (buffer: 804 new, 804 total)
# ✓ Added example (buffer: 805 new, 805 total)
# ✓ Added example (buffer: 806 new, 806 total)
# ✓ Added example (buffer: 807 new, 807 total)
# ✓ Added example (buffer: 808 new, 808 total)
# ✓ Added example (buffer: 809 new, 809 total)
# ✓ Added example (buffer: 810 new, 810 total)
# ✓ Added example (buffer: 811 new, 811 total)
# ✓ Added example (buffer: 812 new, 812 total)
# ✓ Added example (buffer: 813 new, 813 total)
# ✓ Added example (buffer: 814 new, 814 total)
# ✓ Added example (buffer: 815 new, 815 total)
# ✓ Added example (buffer: 816 new, 816 total)
# ✓ Added example (buffer: 817 new, 817 total)
# ✓ Added example (buffer: 818 new, 818 total)
# ✓ Added example (buffer: 819 new, 819 total)
# ✓ Added example (buffer: 820 new, 820 total)
# ✓ Added example (buffer: 821 new, 821 total)
# ✓ Added example (buffer: 822 new, 822 total)
# ✓ Added example (buffer: 823 new, 823 total)
# ✓ Added example (buffer: 824 new, 824 total)
# ✓ Added example (buffer: 825 new, 825 total)
# ✓ Added example (buffer: 826 new, 826 total)
# ✓ Added example (buffer: 827 new, 827 total)
# ✓ Added example (buffer: 828 new, 828 total)
# ✓ Added example (buffer: 829 new, 829 total)
# ✓ Added example (buffer: 830 new, 830 total)
# ✓ Added example (buffer: 831 new, 831 total)
# ✓ Added example (buffer: 832 new, 832 total)
# ✓ Added example (buffer: 833 new, 833 total)
# ✓ Added example (buffer: 834 new, 834 total)
# ✓ Added example (buffer: 835 new, 835 total)
# ✓ Added example (buffer: 836 new, 836 total)
# ✓ Added example (buffer: 837 new, 837 total)
# ✓ Added example (buffer: 838 new, 838 total)
# ✓ Added example (buffer: 839 new, 839 total)
# ✓ Added example (buffer: 840 new, 840 total)
# ✓ Added example (buffer: 841 new, 841 total)
# ✓ Added example (buffer: 842 new, 842 total)
# ✓ Added example (buffer: 843 new, 843 total)
# ✓ Added example (buffer: 844 new, 844 total)
# ✓ Added example (buffer: 845 new, 845 total)
# ✓ Added example (buffer: 846 new, 846 total)
# ✓ Added example (buffer: 847 new, 847 total)
# ✓ Added example (buffer: 848 new, 848 total)
# ✓ Added example (buffer: 849 new, 849 total)
# ✓ Added example (buffer: 850 new, 850 total)
# ✓ Added example (buffer: 851 new, 851 total)
# ✓ Added example (buffer: 852 new, 852 total)
# ✓ Added example (buffer: 853 new, 853 total)
# ✓ Added example (buffer: 854 new, 854 total)
# ✓ Added example (buffer: 855 new, 855 total)
# ✓ Added example (buffer: 856 new, 856 total)
# ✓ Added example (buffer: 857 new, 857 total)
# ✓ Added example (buffer: 858 new, 858 total)
# ✓ Added example (buffer: 859 new, 859 total)
# ✓ Added example (buffer: 860 new, 860 total)
# ✓ Added example (buffer: 861 new, 861 total)
# ✓ Added example (buffer: 862 new, 862 total)
# ✓ Added example (buffer: 863 new, 863 total)
# ✓ Added example (buffer: 864 new, 864 total)
# ✓ Added example (buffer: 865 new, 865 total)
# ✓ Added example (buffer: 866 new, 866 total)
# ✓ Added example (buffer: 867 new, 867 total)
# ✓ Added example (buffer: 868 new, 868 total)
# ✓ Added example (buffer: 869 new, 869 total)
# ✓ Added example (buffer: 870 new, 870 total)
# ✓ Added example (buffer: 871 new, 871 total)
# ✓ Added example (buffer: 872 new, 872 total)
# ✓ Added example (buffer: 873 new, 873 total)
# ✓ Added example (buffer: 874 new, 874 total)
# ✓ Added example (buffer: 875 new, 875 total)
# ✓ Added example (buffer: 876 new, 876 total)
# ✓ Added example (buffer: 877 new, 877 total)
# ✓ Added example (buffer: 878 new, 878 total)
# ✓ Added example (buffer: 879 new, 879 total)
# ✓ Added example (buffer: 880 new, 880 total)
# ✓ Added example (buffer: 881 new, 881 total)
# ✓ Added example (buffer: 882 new, 882 total)
# ✓ Added example (buffer: 883 new, 883 total)
# ✓ Added example (buffer: 884 new, 884 total)
# ✓ Added example (buffer: 885 new, 885 total)
# ✓ Added example (buffer: 886 new, 886 total)
# ✓ Added example (buffer: 887 new, 887 total)
# ✓ Added example (buffer: 888 new, 888 total)
# ✓ Added example (buffer: 889 new, 889 total)
# ✓ Added example (buffer: 890 new, 890 total)
# ✓ Added example (buffer: 891 new, 891 total)
# ✓ Added example (buffer: 892 new, 892 total)
# ✓ Added example (buffer: 893 new, 893 total)
# ✓ Added example (buffer: 894 new, 894 total)
# ✓ Added example (buffer: 895 new, 895 total)
# ✓ Added example (buffer: 896 new, 896 total)
# ✓ Added example (buffer: 897 new, 897 total)
# ✓ Added example (buffer: 898 new, 898 total)
# ✓ Added example (buffer: 899 new, 899 total)
# ✓ Added example (buffer: 900 new, 900 total)
# ✓ Added example (buffer: 901 new, 901 total)
# ✓ Added example (buffer: 902 new, 902 total)
# ✓ Added example (buffer: 903 new, 903 total)
# ✓ Added example (buffer: 904 new, 904 total)
# ✓ Added example (buffer: 905 new, 905 total)
# ✓ Added example (buffer: 906 new, 906 total)
# ✓ Added example (buffer: 907 new, 907 total)
# ✓ Added example (buffer: 908 new, 908 total)
# ✓ Added example (buffer: 909 new, 909 total)
# ✓ Added example (buffer: 910 new, 910 total)
# ✓ Added example (buffer: 911 new, 911 total)
# ✓ Added example (buffer: 912 new, 912 total)
# ✓ Added example (buffer: 913 new, 913 total)
# ✓ Added example (buffer: 914 new, 914 total)
# ✓ Added example (buffer: 915 new, 915 total)
# ✓ Added example (buffer: 916 new, 916 total)
# ✓ Added example (buffer: 917 new, 917 total)
# ✓ Added example (buffer: 918 new, 918 total)
# ✓ Added example (buffer: 919 new, 919 total)
# ✓ Added example (buffer: 920 new, 920 total)
# ✓ Added example (buffer: 921 new, 921 total)
# ✓ Added example (buffer: 922 new, 922 total)
# ✓ Added example (buffer: 923 new, 923 total)
# ✓ Added example (buffer: 924 new, 924 total)
# ✓ Added example (buffer: 925 new, 925 total)
# ✓ Added example (buffer: 926 new, 926 total)
# ✓ Added example (buffer: 927 new, 927 total)
# ✓ Added example (buffer: 928 new, 928 total)
# ✓ Added example (buffer: 929 new, 929 total)
# ✓ Added example (buffer: 930 new, 930 total)
# ✓ Added example (buffer: 931 new, 931 total)
# ✓ Added example (buffer: 932 new, 932 total)
# ✓ Added example (buffer: 933 new, 933 total)
# ✓ Added example (buffer: 934 new, 934 total)
# ✓ Added example (buffer: 935 new, 935 total)
# ✓ Added example (buffer: 936 new, 936 total)
# ✓ Added example (buffer: 937 new, 937 total)
# ✓ Added example (buffer: 938 new, 938 total)
# ✓ Added example (buffer: 939 new, 939 total)
# ✓ Added example (buffer: 940 new, 940 total)
# ✓ Added example (buffer: 941 new, 941 total)
# ✓ Added example (buffer: 942 new, 942 total)
# ✓ Added example (buffer: 943 new, 943 total)
# ✓ Added example (buffer: 944 new, 944 total)
# ✓ Added example (buffer: 945 new, 945 total)
# ✓ Added example (buffer: 946 new, 946 total)
# ✓ Added example (buffer: 947 new, 947 total)
# ✓ Added example (buffer: 948 new, 948 total)
# ✓ Added example (buffer: 949 new, 949 total)
# ✓ Added example (buffer: 950 new, 950 total)
# ✓ Added example (buffer: 951 new, 951 total)
# ✓ Added example (buffer: 952 new, 952 total)
# ✓ Added example (buffer: 953 new, 953 total)
# ✓ Added example (buffer: 954 new, 954 total)
# ✓ Added example (buffer: 955 new, 955 total)
# ✓ Added example (buffer: 956 new, 956 total)
# ✓ Added example (buffer: 957 new, 957 total)
# ✓ Added example (buffer: 958 new, 958 total)
# ✓ Added example (buffer: 959 new, 959 total)
# ✓ Added example (buffer: 960 new, 960 total)
# ✓ Added example (buffer: 961 new, 961 total)
# ✓ Added example (buffer: 962 new, 962 total)
# ✓ Added example (buffer: 963 new, 963 total)
# ✓ Added example (buffer: 964 new, 964 total)
# ✓ Added example (buffer: 965 new, 965 total)
# ✓ Added example (buffer: 966 new, 966 total)
# ✓ Added example (buffer: 967 new, 967 total)
# ✓ Added example (buffer: 968 new, 968 total)
# ✓ Added example (buffer: 969 new, 969 total)
# ✓ Added example (buffer: 970 new, 970 total)
# ✓ Added example (buffer: 971 new, 971 total)
# ✓ Added example (buffer: 972 new, 972 total)
# ✓ Added example (buffer: 973 new, 973 total)
# ✓ Added example (buffer: 974 new, 974 total)
# ✓ Added example (buffer: 975 new, 975 total)
# ✓ Added example (buffer: 976 new, 976 total)
# ✓ Added example (buffer: 977 new, 977 total)
# ✓ Added example (buffer: 978 new, 978 total)
# ✓ Added example (buffer: 979 new, 979 total)
# ✓ Added example (buffer: 980 new, 980 total)
# ✓ Added example (buffer: 981 new, 981 total)
# ✓ Added example (buffer: 982 new, 982 total)
# ✓ Added example (buffer: 983 new, 983 total)
# ✓ Added example (buffer: 984 new, 984 total)
# ✓ Added example (buffer: 985 new, 985 total)
# ✓ Added example (buffer: 986 new, 986 total)
# ✓ Added example (buffer: 987 new, 987 total)
# ✓ Added example (buffer: 988 new, 988 total)
# ✓ Added example (buffer: 989 new, 989 total)
# ✓ Added example (buffer: 990 new, 990 total)
# ✓ Added example (buffer: 991 new, 991 total)
# ✓ Added example (buffer: 992 new, 992 total)
# ✓ Added example (buffer: 993 new, 993 total)
# ✓ Added example (buffer: 994 new, 994 total)
# ✓ Added example (buffer: 995 new, 995 total)
# ✓ Added example (buffer: 996 new, 996 total)
# ✓ Added example (buffer: 997 new, 997 total)
# ✓ Added example (buffer: 998 new, 998 total)
# ✓ Added example (buffer: 999 new, 999 total)
# ✓ Added example (buffer: 1000 new, 1000 total)
# ✓ Added example (buffer: 1001 new, 1001 total)
# ✓ Added example (buffer: 1002 new, 1002 total)
# ✓ Added example (buffer: 1003 new, 1003 total)
# ✓ Added example (buffer: 1004 new, 1004 total)
# ✓ Added example (buffer: 1005 new, 1005 total)
# ✓ Added example (buffer: 1006 new, 1006 total)
# ✓ Added example (buffer: 1007 new, 1007 total)
# ✓ Added example (buffer: 1008 new, 1008 total)
# ✓ Added example (buffer: 1009 new, 1009 total)
# ✓ Added example (buffer: 1010 new, 1010 total)
# ✓ Added example (buffer: 1011 new, 1011 total)
# ✓ Added example (buffer: 1012 new, 1012 total)
# ✓ Added example (buffer: 1013 new, 1013 total)
# ✓ Added example (buffer: 1014 new, 1014 total)
# ✓ Added example (buffer: 1015 new, 1015 total)
# ✓ Added example (buffer: 1016 new, 1016 total)
# ✓ Added example (buffer: 1017 new, 1017 total)
# ✓ Added example (buffer: 1018 new, 1018 total)
# ✓ Added example (buffer: 1019 new, 1019 total)
# ✓ Added example (buffer: 1020 new, 1020 total)
# ✓ Added example (buffer: 1021 new, 1021 total)
# ✓ Added example (buffer: 1022 new, 1022 total)
# ✓ Added example (buffer: 1023 new, 1023 total)
# ✓ Added example (buffer: 1024 new, 1024 total)
# ✓ Added example (buffer: 1025 new, 1025 total)
# ✓ Added example (buffer: 1026 new, 1026 total)
# ✓ Added example (buffer: 1027 new, 1027 total)
# ✓ Added example (buffer: 1028 new, 1028 total)
# ✓ Added example (buffer: 1029 new, 1029 total)
# ✓ Added example (buffer: 1030 new, 1030 total)
# ✓ Added example (buffer: 1031 new, 1031 total)
# ✓ Added example (buffer: 1032 new, 1032 total)
# ✓ Added example (buffer: 1033 new, 1033 total)
# ✓ Added example (buffer: 1034 new, 1034 total)
# ✓ Added example (buffer: 1035 new, 1035 total)
# ✓ Added example (buffer: 1036 new, 1036 total)
# ✓ Added example (buffer: 1037 new, 1037 total)
# ✓ Added example (buffer: 1038 new, 1038 total)
# ✓ Added example (buffer: 1039 new, 1039 total)
# ✓ Added example (buffer: 1040 new, 1040 total)
# ✓ Added example (buffer: 1041 new, 1041 total)
# ✓ Added example (buffer: 1042 new, 1042 total)
# ✓ Added example (buffer: 1043 new, 1043 total)
# ✓ Added example (buffer: 1044 new, 1044 total)
# ✓ Added example (buffer: 1045 new, 1045 total)
# ✓ Added example (buffer: 1046 new, 1046 total)
# ✓ Added example (buffer: 1047 new, 1047 total)
# ✓ Added example (buffer: 1048 new, 1048 total)
# ✓ Added example (buffer: 1049 new, 1049 total)
# ✓ Added example (buffer: 1050 new, 1050 total)
# ✓ Added example (buffer: 1051 new, 1051 total)
# ✓ Added example (buffer: 1052 new, 1052 total)
# ✓ Added example (buffer: 1053 new, 1053 total)
# ✓ Added example (buffer: 1054 new, 1054 total)
# ✓ Added example (buffer: 1055 new, 1055 total)
# ✓ Added example (buffer: 1056 new, 1056 total)
# ✓ Added example (buffer: 1057 new, 1057 total)
# ✓ Added example (buffer: 1058 new, 1058 total)
# ✓ Added example (buffer: 1059 new, 1059 total)
# ✓ Added example (buffer: 1060 new, 1060 total)
# ✓ Added example (buffer: 1061 new, 1061 total)
# ✓ Added example (buffer: 1062 new, 1062 total)
# ✓ Added example (buffer: 1063 new, 1063 total)
# ✓ Added example (buffer: 1064 new, 1064 total)
# ✓ Added example (buffer: 1065 new, 1065 total)
# ✓ Added example (buffer: 1066 new, 1066 total)
# ...
#
# Input: {"text": "I. Die Kl\u00e4gerin und Beschwerdef\u00fchrerin ( Kl\u00e4gerin ) , eine GmbH , ist nach mehreren Vorg\u00e4ngen Rechtsnachfolgerin der A ."}
# Output: {"entities": [{"text": "A", "start": 117, "end": 118, "type": "ORG"}]}
#
# Input: {"text": "Er selbst sehe sich auch angesichts der in seinem damaligen politischen Amt vorgenommenen und - soweit verfahrensrelevant - mehr als zehn Jahre zur\u00fcckliegenden Positionierungen in der Lage , der Erwartung des Verfassungs- und Gesetzgebers zu entsprechen , seine Aufgabe als Richter des Bundesverfassungsgerichts im vorliegenden Fall unvoreingenommen und unabh\u00e4ngig von seiner fr\u00fcheren politischen T\u00e4tigkeit wahrzunehmen ."}
# Output: {"entities": [{"text": "Bundesverfassungsgerichts", "start": 286, "end": 311, "type": "ORG"}]}
#
# Input: {"text": "Ein \u00dcbergang der Arbeitgebereigenschaft auf die Elektronicon-GmbH ist jedenfalls weder im Wege der nach \u00a7 12 Abs 1 S 1 SpTrUG vom 5. 4. 1991 ( BGBl I 854 ) geheilten Einzel\u00fcbertragung ( nachfolgend a ) noch aufgrund einer Universalsukzession nach \u00a7 7 S 2 UmwVO erfolgt ( nachfolgend b ) ."}
# Output: {"entities": [{"text": "Elektronicon-GmbH", "start": 48, "end": 65, "type": "ORG"}]}
#
# Input: {"text": "Zur Verwirklichung dieses Plans initiierte die PKK verschiedene Organisationen , die mehrfach ihre Bezeichnung wechselten ."}
# Output: {"entities": [{"text": "PKK", "start": 47, "end": 50, "type": "ORG"}]}
#
# Input: {"text": "Der Antrag kann von beiden Beteiligten gestellt werden ( vgl. Baumbach / Hartmann , ZPO , 76. Aufl. 2018 , \u00a7 269 , Rdn. 46 ; Fezer / Grabrucker , Handbuch der Markenpraxis , Band I ( Markenverfahrensrecht ) , 3. Aufl. 2016 , Rdn. 384 ) ; eine Beschr\u00e4nkung auf den Markeninhaber l\u00e4sst sich der Entscheidung des Bundesgerichtshofes nicht entnehmen ."}
# Output: {"entities": [{"text": "Bundesgerichtshofes", "start": 310, "end": 329, "type": "ORG"}]}
#
# Input: {"text": "Die Generalstaatsanwaltschaft M\u00fcnchen wird mit der Durchf\u00fchrung der einstweiligen Anordnung beauftragt ."}
# Output: {"entities": [{"text": "Generalstaatsanwaltschaft M\u00fcnchen", "start": 4, "end": 37, "type": "ORG"}]}
#
# Input: {"text": "( 2 ) F\u00f6rdermitglieder schulden dem ZDS nach \u00a7 12 Nr. 1 Satz 2 der Satzung Beitr\u00e4ge ."}
# Output: {"entities": [{"text": "ZDS", "start": 36, "end": 39, "type": "ORG"}]}
#
# Input: {"text": "Ihr Vertrauen in den Bestand des geltenden Gewerbesteuerrechts war mit der Zuleitung des Entwurfs des Unternehmenssteuerfortentwicklungsgesetzes zum Bundesrat nicht mehr schutzw\u00fcrdig ( bb ) ."}
# Output: {"entities": [{"text": "Bundesrat", "start": 149, "end": 158, "type": "ORG"}]}
#
# Input: {"text": "4. Ob die Einbringung des BgA in die F-GmbH den Besteuerungstatbestand der Aufl\u00f6sung der R\u00fccklagen gem\u00e4\u00df \u00a7 20 Abs. 1 Nr. 10 Buchst. b Satz 2 EStG ausl\u00f6sen konnte und ob dabei die Gesetzesfassung des StSenkG oder die erg\u00e4nzte Fassung des JStG 2007 ma\u00dfgeblich gewesen w\u00e4re , braucht im Streitfall nicht entschieden zu werden ."}
# Output: {"entities": [{"text": "F-GmbH", "start": 37, "end": 43, "type": "ORG"}]}
#
# Input: {"text": "I. Die Wortkombination Lebe Balance ist am 2. Oktober 2013 zur Eintragung als Wortmarke in das beim Deutschen Patent- und Markenamt gef\u00fchrte Markenregister f\u00fcr die nachfolgende Dienstleistung der Klassen 9 angemeldet worden :"}
# Output: {"entities": [{"text": "Lebe Balance", "start": 23, "end": 35, "type": "ORG"}, {"text": "Deutschen Patent- und Markenamt", "start": 100, "end": 131, "type": "ORG"}]}
#
# Input: {"text": "Nach diesen Ma\u00dfst\u00e4ben ist die Versetzung des Antragstellers auf den Dienstposten eines Einsatzoffiziers Streitkr\u00e4fte beim ... amt in B nicht zu beanstanden ."}
# Output: {"entities": [{"text": "... amt", "start": 122, "end": 129, "type": "ORG"}]}
#
# Input: {"text": "Der Europ\u00e4ische Gerichtshof f\u00fcr Menschenrechte hat bereits betont , dass eine Begnadigung nicht von vornherein untauglich ist , um dem Verurteilten eine Chance auf Wiedererlangung der Freiheit einzur\u00e4umen ( EGMR , Urteil vom 4. September 2014 - Nr. 140/10 , Trabelsi / Belgien - Rn. 137 ) ."}
# Output: {"entities": [{"text": "Europ\u00e4ische Gerichtshof f\u00fcr Menschenrechte", "start": 4, "end": 46, "type": "ORG"}]}
#
# Input: {"text": "Insoweit wird die Berufung des Kl\u00e4gers gegen das Urteil des Sozialgerichts Duisburg vom 15. M\u00e4rz 2011 zur\u00fcckgewiesen ."}
# Output: {"entities": [{"text": "Sozialgerichts Duisburg", "start": 60, "end": 83, "type": "ORG"}]}
#
# Input: {"text": "ff ) Entgegen der Ansicht der Revision w\u00e4re das Unionsrecht hier auch nicht verletzt , wenn Besch\u00e4ftigte , welche sich auf den unionsrechtlich gew\u00e4hrleisteten Freiz\u00fcgigkeitsschutz berufen k\u00f6nnen , bezogen auf die Ber\u00fccksichtigung ihrer in der Europ\u00e4ischen Union erworbenen einschl\u00e4gigen Berufserfahrung bessergestellt w\u00e4ren , als Besch\u00e4ftigte ohne Bezug zum EU-Ausland ( Problem der sog. Inl\u00e4nderdiskriminierung ) ."}
# Output: {"entities": [{"text": "Europ\u00e4ischen Union", "start": 243, "end": 261, "type": "ORG"}]}
#
# Input: {"text": "Vor diesem Hintergrund sei die Aussage des Ausw\u00e4rtigen Amtes in seinem Schreiben vom 20. M\u00e4rz 2018 , wonach jede Todesstrafe durch einen Gnadenakt des Pr\u00e4sidenten in eine lebenslange Freiheitsstrafe umgewandelt werde , falsch ."}
# Output: {"entities": [{"text": "Ausw\u00e4rtigen Amtes", "start": 43, "end": 60, "type": "ORG"}]}
#
# Input: {"text": "Annex A : Schott , Temperung ( Kristallisation ) und anschlie\u00dfende XRD-Analyse der Glaskeramikschmelze VSM 46802 , 11. 2. 2016 , 3 Seiten"}
# Output: {"entities": [{"text": "Schott", "start": 10, "end": 16, "type": "ORG"}]}
#
# Input: {"text": "Er beantragt sinngem\u00e4\u00df , den Beschluss des Deutschen Patent- und Markenamtes vom 7. Dezember 2015 aufzuheben ."}
# Output: {"entities": [{"text": "Deutschen Patent- und Markenamtes", "start": 43, "end": 76, "type": "ORG"}]}
#
# Input: {"text": "Der Beschluss der Markenstelle f\u00fcr Klasse 38 des Deutschen Patent- und Markenamtes vom 28. Oktober 2013 wird aufgehoben ."}
# Output: {"entities": [{"text": "Markenstelle f\u00fcr Klasse 38 des Deutschen Patent- und Markenamtes", "start": 18, "end": 82, "type": "ORG"}]}
#
# Input: {"text": "Der Beschluss des Oberlandesgerichts M\u00fcnchen vom 16. Oktober 2017 verletze den Beschwerdef\u00fchrer in seinem Grundrecht auf effektiven Rechtsschutz nach Art. 19 Abs. 4 Satz 1 GG ."}
# Output: {"entities": [{"text": "Oberlandesgerichts M\u00fcnchen", "start": 18, "end": 44, "type": "ORG"}]}
#
# Input: {"text": "Er hat in Rz 35 ff. seiner Entscheidung begr\u00fcndet , warum - auf Grundlage der Rechtsprechung des EuGH - die nationale Regelung mit Unionsrecht vereinbar ist , und hat aus den unter Rz 45 ff. genannten Gr\u00fcnden die Einwendungen des Kl\u00e4gers f\u00fcr nicht durchgreifend erachtet ."}
# Output: {"entities": [{"text": "EuGH", "start": 97, "end": 101, "type": "ORG"}]}
#
# Input: {"text": "a ) Eine Rechtssache hat grunds\u00e4tzliche Bedeutung i. S. des \u00a7 115 Abs. 2 Nr. 1 FGO oder erfordert eine Entscheidung des Bundesfinanzhofs ( BFH ) zur Fortbildung des Rechts als Unterfall des Zulassungsgrundes der grunds\u00e4tzlichen Bedeutung , wenn die f\u00fcr die Beurteilung des Streitfalls ma\u00dfgebliche Rechtsfrage das Interesse der Allgemeinheit an der einheitlichen Entwicklung und Handhabung des Rechts ber\u00fchrt ."}
# Output: {"entities": [{"text": "Bundesfinanzhofs", "start": 120, "end": 136, "type": "ORG"}, {"text": "BFH", "start": 139, "end": 142, "type": "ORG"}]}
#
# Input: {"text": "Die Beklagte hat die Kl\u00e4gerinnen mit Klageschrift vom 17. August 2015 vor dem Landgericht D\u00fcsseldorf ( 4c O 48/15 ) wegen Verletzung des Streitpatents u. a. auf Unterlassung in Anspruch genommen ."}
# Output: {"entities": [{"text": "Landgericht D\u00fcsseldorf", "start": 78, "end": 100, "type": "ORG"}]}
#
# Input: {"text": "Die Bundesregierung ist den Verfahren beigetreten ( \u00a7 94 Abs. 5 Satz 1 BVerfGG ) ."}
# Output: {"entities": [{"text": "Bundesregierung", "start": 4, "end": 19, "type": "ORG"}]}
#
# Input: {"text": "Der Senat geht vielmehr davon aus , dass entsprechend der Rechtsprechung des BGH die Gesellschaft b\u00fcrgerlichen Rechts und die Partnerschaftsgesellschaft und gleicherma\u00dfen auch die BAG unver\u00e4ndert fortbestehen ( SozR 4 - 2500 \u00a7 87b Nr 2 RdNr 27 mit zahlreichen Nachweisen ) ."}
# Output: {"entities": [{"text": "BGH", "start": 77, "end": 80, "type": "ORG"}]}
#
# Input: {"text": "Die Revision der Kl\u00e4gerin gegen das Urteil des S\u00e4chsischen Landessozialgerichts vom 19. Mai 2016 wird zur\u00fcckgewiesen ."}
# Output: {"entities": [{"text": "S\u00e4chsischen Landessozialgerichts", "start": 47, "end": 79, "type": "ORG"}]}
#
# Input: {"text": "Wegen dieser nicht genehmigten Teilnahme erlie\u00df die Bezirksregierung K\u00f6ln gegen die Beschwerdef\u00fchrerin zu III. unter dem 10. Mai 2010 eine Disziplinarverf\u00fcgung , mit der ihr eine Geldbu\u00dfe in H\u00f6he von 1.500 EUR auferlegt wurde ."}
# Output: {"entities": [{"text": "Bezirksregierung K\u00f6ln", "start": 52, "end": 73, "type": "ORG"}]}
#
# Input: {"text": "Mit Schreiben vom 8. November 2016 nahm das vorlegende Gericht zur Vorlagefrage erg\u00e4nzend Stellung und stellte dabei klar , dass es im vorliegenden Fall - anders als vom Bundesverfassungsgericht mit Beschluss vom 26. Juli 2016 entschieden - um die M\u00f6glichkeit der Zwangsmedikation bei ambulanter Behandlung gehe ."}
# Output: {"entities": [{"text": "Bundesverfassungsgericht", "start": 170, "end": 194, "type": "ORG"}]}
#
# Input: {"text": "( 2 ) Der Pensions-Sicherungs-Verein Versicherungsverein auf Gegenseitigkeit unterliegt der Aufsicht durch die Bundesanstalt f\u00fcr Finanzdienstleistungsaufsicht . \u2026 \u201c"}
# Output: {"entities": [{"text": "Bundesanstalt f\u00fcr Finanzdienstleistungsaufsicht", "start": 111, "end": 158, "type": "ORG"}]}
#
# Input: {"text": "Der Sohn der Kl\u00e4gerin und Beschwerdef\u00fchrerin ( Kl\u00e4gerin ) , Herr ... ( A ) , f\u00fchrte bis zur Untersagung durch die Stadt M am 8. Januar 2001 das Restaurant X."}
# Output: {"entities": [{"text": "X.", "start": 155, "end": 157, "type": "ORG"}]}
#
# Input: {"text": "aa ) Die Bindung kann entfallen , wenn sich nachtr\u00e4glich die ma\u00dfgebenden Umst\u00e4nde ge\u00e4ndert haben , und zwar entweder , weil sich der zugrunde gelegte Sachverhalt in einer f\u00fcr die Entscheidung erheblichen Weise ge\u00e4ndert hat ( dazu BFH-Urteil vom 7. August 1990 VII R 120/89 , BFH / NV 1991 , 569 ) , sich einschl\u00e4gige Gesetzesbestimmungen r\u00fcckwirkend ge\u00e4ndert haben oder sich die h\u00f6chstrichterliche Rechtsprechung des entscheidenden Senats , des Gro\u00dfen Senats des BFH , des EuGH oder des Gemeinsamen Senats der obersten Gerichtsh\u00f6fe des Bundes - unabh\u00e4ngig von dem Streitfall - ge\u00e4ndert hat ( BFH-Urteil vom 8. November 1983 VII R 141/82 , BFHE 140 , 11 , BStBl II 1984 , 317 , unter II. 2. , zur Entscheidung des Senats ; BFH-Beschl\u00fcsse vom 22. Februar 2006 I B 145/05 , BFHE 213 , 29 , BStBl II 2006 , 546 , unter II. 2. d bb , Rz 35 , zur Gesetzes\u00e4nderung ; vom 11. Januar 2007 XI B 22/06 , BFH / NV 2007 , 909 , zur Entscheidung des Gro\u00dfen Senats ; Gr\u00e4ber / Ratschow , a. a. O. , \u00a7 126 Rz 29 ) ."}
# Output: {"entities": [{"text": "Gro\u00dfen Senats des BFH", "start": 445, "end": 466, "type": "ORG"}, {"text": "EuGH", "start": 473, "end": 477, "type": "ORG"}, {"text": "Gemeinsamen Senats der obersten Gerichtsh\u00f6fe des Bundes", "start": 487, "end": 542, "type": "ORG"}]}
#
# Input: {"text": "1. Auf die Revision des Angeklagten wird das Urteil des Landgerichts Koblenz vom 21. August 2017 , soweit es ihn betrifft , aufgehoben"}
# Output: {"entities": [{"text": "Landgerichts Koblenz", "start": 56, "end": 76, "type": "ORG"}]}
#
# Input: {"text": "Da allein das Fehlen jeglicher Unterscheidungskraft ein Eintragungshindernis begr\u00fcndet , ist nach der Rechtsprechung des Bundesgerichtshofes ein gro\u00dfz\u00fcgiger Ma\u00dfstab anzulegen , so dass jede auch noch so geringe Unterscheidungskraft gen\u00fcgt , um das Schutzhindernis zu \u00fcberwinden ( vgl. BGH GRUR 2012 , 1143 , Rn. 7 - Starsat ; GRUR 2012 , 1044 , 1045 , Rn. 9 - Neuschwanstein ; GRUR 2012 , 270 , Rn. 8 - Link economy ) ."}
# Output: {"entities": [{"text": "Bundesgerichtshofes", "start": 121, "end": 140, "type": "ORG"}]}
#
#
#
# YOUR TASK:
# Synthesize a complete ruleset (max 10 rules) that:
# 1. Rely ONLY on the data provided
# 2. Handles all corrections correctly (CRITICAL - these show failure modes)
# 3. Works on all examples
# 4. Respects user feedback
# 5. Is general and minimal (avoid redundant rules)
#
# RULES CAN BE:- Regex patterns (for structured extraction)
#
# IMPORTANT: You must ONLY use the allowed formats listed above. Do NOT generate rules in other formats.
# IMPORTANT: Do NOT include Python/code rules. Only return the listed formats.
# IMPORTANT: Do NOT include spaCy rules. Only return the listed formats.
#
# SCHEMA-AWARE RULES:
# For this task, rules must include an output_template that maps matches to the output schema.
#
# Output schema:
# entities: List[Entity]
#
# Entity:
#   text: string  # The matched text span
#   start: integer  # Start character offset
#   end: integer  # End character offset
#   type: string  # Entity label
#
# Each rule needs:
# - pattern: The regex pattern to match
# - output_template: JSON template for each match, using variables:
#   - $0: Full match text
#   - $start: Start character offset
#   - $end: End character offset
#   - $1, $2, ...: Capture groups (regex only)
# - output_key: Which output array to populate (e.g., "entities")
#
# Return JSON:
# {
#   "analysis": "What patterns did you find? What went wrong in corrections?",
#   "strategy": "Overall approach",
#   "note": "Every rule must include both output_template and output_key",
#   "rules": [
#     {
#       "name": "Short rule name",
#       "description": "What this rule does",
#       "format": "regex",
#       "pattern": "regex pattern",
#       "output_template": {"text": "$0", "start": "$start", "end": "$end", "type": "LITERAL_OR_$VAR"},
#       "output_key": "entities",
#       "priority": 1-10 (higher = more important),
#       "reasoning": "Why this rule is needed"
#     }
#   ]
# }
#
# NER RULE EXAMPLES (regex):
#
#
# Example 1 - Organizations with corporate suffixes:
# {
#   "name": "corporate_suffixes",
#   "format": "regex",
#   "pattern": "\b([A-Z][a-z0-9]+(?:\s+[A-Z][a-z]+)*)\s+(AG|GmbH|KG|UG|OHG|Gbr)\b",
#   "output_template": {"text": "$0", "start": "$start", "end": "$end", "type": "ORG"},
#   "output_key": "entities",
#   "priority": 9
# }
#
# Focus on learning from CORRECTIONS - they show exactly what went wrong!
#
# IMPORTANT: Return ONLY valid JSON. Ensure:
# - All strings use double quotes and are properly escaped
# - All braces and brackets are balanced
# - No trailing commas
# - Response is complete (not truncated)
#
# 📚 Synthesizing rules from dataset...
#       Validation error: bad character range \.-( at position 38
#    ⚠ Skipped invalid rule: mixed_case_mw_name_fallback
# ✓ Synthesized 5 rules (67.0s)
# ✓ Generated 5 rules
#
# 🔄 Refinement loop (max 3 iterations)
# [1/3] Evaluating rules...
# [1/3] Accuracy: 3.4% (334/9888)
# [1/3] Refining based on 9554 failures...
# de
# [1/3] Refined 8 rules (98.3s)
# [2/3] Evaluating rules...
# [2/3] Accuracy: 4.5% (446/9888)
# [2/3] Refining based on 9442 failures...
# de
# [2/3] Refined 11 rules (108.4s)
# [3/3] Evaluating rules...
# [3/3] Accuracy: 17.8% (1756/9888)
# [3/3] Refining based on 8132 failures...
# de
#       Validation error: look-behind requires fixed-width pattern
#    ⚠ Skipped invalid rule: lebebalance_trademark_phrase
#       Validation error: look-behind requires fixed-width pattern
#    ⚠ Skipped invalid rule: annex_single_organization
# [3/3] Refined 13 rules (139.1s)
#
# ============================================================
# Learning complete! (415.4s)
#   Rules: 11
#   Accuracy: 17.8% (1756/9888)
# ============================================================

# %%
rules_file = Path("./rulechef_data/2025-02-02_ORG_ler_dataset.json")
rules_data = json.loads(rules_file.read_text())

rules = [Rule.from_dict(r) for r in rules_data.get("rules")]
for rule in rules:
    print_rule_result(rule)
    print("####################")
# Out:
# CONTENT Match ordinal + chamber/senat/Patentabteilung and optional 'des' + court name (e.g. '17. Zivilkammer des Landgerichts Dortmund', '14. Senat ( Technischer Beschwerdesenat ) des Bundespatentgerichts'). Anchored to the ordinal to avoid capturing preceding sentence text.
# regex.Regex('\\b\\d{1,2}\\.\\s+(?:[A-ZÄÖÜ][A-Za-zäöüÄÖÜß\\-\\(\\)/]{0,40}\\s+)?(?:Zivilkammer|Kammer|Senat|Beschwerdesenat|Patentabteilung|Abteilung|Referat)\\b(?:[\\s\\(\\)\\-\\,\\.\\/:;]{0,12}[^\\n\\,\\.\\;]{0,60}?\\s+des\\s+[A-ZÄÖÜ][A-Za-zäöüÄÖÜß\\-\\s]{1,60})?', flags=regex.V0)
# ####################
# CONTENT Match department/section names followed by 'des'/'der' and an organisation (e.g. 'Patentabteilung 1.51 des Deutschen Patent- und Markenamts').
# regex.Regex('\\b(?:Patentabteilung|Abteilung|Referat|Sachgebiet)[^,\\n\\.;]{0,40}\\b(?:des|der)\\s+(?:Deutschen\\s+)?(?:Patent-\\s*und\\s*Markenamts?|Patent-\\s*und\\s*Markenamt|Bundespatentgericht(?:s)?|Landgericht(?:s)?|Amtsgericht(?:s)?|Oberlandesgericht(?:s)?|Bundesverfassungsgericht(?:s)?|Bundesgerichtshof(?:es|es)?)\\b', flags=regex.V0)
# ####################
# CONTENT Match common full institution names including genitive forms (e.g. 'Bundesverfassungsgericht', 'Bundesverfassungsgerichts', 'Bundesgerichtshof', 'Patent- und Markenamt', 'Bundespatentgericht', 'Bundeswehr', 'Generalstaatsanwaltschaft').
# regex.Regex('\\b(?:Bundesverfassungsgericht(?:s|es)?|Bundesgerichtshof(?:es|es)?|Bundespatentgericht(?:s)?|Patent-\\s*und\\s*Markenamt(?:s|es)?|Deutschen\\s+Patent-\\s*und\\s*Markenamt(?:s)?|Landgericht(?:s)?|Amtsgericht(?:s)?|Oberlandesgericht(?:s)?|Generalstaatsanwaltschaft|Senatsverwaltung|Bundeswehr)\\b', flags=regex.V0)
# ####################
# CONTENT Match corporate names that end with a legal suffix (AG, GmbH, KG, UG, OHG, GbR, Gbr, e.V., eV) but limit to up to 4 capitalized words before the suffix to avoid greedy long matches.
# regex.Regex("\\b(?:[A-ZÄÖÜ][A-Za-z0-9ÄÖÜäöüß\\-/&()']*(?:\\s+[A-ZÄÖÜ][A-Za-z0-9ÄÖÜäöüß\\-/&()']*){0,3})\\s+(?:AG|GmbH|KG|UG|OHG|GbR|Gbr|e\\.V\\.|eV)\\b", flags=regex.V0)
# ####################
# CONTENT Match corporate names that include a suffix and a short trailing descriptor (e.g. 'KIN GmbH Lebensmittelinstitut', 'Elektronicon-GmbH'). Allows a few additional capitalized words after the suffix.
# regex.Regex("\\b(?:[A-ZÄÖÜ][A-Za-z0-9ÄÖÜäöüß\\-/&()']*(?:\\s+[A-ZÄÖÜ][A-Za-z0-9ÄÖÜäöüß\\-/&()']*){0,3})\\s+(?:GmbH|AG|UG|KG|OHG)(?:\\s+[A-ZÄÖÜ][A-Za-zäöüÄÖÜß\\-]{1,40}){0,3}\\b", flags=regex.V0)
# ####################
# CONTENT Match hyphenated fund names like 'A-Fonds', 'B-Fonds' and similar constructs (single capital/number + '-' + 'Fonds').
# regex.Regex('\\b[A-Z0-9]+-[Ff]onds\\b', flags=regex.V0)
# ####################
# CONTENT Match named commissions, ministries, ministers, senats, senatsverwaltungen and similar (e.g. 'Europäischen Kommission', 'Bundesminister des Auswärtigen', 'Senatsverwaltung für Justiz ... Berlin'). Limits to a few capitalized words before the target token.
# regex.Regex('\\b(?:[A-ZÄÖÜ][a-zäöüß]+(?:\\s+[A-ZÄÖÜ][a-zäöüß]+){0,3})\\s+(?:Kommission|Minister|Ministerium|Bundesminister|Bundesministerium|Senat|Senatsverwaltung|Generalstaatsanwaltschaft|Bundeswehr)\\b', flags=regex.V0)
# ####################
# CONTENT Match uppercase acronyms of length 2 to 6 (e.g. BGH, BVerfG) as organisations. Lower priority than full-name rules to avoid overriding them.
# regex.Regex('\\b[A-ZÄÖÜ]{2,6}\\b', flags=regex.V0)
# ####################

# %%
rules_file = Path("./rulechef_data/2025-02-02_ORG_ler_dataset_v2.json")
rules_data = json.loads(rules_file.read_text())

rules = [Rule.from_dict(r) for r in rules_data.get("rules")]
for rule in rules:
    print_rule_result(rule)
    print("####################")
# Out:
# CONTENT Match ordinals + court/committee units (e.g. '17. Zivilkammer des Landgerichts Dortmund', '14. Senat ( Technischer Beschwerdesenat ) des Bundespatentgerichts'). This is intentionally limited to known unit keywords to avoid capturing arbitrary nouns.
# regex.Regex('(?<!\\S)(?:\\d{1,2}\\.\\s*)?(?:Zivilkammer|Senat|Kammer|Beschwerdesenat|Technischer\\s+Beschwerdesenat|Patentabteilung)(?:\\s*\\([^\\)]{1,80}\\))?(?:\\s+[A-ZÄÖÜ0-9][\\w\\.\\-\\(\\)/]{0,60}){0,4}\\s+(?:des|der)\\s+(?:[A-ZÄÖÜ][\\w\\.-]*(?:\\s+[A-ZÄÖÜ][\\w\\.-]*){0,6})', flags=regex.V0)
# ####################
# CONTENT Match the full Patentabteilung phrase for the German Patent and Trademark Office, including numeric subdivision (e.g. 'Patentabteilung 1.51 des Deutschen Patent- und Markenamts').
# regex.Regex('(?<!\\S)(?:Patentabteilung\\s*\\d+(?:\\.\\d+)?(?:\\s*\\([^\\)]*\\))?\\s+des\\s+Deutschen\\s+Patent-\\s*und\\s+Markenamts)\\b', flags=regex.V0)
# ####################
# CONTENT Fixed list for frequently occurring institutions and variants (including possible genitive s).
# regex.Regex('(?<!\\S)(?:Bundesverfassungsgericht(?:s)?|Bundesgerichtshof(?:s|es)?|Bundespatentgericht(?:s)?|Deutsches\\s+Patent-\\s*und\\s+Markenamt(?:s)?|Deutschen\\s+Patent-\\s*und\\s+Markenamt(?:s)?|Europäische[nm]?\\s+Kommission|Europäischen\\s+Kommission|Bundeswehr|DPMA)\\b', flags=regex.V0)
# ####################
# CONTENT Match long Senate/administration names that include 'Senatsverwaltung f�r ... Berlin' (captures the full expression).
# regex.Regex('(?<!\\S)(Senatsverwaltung\\s+f(?:ü|u)r[^\\n]{1,160}?Berlin)\\b', flags=regex.V0)
# ####################
# CONTENT Match ministry or minister titles like 'Bundesminister des Auswärtigen' and similar "Bundesminister(in) des ..." forms.
# regex.Regex('(?<!\\S)(Bundesminister(?:in|n)?\\s+des\\s+[A-ZÄÖÜ][\\wäöüÄÖÜ\\- ]{1,80})\\b', flags=regex.V0)
# ####################
# CONTENT Company names ending with common corporate suffixes (AG, GmbH, KG, UG, OHG, e.V., GbR, SE, Ltd, Inc).
# regex.Regex('(?<!\\S)\\b[A-ZÄÖÜ0-9][\\w\\.-]*(?:\\s+[A-ZÄÖÜ0-9][\\w\\.-]*){0,4}\\s+(?:AG|GmbH|KG|UG|OHG|e\\.V\\.|GbR|Gbr|SE|Ltd|Inc)\\b', flags=regex.V0)
# ####################
# CONTENT Hyphenated names where suffix is attached with hyphen (e.g. 'Elektronicon-GmbH', 'A-AG').
# regex.Regex('(?<!\\S)[A-ZÄÖÜ][\\w\\.-]*-(?:AG|GmbH|KG|UG|OHG|e\\.V\\.|SE|Ltd|Inc)\\b', flags=regex.V0)
# ####################
# CONTENT Match fund names like 'A-Fonds' or 'B-Fonds' and variants (single-letter prefix or letter-hyphen variants).
# regex.Regex('(?<!\\S)\\b[A-Z](?:-[A-Z][\\w-]*)?\\s*Fonds\\b', flags=regex.V0)
# ####################
# CONTENT Refined rule: match only when 'des'/'der' is followed by likely institution tokens (Gericht, Amt, Kommission, Minister, Senat, Verwaltung, Patent, Fonds, Handelsregister, etc.) to avoid capturing preceding nouns.
# regex.Regex('(?<=\\b(?:des|der)\\s)(?:[A-ZÄÖÜ][\\w\\.-]*\\s*(?:Gericht|Gerichts|Amt|Amts|Patent(?:-\\s*und\\s*Markenamts)?|Kommission|Minister(?:iums|ium|)|Senat|Verwaltung|Fonds|Handelsregister|Bundeswehr|Patentgericht|Landgericht|Bundespatentgericht|Bundesgerichtshof)(?:\\s+[A-ZÄÖÜ][\\w\\.-]*){0,5})', flags=regex.V0)
# ####################
# CONTENT Match uppercase trademark names when introduced by 'Bezeichnung' and followed by 'als Wortmarke' (e.g. 'Bezeichnung DUO als Wortmarke').
# regex.Regex('(?<=\\bBezeichnung\\s)([A-ZÄÖÜ]{2,20})(?=\\s+als\\s+Wortmarke)', flags=regex.V0)
# ####################
# CONTENT Generic uppercase acronyms (2-6 letters) commonly used for institutions (BGH, BFH, DPMA, KMU, etc.). Lower priority so full-name rules win first.
# regex.Regex('(?<!\\S)\\b[A-ZÄÖÜ]{2,6}\\b', flags=regex.V0)
# ####################

# %%
rule_learner = RuleChefLearner(
    model="gpt-5-mini-2025-08-07",
    dataset="ler",
    allowed_classes="ORG",
    rule_file="2025-02-02_ORG_ler_dataset_v2",
    lang="de",
)
rule_learner.fit(sampled[:100], negative)
# Out:
# {'REG', 'ORG', 'LIT', 'LOC', 'RS', 'NRM', 'PERS'}
# ✓ Loaded dataset: 0 corrections, 9888 examples
# ✓ Added example (buffer: 1 new, 1 total)
# ✓ Added example (buffer: 2 new, 2 total)
# ✓ Added example (buffer: 3 new, 3 total)
# ✓ Added example (buffer: 4 new, 4 total)
# ✓ Added example (buffer: 5 new, 5 total)
# ✓ Added example (buffer: 6 new, 6 total)
# ✓ Added example (buffer: 7 new, 7 total)
# ✓ Added example (buffer: 8 new, 8 total)
# ✓ Added example (buffer: 9 new, 9 total)
# ✓ Added example (buffer: 10 new, 10 total)
# ✓ Added example (buffer: 11 new, 11 total)
# ✓ Added example (buffer: 12 new, 12 total)
# ✓ Added example (buffer: 13 new, 13 total)
# ✓ Added example (buffer: 14 new, 14 total)
# ✓ Added example (buffer: 15 new, 15 total)
# ✓ Added example (buffer: 16 new, 16 total)
# ✓ Added example (buffer: 17 new, 17 total)
# ✓ Added example (buffer: 18 new, 18 total)
# ✓ Added example (buffer: 19 new, 19 total)
# ✓ Added example (buffer: 20 new, 20 total)
# ✓ Added example (buffer: 21 new, 21 total)
# ✓ Added example (buffer: 22 new, 22 total)
# ✓ Added example (buffer: 23 new, 23 total)
# ✓ Added example (buffer: 24 new, 24 total)
# ✓ Added example (buffer: 25 new, 25 total)
# ✓ Added example (buffer: 26 new, 26 total)
# ✓ Added example (buffer: 27 new, 27 total)
# ✓ Added example (buffer: 28 new, 28 total)
# ✓ Added example (buffer: 29 new, 29 total)
# ✓ Added example (buffer: 30 new, 30 total)
# ✓ Added example (buffer: 31 new, 31 total)
# ✓ Added example (buffer: 32 new, 32 total)
# ✓ Added example (buffer: 33 new, 33 total)
# ✓ Added example (buffer: 34 new, 34 total)
# ✓ Added example (buffer: 35 new, 35 total)
# ✓ Added example (buffer: 36 new, 36 total)
# ✓ Added example (buffer: 37 new, 37 total)
# ✓ Added example (buffer: 38 new, 38 total)
# ✓ Added example (buffer: 39 new, 39 total)
# ✓ Added example (buffer: 40 new, 40 total)
# ✓ Added example (buffer: 41 new, 41 total)
# ✓ Added example (buffer: 42 new, 42 total)
# ✓ Added example (buffer: 43 new, 43 total)
# ✓ Added example (buffer: 44 new, 44 total)
# ✓ Added example (buffer: 45 new, 45 total)
# ✓ Added example (buffer: 46 new, 46 total)
# ✓ Added example (buffer: 47 new, 47 total)
# ✓ Added example (buffer: 48 new, 48 total)
# ✓ Added example (buffer: 49 new, 49 total)
# ✓ Added example (buffer: 50 new, 50 total)
# ✓ Added example (buffer: 51 new, 51 total)
# ✓ Added example (buffer: 52 new, 52 total)
# ✓ Added example (buffer: 53 new, 53 total)
# ✓ Added example (buffer: 54 new, 54 total)
# ✓ Added example (buffer: 55 new, 55 total)
# ✓ Added example (buffer: 56 new, 56 total)
# ✓ Added example (buffer: 57 new, 57 total)
# ✓ Added example (buffer: 58 new, 58 total)
# ✓ Added example (buffer: 59 new, 59 total)
# ✓ Added example (buffer: 60 new, 60 total)
# ✓ Added example (buffer: 61 new, 61 total)
# ✓ Added example (buffer: 62 new, 62 total)
# ✓ Added example (buffer: 63 new, 63 total)
# ✓ Added example (buffer: 64 new, 64 total)
# ✓ Added example (buffer: 65 new, 65 total)
# ✓ Added example (buffer: 66 new, 66 total)
# ✓ Added example (buffer: 67 new, 67 total)
# ✓ Added example (buffer: 68 new, 68 total)
# ✓ Added example (buffer: 69 new, 69 total)
# ✓ Added example (buffer: 70 new, 70 total)
# ✓ Added example (buffer: 71 new, 71 total)
# ✓ Added example (buffer: 72 new, 72 total)
# ✓ Added example (buffer: 73 new, 73 total)
# ✓ Added example (buffer: 74 new, 74 total)
# ✓ Added example (buffer: 75 new, 75 total)
# ✓ Added example (buffer: 76 new, 76 total)
# ✓ Added example (buffer: 77 new, 77 total)
# ✓ Added example (buffer: 78 new, 78 total)
# ✓ Added example (buffer: 79 new, 79 total)
# ✓ Added example (buffer: 80 new, 80 total)
# ✓ Added example (buffer: 81 new, 81 total)
# ✓ Added example (buffer: 82 new, 82 total)
# ✓ Added example (buffer: 83 new, 83 total)
# ✓ Added example (buffer: 84 new, 84 total)
# ✓ Added example (buffer: 85 new, 85 total)
# ✓ Added example (buffer: 86 new, 86 total)
# ✓ Added example (buffer: 87 new, 87 total)
# ✓ Added example (buffer: 88 new, 88 total)
# ✓ Added example (buffer: 89 new, 89 total)
# ✓ Added example (buffer: 90 new, 90 total)
# ✓ Added example (buffer: 91 new, 91 total)
# ✓ Added example (buffer: 92 new, 92 total)
# ✓ Added example (buffer: 93 new, 93 total)
# ✓ Added example (buffer: 94 new, 94 total)
# ✓ Added example (buffer: 95 new, 95 total)
# ✓ Added example (buffer: 96 new, 96 total)
# ✓ Added example (buffer: 97 new, 97 total)
# ✓ Added example (buffer: 98 new, 98 total)
# ✓ Added example (buffer: 99 new, 99 total)
# ✓ Added example (buffer: 100 new, 100 total)
# ✓ Added negative example (buffer: 101 new, 101 total)
# ✓ Added negative example (buffer: 102 new, 102 total)
# ✓ Added negative example (buffer: 103 new, 103 total)
# ✓ Added negative example (buffer: 104 new, 104 total)
# ✓ Added negative example (buffer: 105 new, 105 total)
# ✓ Added negative example (buffer: 106 new, 106 total)
#
# 📥 Converting 106 buffered examples to dataset...
#    (0 corrections, 0 LLM, 106 human)
# ✓ Converted to dataset: 0 corrections, 9994 examples
#
# ============================================================
# Learning rules from 9994 training items
#   Corrections: 0 (high value)
#   Examples: 9994
#   Mode: Synthesis + Refinement (max 3 iterations)
# ============================================================
#
# de
# Task: Named Entity Recognition
# Description: Extract ORG: Organisationsnamen (Parteien, Vereine, Institutionen, Unternehmen) from German text
# Input schema: {'text': 'str'}
# Output schema:
# entities: List[Entity]
#
# Entity:
#   text: string  # The matched text span
#   start: integer  # Start character offset
#   end: integer  # End character offset
#   type: string  # Entity label
#
# TRAINING EXAMPLES (50 shown):
# Learn rules from the these examples:
#
# Input: {"text": "Die Beschwerde gegen die Nichtzulassung der Revision in dem Urteil der 17. Zivilkammer des Landgerichts Dortmund vom 30. Juni 2017 wird auf Kosten der Kl\u00e4ger als unzul\u00e4ssig verworfen ."}
# Output: {"entities": [{"text": "17. Zivilkammer des Landgerichts Dortmund", "start": 71, "end": 112, "type": "ORG"}]}
#
# Input: {"text": "Das Bundesverfassungsgericht darf von seiner Befugnis , den Vollzug eines Gesetzes auszusetzen , nur mit gr\u00f6\u00dfter Zur\u00fcckhaltung Gebrauch machen , weil dies einen erheblichen Eingriff in die origin\u00e4re Zust\u00e4ndigkeit des Gesetzgebers darstellt ( vgl. BVerfGE 104 , 23 < 27 > ; 104 , 51 < 55 > ; 112 , 216 < 220 > ; 112 , 284 < 292 > ; 122 , 342 < 361 > ; 131 , 47 < 61 > ; 140 , 99 < 106 f. > ; 140 , 211 < 219 > ; stRspr ) ."}
# Output: {"entities": [{"text": "Bundesverfassungsgericht", "start": 4, "end": 28, "type": "ORG"}]}
#
# Input: {"text": "Deren H\u00f6he k\u00f6nnen sie \u201e frei w\u00e4hlen \u201c , sie m\u00fcssen jedoch mindestens \u201e 50 % des Beitrags gem\u00e4\u00df Satz 1 \u201c , dh. des monatlichen Beitrags eines Mitglieds im ZDS , leisten ."}
# Output: {"entities": [{"text": "ZDS", "start": 154, "end": 157, "type": "ORG"}]}
#
# Input: {"text": "Jedoch besteht nach der Rechtsprechung des Bundesgerichtshofs ein f\u00fcr die Strafzumessung ma\u00dfgebliches Stufenverh\u00e4ltnis von so genannten harten Drogen wie Heroin oder Kokain \u00fcber Amphetamin , das auf der Gef\u00e4hrlichkeitsskala einen mittleren Platz einnimmt , bis hin zu so genannten weichen Drogen wie Cannabis ( vgl. BGH , Beschluss vom 15. Juni 2016 - 1 StR 72/16 , NStZ-RR 2016 , 313 , 314 ) ."}
# Output: {"entities": [{"text": "Bundesgerichtshofs", "start": 43, "end": 61, "type": "ORG"}]}
#
# Input: {"text": "I. Die Anmelderin hat am 27. Mai 2015 beim Deutschen Patent- und Markenamt beantragt , die Bezeichnung DUO als Wortmarke f\u00fcr \" Wand- und Deckenschalungen aus Kunststoff \" ( Klasse 19 ) in das Markenregister einzutragen ."}
# Output: {"entities": [{"text": "Deutschen Patent- und Markenamt", "start": 43, "end": 74, "type": "ORG"}, {"text": "DUO", "start": 103, "end": 106, "type": "ORG"}]}
#
# Input: {"text": "In der Beschwerdesache betreffend die Patentanmeldung 10 2009 003 162.6 hat der 14. Senat ( Technischer Beschwerdesenat ) des Bundespatentgerichts in der Sitzung vom 1. Februar 2018 unter Mitwirkung des Vorsitzenden Richters Dr. Maksymiw und der Richter Schell und Dr. J\u00e4ger sowie der Richterin Dr. Wagner beschlossen :"}
# Output: {"entities": [{"text": "14. Senat ( Technischer Beschwerdesenat ) des Bundespatentgerichts", "start": 80, "end": 146, "type": "ORG"}]}
#
# Input: {"text": "Sie h\u00e4tte dann aber vortragen m\u00fcssen , dass der BGH die aufgeworfene Fragestellung entweder noch nicht entschieden habe oder dass neuer Kl\u00e4rungsbedarf auf der Basis bereits vorhandener Rechtsprechung des BGH entstanden sei ."}
# Output: {"entities": [{"text": "BGH", "start": 48, "end": 51, "type": "ORG"}]}
#
# Input: {"text": "Die nukleare Teilhabe im Sinne der \" Konzeptionellen Leitlinien zur Weiterentwicklung der Bundeswehr \" vom 12. Juli 1994 w\u00fcrde aber konkret durch die Piloten des Jagdbombergeschwaders 33 ausge\u00fcbt ."}
# Output: {"entities": [{"text": "Bundeswehr", "start": 90, "end": 100, "type": "ORG"}]}
#
# Input: {"text": "Auch aus dem von der Kl\u00e4gerin in der m\u00fcndlichen Verhandlung \u00fcbergebenen Antwortschreiben der Europ\u00e4ischen Kommission vom 11. Dezember 2007 an den Bundesminister des Ausw\u00e4rtigen vermag der Senat keine europarechtlichen Vorgaben zu entnehmen , die f\u00fcr eine Zeitpunktbetrachtung des in \u00a7 2 Abs. 7 Satz 1 InvZulG 2005 verwendeten KMU-Erfordernisses sprechen ."}
# Output: {"entities": [{"text": "Europ\u00e4ischen Kommission", "start": 93, "end": 116, "type": "ORG"}, {"text": "Bundesminister des Ausw\u00e4rtigen", "start": 146, "end": 176, "type": "ORG"}]}
#
# Input: {"text": "3. Die Verfassungsbeschwerde ist der Kl\u00e4gerin sowie der Senatsverwaltung f\u00fcr Justiz , Verbraucherschutz und Antidiskriminierung Berlin zugestellt worden ."}
# Output: {"entities": [{"text": "Senatsverwaltung f\u00fcr Justiz , Verbraucherschutz und Antidiskriminierung Berlin", "start": 56, "end": 134, "type": "ORG"}]}
#
# Input: {"text": "Ein solcher kann auch nicht aus dem Hinweis \" f\u00fcr : A-Fonds \" hergeleitet werden , denn der A-Fonds war zum Zeitpunkt der Bekanntgabe des Bescheides infolge der Verschmelzung auf den B-Fonds gem\u00e4\u00df \u00a7 40 InvG a. F. ( Fall der Gesamtrechtsnachfolge , vgl. \u00a7 14 InvStG , sowie Obermann / Brill / Heeren , Deutsche Steuer-Zeitung - DStZ - 2009 , 152 , 156 ; Ebner , DStZ 2007 , 68 f. ) vollbeendet ."}
# Output: {"entities": [{"text": "A-Fonds", "start": 52, "end": 59, "type": "ORG"}, {"text": "B-Fonds", "start": 183, "end": 190, "type": "ORG"}]}
#
# Input: {"text": "Mit Beschluss vom ... September 2012 wurde die A-AG wegen Verm\u00f6genslosigkeit nach \u00a7 394 des Gesetzes \u00fcber das Verfahren in Familiensachen und in den Angelegenheiten der freiwilligen Gerichtsbarkeit ( FamFG ) im Handelsregister gel\u00f6scht ."}
# Output: {"entities": [{"text": "A-AG", "start": 47, "end": 51, "type": "ORG"}]}
#
# Input: {"text": "Auch wenn die Ermittlung des Schutzgegenstandes regelm\u00e4\u00dfig dem Verletzungsverfahren - und damit den Gerichten - vorbehalten sei , k\u00f6nnten die Grunds\u00e4tze des Bundesgerichtshofes auch auf die Pr\u00fcfung der Schutzf\u00e4higkeit , insbesondere auch auf die Pr\u00fcfung der Designf\u00e4higkeit , \u00fcbertragen werden ."}
# Output: {"entities": [{"text": "Bundesgerichtshofes", "start": 157, "end": 176, "type": "ORG"}]}
#
# Input: {"text": "( 1 ) Der nach Erlass des Senatsurteils vom 31. August 2016 bekannt gewordene Umstand , dass der gerichtliche Sachverst\u00e4ndige in der Fachzeitschrift HIV & More 4/2016 , S. 26 ( vgl. TWeV36 ) f\u00fcr eine Postexpositionsprophylaxe in Zusammenhang mit dem Sonderfall eines multiresistenten HI-Virus eine Behandlung mit Dolutegravir oder Darunagravir empfohlen hat , ist bereits vom Bundesgerichtshof in der Beschwerdeentscheidung unter Rn. 62 f. ber\u00fccksichtigt worden und hat nicht zu einer abweichenden Beurteilung gef\u00fchrt ."}
# Output: {"entities": [{"text": "Bundesgerichtshof", "start": 376, "end": 393, "type": "ORG"}]}
#
# Input: {"text": "aa ) Zum einen ist sie nicht kl\u00e4rungsbed\u00fcrftig , da sie in der Rechtsprechung des BFH bereits gekl\u00e4rt ist ."}
# Output: {"entities": [{"text": "BFH", "start": 82, "end": 85, "type": "ORG"}]}
#
# Input: {"text": "Dementsprechend sei es bislang st\u00e4ndige Praxis des DPMA gewesen , auf Basis von Formulierungspatenten erg\u00e4nzende Schutzzertifikate zu erteilen ."}
# Output: {"entities": [{"text": "DPMA", "start": 51, "end": 55, "type": "ORG"}]}
#
# Input: {"text": "D5 KIN GmbH Lebensmittelinstitut , Pr\u00fcfbericht , 27. August 2015 , 2 Seiten , und"}
# Output: {"entities": [{"text": "KIN GmbH Lebensmittelinstitut", "start": 3, "end": 32, "type": "ORG"}]}
#
# Input: {"text": "den Beschluss der Patentabteilung 1.51 des Deutschen Patent- und Markenamts vom 16. Mai 2013 aufzuheben und das Patent vollumf\u00e4nglich zu widerrufen ."}
# Output: {"entities": [{"text": "Patentabteilung 1.51 des Deutschen Patent- und Markenamts", "start": 18, "end": 75, "type": "ORG"}]}
#
# Input: {"text": "I. Die Kl\u00e4gerin und Beschwerdef\u00fchrerin ( Kl\u00e4gerin ) , eine GmbH , ist nach mehreren Vorg\u00e4ngen Rechtsnachfolgerin der A ."}
# Output: {"entities": [{"text": "A", "start": 117, "end": 118, "type": "ORG"}]}
#
# Input: {"text": "Er selbst sehe sich auch angesichts der in seinem damaligen politischen Amt vorgenommenen und - soweit verfahrensrelevant - mehr als zehn Jahre zur\u00fcckliegenden Positionierungen in der Lage , der Erwartung des Verfassungs- und Gesetzgebers zu entsprechen , seine Aufgabe als Richter des Bundesverfassungsgerichts im vorliegenden Fall unvoreingenommen und unabh\u00e4ngig von seiner fr\u00fcheren politischen T\u00e4tigkeit wahrzunehmen ."}
# Output: {"entities": [{"text": "Bundesverfassungsgerichts", "start": 286, "end": 311, "type": "ORG"}]}
#
# Input: {"text": "Ein \u00dcbergang der Arbeitgebereigenschaft auf die Elektronicon-GmbH ist jedenfalls weder im Wege der nach \u00a7 12 Abs 1 S 1 SpTrUG vom 5. 4. 1991 ( BGBl I 854 ) geheilten Einzel\u00fcbertragung ( nachfolgend a ) noch aufgrund einer Universalsukzession nach \u00a7 7 S 2 UmwVO erfolgt ( nachfolgend b ) ."}
# Output: {"entities": [{"text": "Elektronicon-GmbH", "start": 48, "end": 65, "type": "ORG"}]}
#
# Input: {"text": "Zur Verwirklichung dieses Plans initiierte die PKK verschiedene Organisationen , die mehrfach ihre Bezeichnung wechselten ."}
# Output: {"entities": [{"text": "PKK", "start": 47, "end": 50, "type": "ORG"}]}
#
# Input: {"text": "Der Antrag kann von beiden Beteiligten gestellt werden ( vgl. Baumbach / Hartmann , ZPO , 76. Aufl. 2018 , \u00a7 269 , Rdn. 46 ; Fezer / Grabrucker , Handbuch der Markenpraxis , Band I ( Markenverfahrensrecht ) , 3. Aufl. 2016 , Rdn. 384 ) ; eine Beschr\u00e4nkung auf den Markeninhaber l\u00e4sst sich der Entscheidung des Bundesgerichtshofes nicht entnehmen ."}
# Output: {"entities": [{"text": "Bundesgerichtshofes", "start": 310, "end": 329, "type": "ORG"}]}
#
# Input: {"text": "Die Generalstaatsanwaltschaft M\u00fcnchen wird mit der Durchf\u00fchrung der einstweiligen Anordnung beauftragt ."}
# Output: {"entities": [{"text": "Generalstaatsanwaltschaft M\u00fcnchen", "start": 4, "end": 37, "type": "ORG"}]}
#
# Input: {"text": "( 2 ) F\u00f6rdermitglieder schulden dem ZDS nach \u00a7 12 Nr. 1 Satz 2 der Satzung Beitr\u00e4ge ."}
# Output: {"entities": [{"text": "ZDS", "start": 36, "end": 39, "type": "ORG"}]}
#
# Input: {"text": "Ihr Vertrauen in den Bestand des geltenden Gewerbesteuerrechts war mit der Zuleitung des Entwurfs des Unternehmenssteuerfortentwicklungsgesetzes zum Bundesrat nicht mehr schutzw\u00fcrdig ( bb ) ."}
# Output: {"entities": [{"text": "Bundesrat", "start": 149, "end": 158, "type": "ORG"}]}
#
# Input: {"text": "4. Ob die Einbringung des BgA in die F-GmbH den Besteuerungstatbestand der Aufl\u00f6sung der R\u00fccklagen gem\u00e4\u00df \u00a7 20 Abs. 1 Nr. 10 Buchst. b Satz 2 EStG ausl\u00f6sen konnte und ob dabei die Gesetzesfassung des StSenkG oder die erg\u00e4nzte Fassung des JStG 2007 ma\u00dfgeblich gewesen w\u00e4re , braucht im Streitfall nicht entschieden zu werden ."}
# Output: {"entities": [{"text": "F-GmbH", "start": 37, "end": 43, "type": "ORG"}]}
#
# Input: {"text": "I. Die Wortkombination Lebe Balance ist am 2. Oktober 2013 zur Eintragung als Wortmarke in das beim Deutschen Patent- und Markenamt gef\u00fchrte Markenregister f\u00fcr die nachfolgende Dienstleistung der Klassen 9 angemeldet worden :"}
# Output: {"entities": [{"text": "Lebe Balance", "start": 23, "end": 35, "type": "ORG"}, {"text": "Deutschen Patent- und Markenamt", "start": 100, "end": 131, "type": "ORG"}]}
#
# Input: {"text": "Nach diesen Ma\u00dfst\u00e4ben ist die Versetzung des Antragstellers auf den Dienstposten eines Einsatzoffiziers Streitkr\u00e4fte beim ... amt in B nicht zu beanstanden ."}
# Output: {"entities": [{"text": "... amt", "start": 122, "end": 129, "type": "ORG"}]}
#
# Input: {"text": "Der Europ\u00e4ische Gerichtshof f\u00fcr Menschenrechte hat bereits betont , dass eine Begnadigung nicht von vornherein untauglich ist , um dem Verurteilten eine Chance auf Wiedererlangung der Freiheit einzur\u00e4umen ( EGMR , Urteil vom 4. September 2014 - Nr. 140/10 , Trabelsi / Belgien - Rn. 137 ) ."}
# Output: {"entities": [{"text": "Europ\u00e4ische Gerichtshof f\u00fcr Menschenrechte", "start": 4, "end": 46, "type": "ORG"}]}
#
# Input: {"text": "Insoweit wird die Berufung des Kl\u00e4gers gegen das Urteil des Sozialgerichts Duisburg vom 15. M\u00e4rz 2011 zur\u00fcckgewiesen ."}
# Output: {"entities": [{"text": "Sozialgerichts Duisburg", "start": 60, "end": 83, "type": "ORG"}]}
#
# Input: {"text": "ff ) Entgegen der Ansicht der Revision w\u00e4re das Unionsrecht hier auch nicht verletzt , wenn Besch\u00e4ftigte , welche sich auf den unionsrechtlich gew\u00e4hrleisteten Freiz\u00fcgigkeitsschutz berufen k\u00f6nnen , bezogen auf die Ber\u00fccksichtigung ihrer in der Europ\u00e4ischen Union erworbenen einschl\u00e4gigen Berufserfahrung bessergestellt w\u00e4ren , als Besch\u00e4ftigte ohne Bezug zum EU-Ausland ( Problem der sog. Inl\u00e4nderdiskriminierung ) ."}
# Output: {"entities": [{"text": "Europ\u00e4ischen Union", "start": 243, "end": 261, "type": "ORG"}]}
#
# Input: {"text": "Vor diesem Hintergrund sei die Aussage des Ausw\u00e4rtigen Amtes in seinem Schreiben vom 20. M\u00e4rz 2018 , wonach jede Todesstrafe durch einen Gnadenakt des Pr\u00e4sidenten in eine lebenslange Freiheitsstrafe umgewandelt werde , falsch ."}
# Output: {"entities": [{"text": "Ausw\u00e4rtigen Amtes", "start": 43, "end": 60, "type": "ORG"}]}
#
# Input: {"text": "Annex A : Schott , Temperung ( Kristallisation ) und anschlie\u00dfende XRD-Analyse der Glaskeramikschmelze VSM 46802 , 11. 2. 2016 , 3 Seiten"}
# Output: {"entities": [{"text": "Schott", "start": 10, "end": 16, "type": "ORG"}]}
#
# Input: {"text": "Er beantragt sinngem\u00e4\u00df , den Beschluss des Deutschen Patent- und Markenamtes vom 7. Dezember 2015 aufzuheben ."}
# Output: {"entities": [{"text": "Deutschen Patent- und Markenamtes", "start": 43, "end": 76, "type": "ORG"}]}
#
# Input: {"text": "Der Beschluss der Markenstelle f\u00fcr Klasse 38 des Deutschen Patent- und Markenamtes vom 28. Oktober 2013 wird aufgehoben ."}
# Output: {"entities": [{"text": "Markenstelle f\u00fcr Klasse 38 des Deutschen Patent- und Markenamtes", "start": 18, "end": 82, "type": "ORG"}]}
#
# Input: {"text": "Der Beschluss des Oberlandesgerichts M\u00fcnchen vom 16. Oktober 2017 verletze den Beschwerdef\u00fchrer in seinem Grundrecht auf effektiven Rechtsschutz nach Art. 19 Abs. 4 Satz 1 GG ."}
# Output: {"entities": [{"text": "Oberlandesgerichts M\u00fcnchen", "start": 18, "end": 44, "type": "ORG"}]}
#
# Input: {"text": "Er hat in Rz 35 ff. seiner Entscheidung begr\u00fcndet , warum - auf Grundlage der Rechtsprechung des EuGH - die nationale Regelung mit Unionsrecht vereinbar ist , und hat aus den unter Rz 45 ff. genannten Gr\u00fcnden die Einwendungen des Kl\u00e4gers f\u00fcr nicht durchgreifend erachtet ."}
# Output: {"entities": [{"text": "EuGH", "start": 97, "end": 101, "type": "ORG"}]}
#
# Input: {"text": "a ) Eine Rechtssache hat grunds\u00e4tzliche Bedeutung i. S. des \u00a7 115 Abs. 2 Nr. 1 FGO oder erfordert eine Entscheidung des Bundesfinanzhofs ( BFH ) zur Fortbildung des Rechts als Unterfall des Zulassungsgrundes der grunds\u00e4tzlichen Bedeutung , wenn die f\u00fcr die Beurteilung des Streitfalls ma\u00dfgebliche Rechtsfrage das Interesse der Allgemeinheit an der einheitlichen Entwicklung und Handhabung des Rechts ber\u00fchrt ."}
# Output: {"entities": [{"text": "Bundesfinanzhofs", "start": 120, "end": 136, "type": "ORG"}, {"text": "BFH", "start": 139, "end": 142, "type": "ORG"}]}
#
# Input: {"text": "Die Beklagte hat die Kl\u00e4gerinnen mit Klageschrift vom 17. August 2015 vor dem Landgericht D\u00fcsseldorf ( 4c O 48/15 ) wegen Verletzung des Streitpatents u. a. auf Unterlassung in Anspruch genommen ."}
# Output: {"entities": [{"text": "Landgericht D\u00fcsseldorf", "start": 78, "end": 100, "type": "ORG"}]}
#
# Input: {"text": "Die Bundesregierung ist den Verfahren beigetreten ( \u00a7 94 Abs. 5 Satz 1 BVerfGG ) ."}
# Output: {"entities": [{"text": "Bundesregierung", "start": 4, "end": 19, "type": "ORG"}]}
#
# Input: {"text": "Der Senat geht vielmehr davon aus , dass entsprechend der Rechtsprechung des BGH die Gesellschaft b\u00fcrgerlichen Rechts und die Partnerschaftsgesellschaft und gleicherma\u00dfen auch die BAG unver\u00e4ndert fortbestehen ( SozR 4 - 2500 \u00a7 87b Nr 2 RdNr 27 mit zahlreichen Nachweisen ) ."}
# Output: {"entities": [{"text": "BGH", "start": 77, "end": 80, "type": "ORG"}]}
#
# Input: {"text": "Die Revision der Kl\u00e4gerin gegen das Urteil des S\u00e4chsischen Landessozialgerichts vom 19. Mai 2016 wird zur\u00fcckgewiesen ."}
# Output: {"entities": [{"text": "S\u00e4chsischen Landessozialgerichts", "start": 47, "end": 79, "type": "ORG"}]}
#
# Input: {"text": "Wegen dieser nicht genehmigten Teilnahme erlie\u00df die Bezirksregierung K\u00f6ln gegen die Beschwerdef\u00fchrerin zu III. unter dem 10. Mai 2010 eine Disziplinarverf\u00fcgung , mit der ihr eine Geldbu\u00dfe in H\u00f6he von 1.500 EUR auferlegt wurde ."}
# Output: {"entities": [{"text": "Bezirksregierung K\u00f6ln", "start": 52, "end": 73, "type": "ORG"}]}
#
# Input: {"text": "Mit Schreiben vom 8. November 2016 nahm das vorlegende Gericht zur Vorlagefrage erg\u00e4nzend Stellung und stellte dabei klar , dass es im vorliegenden Fall - anders als vom Bundesverfassungsgericht mit Beschluss vom 26. Juli 2016 entschieden - um die M\u00f6glichkeit der Zwangsmedikation bei ambulanter Behandlung gehe ."}
# Output: {"entities": [{"text": "Bundesverfassungsgericht", "start": 170, "end": 194, "type": "ORG"}]}
#
# Input: {"text": "( 2 ) Der Pensions-Sicherungs-Verein Versicherungsverein auf Gegenseitigkeit unterliegt der Aufsicht durch die Bundesanstalt f\u00fcr Finanzdienstleistungsaufsicht . \u2026 \u201c"}
# Output: {"entities": [{"text": "Bundesanstalt f\u00fcr Finanzdienstleistungsaufsicht", "start": 111, "end": 158, "type": "ORG"}]}
#
# Input: {"text": "Der Sohn der Kl\u00e4gerin und Beschwerdef\u00fchrerin ( Kl\u00e4gerin ) , Herr ... ( A ) , f\u00fchrte bis zur Untersagung durch die Stadt M am 8. Januar 2001 das Restaurant X."}
# Output: {"entities": [{"text": "X.", "start": 155, "end": 157, "type": "ORG"}]}
#
# Input: {"text": "aa ) Die Bindung kann entfallen , wenn sich nachtr\u00e4glich die ma\u00dfgebenden Umst\u00e4nde ge\u00e4ndert haben , und zwar entweder , weil sich der zugrunde gelegte Sachverhalt in einer f\u00fcr die Entscheidung erheblichen Weise ge\u00e4ndert hat ( dazu BFH-Urteil vom 7. August 1990 VII R 120/89 , BFH / NV 1991 , 569 ) , sich einschl\u00e4gige Gesetzesbestimmungen r\u00fcckwirkend ge\u00e4ndert haben oder sich die h\u00f6chstrichterliche Rechtsprechung des entscheidenden Senats , des Gro\u00dfen Senats des BFH , des EuGH oder des Gemeinsamen Senats der obersten Gerichtsh\u00f6fe des Bundes - unabh\u00e4ngig von dem Streitfall - ge\u00e4ndert hat ( BFH-Urteil vom 8. November 1983 VII R 141/82 , BFHE 140 , 11 , BStBl II 1984 , 317 , unter II. 2. , zur Entscheidung des Senats ; BFH-Beschl\u00fcsse vom 22. Februar 2006 I B 145/05 , BFHE 213 , 29 , BStBl II 2006 , 546 , unter II. 2. d bb , Rz 35 , zur Gesetzes\u00e4nderung ; vom 11. Januar 2007 XI B 22/06 , BFH / NV 2007 , 909 , zur Entscheidung des Gro\u00dfen Senats ; Gr\u00e4ber / Ratschow , a. a. O. , \u00a7 126 Rz 29 ) ."}
# Output: {"entities": [{"text": "Gro\u00dfen Senats des BFH", "start": 445, "end": 466, "type": "ORG"}, {"text": "EuGH", "start": 473, "end": 477, "type": "ORG"}, {"text": "Gemeinsamen Senats der obersten Gerichtsh\u00f6fe des Bundes", "start": 487, "end": 542, "type": "ORG"}]}
#
# Input: {"text": "1. Auf die Revision des Angeklagten wird das Urteil des Landgerichts Koblenz vom 21. August 2017 , soweit es ihn betrifft , aufgehoben"}
# Output: {"entities": [{"text": "Landgerichts Koblenz", "start": 56, "end": 76, "type": "ORG"}]}
#
# Input: {"text": "Da allein das Fehlen jeglicher Unterscheidungskraft ein Eintragungshindernis begr\u00fcndet , ist nach der Rechtsprechung des Bundesgerichtshofes ein gro\u00dfz\u00fcgiger Ma\u00dfstab anzulegen , so dass jede auch noch so geringe Unterscheidungskraft gen\u00fcgt , um das Schutzhindernis zu \u00fcberwinden ( vgl. BGH GRUR 2012 , 1143 , Rn. 7 - Starsat ; GRUR 2012 , 1044 , 1045 , Rn. 9 - Neuschwanstein ; GRUR 2012 , 270 , Rn. 8 - Link economy ) ."}
# Output: {"entities": [{"text": "Bundesgerichtshofes", "start": 121, "end": 140, "type": "ORG"}]}
#
#
#
# EXISTING RULES (11 current):
#
# - court_unit_with_ordinal (priority 10, success: untested)
#   Format: regex
#   Pattern: (?<!\S)(?:\d{1,2}\.\s*)?(?:Zivilkammer|Senat|Kammer|Beschwerdesenat|Technischer\s+Beschwerdesenat|Pa...
#   Confidence: 0.50
#
# - patent_department_full (priority 10, success: untested)
#   Format: regex
#   Pattern: (?<!\S)(?:Patentabteilung\s*\d+(?:\.\d+)?(?:\s*\([^\)]*\))?\s+des\s+Deutschen\s+Patent-\s*und\s+Mark...
#   Confidence: 0.50
#
# - specific_institutions_list (priority 10, success: untested)
#   Format: regex
#   Pattern: (?<!\S)(?:Bundesverfassungsgericht(?:s)?|Bundesgerichtshof(?:s|es)?|Bundespatentgericht(?:s)?|Deutsc...
#   Confidence: 0.50
#
# - senatsverwaltung_full (priority 10, success: untested)
#   Format: regex
#   Pattern: (?<!\S)(Senatsverwaltung\s+f(?:ü|u)r[^\n]{1,160}?Berlin)\b
#   Confidence: 0.50
#
# - minister_and_ministry (priority 10, success: untested)
#   Format: regex
#   Pattern: (?<!\S)(Bundesminister(?:in|n)?\s+des\s+[A-ZÄÖÜ][\wäöüÄÖÜ\- ]{1,80})\b
#   Confidence: 0.50
#
# - corporate_suffixes_with_followers (priority 9, success: untested)
#   Format: regex
#   Pattern: (?<!\S)\b[A-ZÄÖÜ0-9][\w\.-]*(?:\s+[A-ZÄÖÜ0-9][\w\.-]*){0,4}\s+(?:AG|GmbH|KG|UG|OHG|e\.V\.|GbR|Gbr|SE...
#   Confidence: 0.50
#
# - hyphenated_company_names (priority 9, success: untested)
#   Format: regex
#   Pattern: (?<!\S)[A-ZÄÖÜ][\w\.-]*-(?:AG|GmbH|KG|UG|OHG|e\.V\.|SE|Ltd|Inc)\b
#   Confidence: 0.50
#
# - funds_A_or_letter_Fonds (priority 9, success: untested)
#   Format: regex
#   Pattern: (?<!\S)\b[A-Z](?:-[A-Z][\w-]*)?\s*Fonds\b
#   Confidence: 0.50
#
# - refined_org_after_des_or_der (priority 9, success: untested)
#   Format: regex
#   Pattern: (?<=\b(?:des|der)\s)(?:[A-ZÄÖÜ][\w\.-]*\s*(?:Gericht|Gerichts|Amt|Amts|Patent(?:-\s*und\s*Markenamts...
#   Confidence: 0.50
#
# - trademark_uppercase_following_bezeichnung (priority 9, success: untested)
#   Format: regex
#   Pattern: (?<=\bBezeichnung\s)([A-ZÄÖÜ]{2,20})(?=\s+als\s+Wortmarke)
#   Confidence: 0.50
#
# - uppercase_acronyms_general (priority 7, success: untested)
#   Format: regex
#   Pattern: (?<!\S)\b[A-ZÄÖÜ]{2,6}\b
#   Confidence: 0.50
#
# CONSIDER:
# - Refine existing high-performing rules
# - Fix or replace low-performing rules
# - Keep rules that work well
# - Add new rules for uncovered patterns
#
# YOUR TASK:
# Update and refine ruleset (max 10 rules) that:
# 1. Rely ONLY on the data provided
# 2. Handles all corrections correctly (CRITICAL - these show failure modes)
# 3. Works on all examples
# 4. Respects user feedback
# 5. Is general and minimal (avoid redundant rules)
#
# RULES CAN BE:- Regex patterns (for structured extraction)
#
# IMPORTANT: You must ONLY use the allowed formats listed above. Do NOT generate rules in other formats.
# IMPORTANT: Do NOT include Python/code rules. Only return the listed formats.
# IMPORTANT: Do NOT include spaCy rules. Only return the listed formats.
#
# SCHEMA-AWARE RULES:
# For this task, rules must include an output_template that maps matches to the output schema.
#
# Output schema:
# entities: List[Entity]
#
# Entity:
#   text: string  # The matched text span
#   start: integer  # Start character offset
#   end: integer  # End character offset
#   type: string  # Entity label
#
# Each rule needs:
# - pattern: The regex pattern to match
# - output_template: JSON template for each match, using variables:
#   - $0: Full match text
#   - $start: Start character offset
#   - $end: End character offset
#   - $1, $2, ...: Capture groups (regex only)
# - output_key: Which output array to populate (e.g., "entities")
#
# Return JSON:
# {
#   "analysis": "What patterns did you find? What went wrong in corrections?",
#   "strategy": "Overall approach",
#   "note": "Every rule must include both output_template and output_key",
#   "rules": [
#     {
#       "name": "Short rule name",
#       "description": "What this rule does",
#       "format": "regex",
#       "pattern": "regex pattern",
#       "output_template": {"text": "$0", "start": "$start", "end": "$end", "type": "LITERAL_OR_$VAR"},
#       "output_key": "entities",
#       "priority": 1-10 (higher = more important),
#       "reasoning": "Why this rule is needed"
#     }
#   ]
# }
#
# NER RULE EXAMPLES (regex):
#
#
# Example 1 - Organizations with corporate suffixes:
# {
#   "name": "corporate_suffixes",
#   "format": "regex",
#   "pattern": "\b([A-Z][a-z0-9]+(?:\s+[A-Z][a-z]+)*)\s+(AG|GmbH|KG|UG|OHG|Gbr)\b",
#   "output_template": {"text": "$0", "start": "$start", "end": "$end", "type": "ORG"},
#   "output_key": "entities",
#   "priority": 9
# }
#
# Focus on learning from CORRECTIONS - they show exactly what went wrong!
#
# IMPORTANT: Return ONLY valid JSON. Ensure:
# - All strings use double quotes and are properly escaped
# - All braces and brackets are balanced
# - No trailing commas
# - Response is complete (not truncated)
#
# 📚 Synthesizing rules from dataset...
# ✓ Synthesized 9 rules (125.4s)
# ✓ Generated 9 rules
#
# 🔄 Refinement loop (max 3 iterations)
# [1/3] Evaluating rules...
# [1/3] Accuracy: 11.4% (1139/9994)
# [1/3] Refining based on 8855 failures...
# de
#       Validation error: look-behind requires fixed-width pattern
#    ⚠ Skipped invalid rule: single_letter_party_placeholders
# [1/3] Refined 9 rules (117.8s)
# [2/3] Evaluating rules...
# [2/3] Accuracy: 14.3% (1426/9994)
# [2/3] Refining based on 8568 failures...
# de
# [2/3] Refined 14 rules (99.7s)
# [3/3] Evaluating rules...
# [3/3] Accuracy: 17.7% (1771/9994)
# [3/3] Refining based on 8223 failures...
# de
# [3/3] Refined 15 rules (140.0s)
#
# ============================================================
# Learning complete! (485.3s)
#   Rules: 14
#   Accuracy: 17.7% (1771/9994)
# ============================================================

# %%
rules_file = Path("./rulechef_data/2025-02-02_ORG_ler_dataset_v2.json")
rules_data = json.loads(rules_file.read_text())

rules = [Rule.from_dict(r) for r in rules_data.get("rules")]
for rule in rules:
    print_rule_result(rule)
    print("####################")
# Out:
# CONTENT Numbered Zivilkammer of a Landgericht, e.g. '17. Zivilkammer des Landgerichts Dortmund'
# regex.Regex('(?<!\\S)(\\d{1,2}\\.\\s*Zivilkammer\\s+des\\s+Landgerichts\\s+[A-ZÄÖÜ][A-Za-zäöüÄÖÜß\\-]*(?:\\s+[A-ZÄÖÜ][A-Za-zäöüÄÖÜß\\-]*){0,4})', flags=regex.V0)
# ####################
# CONTENT Numbered Senat lines with optional parenthetical qualifier and trailer 'des <court>', e.g. '14. Senat ( Technischer Beschwerdesenat ) des Bundespatentgerichts'
# regex.Regex('(?<!\\S)(\\d{1,2}\\.\\s*Senat(?:\\s*\\([^\\)]*\\))?(?:\\s*\\([^\\)]*\\))?(?:\\s+des\\s+[A-ZÄÖÜ][A-Za-zäöüÄÖÜß\\-]*(?:[\\s\\-\\/\\,][A-ZÄÖÜa-zäöüÄÖÜß0-9\\-\\(\\)]*){0,6})?)', flags=regex.V0)
# ####################
# CONTENT Patentabteilung phrases referring to the German Patent Office including number and trailer, e.g. 'Patentabteilung 1.51 des Deutschen Patent- und Markenamts'
# regex.Regex('(?<!\\S)(Patentabteilung\\s*\\d+(?:\\.\\d+)?(?:\\s*\\([^\\)]*\\))?\\s+des\\s+(?:Deutschen|Deutsches)\\s+Patent-?\\s*(?:und\\s+Markenamt|und\\s+Markenamts|Markenamts|Markenamt)\\b)', flags=regex.V0)
# ####################
# CONTENT Full names of major federal courts and institutions in standard forms (incl. simple inflected forms)
# regex.Regex('(?<!\\S)\\b(Bundesverfassungsgericht(?:es|s)?|Bundesgerichtshof(?:es|s)?|Bundespatentgericht(?:es|s)?|Bundespatentgerichts|Bundeswehr)\\b', flags=regex.V0)
# ####################
# CONTENT Possessive/inflected forms of court names like 'Bundesgerichtshofes', 'Bundespatentgerichts' etc.
# regex.Regex('(?<!\\S)\\b(Bundesgerichtshofes|Bundesverfassungsgerichtes|Bundespatentgerichts|Bundesgerichts|Bundesgerichtshofes)\\b', flags=regex.V0)
# ####################
# CONTENT Senatsverwaltung with long trailer including commas and 'Berlin', e.g. 'Senatsverwaltung für Justiz , Verbraucherschutz und Antidiskriminierung Berlin'
# regex.Regex('(?<!\\S)(Senatsverwaltung\\s+für\\s+[A-ZÄÖÜ][A-Za-zäöüÄÖÜß\\,\\-\\s]{1,160}?Berlin)\\b', flags=regex.V0)
# ####################
# CONTENT Generic numbered chamber patterns (e.g., '17. Zivilkammer', or other numbered chambers with 'des <court>')
# regex.Regex('(?<!\\S)(\\d{1,2}\\.\\s*(?:Zivilkammer|Kammer|Strafkammer|Zivilgericht|Abteilung)(?:\\s+des\\s+[A-ZÄÖÜ][A-Za-zäöüÄÖÜß\\-]+(?:\\s+[A-ZÄÖÜ][A-Za-zäöüÄÖÜß\\-]+){0,4})?)', flags=regex.V0)
# ####################
# CONTENT Corporate names with legal suffixes (AG, GmbH, KG, UG, OHG, e.V., Fonds, Gbr, GbR) where the leading token is a realistic name (mixed-case or all-caps acronym), excludes leading digit-containing tokens like 'D5'.
# regex.Regex('(?<!\\S)((?:[A-ZÄÖÜ][a-zäöüß][A-Za-zäöüÄÖÜß0-9\\.-]*|[A-ZÄÖÜ]{2,}))(?:\\s+[A-ZÄÖÜ][A-Za-zäöüÄÖÜß0-9\\.-]*){0,6}\\s+(AG|GmbH|KG|UG|OHG|e\\.V\\.|Fonds|Gbr|GbR)\\b(?:\\s+[A-ZÄÖÜ][A-Za-zäöüÄÖÜß0-9\\-]*){0,6}', flags=regex.V0)
# ####################
# CONTENT Hyphenated company names with suffixes, e.g. 'Elektronicon-GmbH', 'A-AG'
# regex.Regex('(?<!\\S)([A-ZÄÖÜ][A-Za-zäöüÄÖÜ0-9]*-(?:AG|GmbH|KG|UG|OHG|e\\.V\\.|Fonds|Gbr|GbR))\\b(?:\\s+[A-ZÄÖÜ][A-Za-zäöüÄÖÜ0-9\\-]*)?', flags=regex.V0)
# ####################
# CONTENT Single-letter or short acronym funds e.g. 'A-Fonds', 'B-Fonds', also 'A-Fonds' with optional dash/space
# regex.Regex('(?<!\\S)([A-Z](?:-[A-Z][A-Za-z0-9\\-]*)?)\\s*-?Fonds\\b', flags=regex.V0)
# ####################
# CONTENT General forms of the German Patent and Trademark Office in various inflections, e.g. 'Deutschen Patent- und Markenamt', 'Deutsches Patent- und Markenamt'
# regex.Regex('(?<!\\S)(?:Deutschen|Deutsches)\\s+Patent-?\\s*(?:und\\s+Markenamt|und\\s+Markenamts|Markenamt|Markenamts)\\b', flags=regex.V0)
# ####################
# CONTENT Common acronyms for courts/agencies and other organisations (BGH, BVerfG, BPatG, BFH, DPMA, ZDS, PKK, DUO etc.)
# regex.Regex('(?<!\\S)\\b(BGH|BVerfG|BPatG|BFH|DPMA|ZDS|PKK|DUO)\\b', flags=regex.V0)
# ####################
# CONTENT Short all-caps organisation tokens of length>=2 (fallback for things like 'A-B' handled elsewhere), but only pure letters to avoid matching codes with digits
# regex.Regex('(?<!\\S)\\b([A-ZÄÖÜ]{2,})\\b', flags=regex.V0)
# ####################
# CONTENT Allow corporate base + suffix + trailing descriptor words (e.g., 'KIN GmbH Lebensmittelinstitut') where first token is valid (no digit-only or digit-mixed first token).
# regex.Regex('(?<!\\S)((?:[A-ZÄÖÜ][a-zäöüß][A-Za-zäöüÄÖÜß0-9\\.-]*|[A-ZÄÖÜ]{2,}))(?:\\s+[A-ZÄÖÜ][A-Za-zäöüÄÖÜß0-9\\.-]*){0,4}\\s+(AG|GmbH|KG|UG|OHG|e\\.V\\.|Fonds|Gbr|GbR)\\b(?:\\s+[A-Za-zäöüÄÖÜß0-9\\-]+){1,5}', flags=regex.V0)
# ####################
