# %%
from scripts.llm_baseline import LLMNER

# %%
llm_ner = LLMNER()
# Out:
# Warning: Few-shot examples file not found at /Users/nadia/Desktop/TU CLEAR/CLEAR-anonymization/prompts/examples.json
# Using default cache file: /Users/nadia/Desktop/TU CLEAR/CLEAR-anonymization/cache/cache_gpt-4.1-mini.json

# %%
sentence = "In diesem machte er im Wege der Stufenklage Pflichtteils- und Pflichtteilsergänzungsansprüche gegen die Restitutionsbeklagte ( im Folgenden : Beklagte ) aus dem Erbfall nach dem am 26. Juni 2006 verstorbenen Erblasser geltend ."
tokens = sentence.split(" ")

# %%
predicted = llm_ner.predict(tokens)["labels"]

# %%
for token, pred in zip(tokens, predicted):
    print(token, "-------->", pred)
# Out:
# In --------> O
# diesem --------> O
# machte --------> O
# er --------> O
# im --------> O
# Wege --------> O
# der --------> O
# Stufenklage --------> O
# Pflichtteils- --------> O
# und --------> O
# Pflichtteilsergänzungsansprüche --------> O
# gegen --------> O
# die --------> O
# Restitutionsbeklagte --------> B-ORG
# ( --------> O
# im --------> O
# Folgenden --------> O
# : --------> O
# Beklagte --------> B-ORG
# ) --------> O
# aus --------> O
# dem --------> O
# Erbfall --------> O
# nach --------> O
# dem --------> O
# am --------> O
# 26. --------> B-NRM
# Juni --------> I-NRM
# 2006 --------> I-NRM
# verstorbenen --------> O
# Erblasser --------> O
# geltend --------> O
# . --------> O
